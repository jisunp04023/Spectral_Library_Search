# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
lungT1 = pd.read_excel('./dot_under_0.2/NFRP_lung_target_1.xlsx')
lungT1.head()
# Out:
#                                     ### Query  Rk              ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00038.00038.2   1   QPVQVPVTLVR/2  0.138
# 1  01088_A01_P010740_S00_N01_R1.00177.00177.2   1  GVDLTEPTQPTR/2  0.182
# 2  01088_A01_P010740_S00_N01_R1.00178.00178.2   1  LSYSTSQEFSSR/2  0.123
# 3  01088_A01_P010740_S00_N01_R1.00185.00185.2   1  DLEINAEEEPEK/2  0.152
# 4  01088_A01_P010740_S00_N01_R1.00189.00189.2   1   IPILSTFLTAR/2  0.160
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.024   [2]      0   0.491     13    0.060  ...      -1        0
# 1  0.011   [2]      0   0.500     61    0.066  ...      -1        0
# 2  0.019   [2]      0   0.494     48    0.046  ...      -1        0
# 3  0.022   [2]      0  -0.005     32    0.062  ...      -1        0
# 4  0.005   [2]      0   0.507     19    0.080  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# 1          0        ()  Normal  Unk  Unk   1
# 2          0        ()  Normal  Unk  Unk   1
# 3          0        ()  Normal  Unk  Unk   1
# 4          0        ()  Normal  Unk  Unk   1
#
#                               Proteins  LibFileOffset
# 0    sp|Q06330|SUH_HUMAN(pre=R,post=N)      204920315
# 1  sp|P20339|RAB5A_HUMAN(pre=R,post=N)       93428339
# 2  sp|Q5VUB5|F1711_HUMAN(pre=K,post=E)      165457641
# 3   sp|Q12955|ANK3_HUMAN(pre=R,post=K)       32499455
# 4   sp|Q9UBB6|NCDN_HUMAN(pre=K,post=G)      115380768
#
# [5 rows x 22 columns]

# %%
lungT2 = pd.read_excel('./dot_under_0.2/NFRP_lung_target_2.xlsx')
lungT2.head()
# Out:
#                                     ### Query  Rk  \
# 0  01088_E04_P010740_S00_N29_R1.51102.51102.3   1
# 1  01088_E04_P010740_S00_N29_R1.51103.51103.3   1
# 2  01088_E04_P010740_S00_N29_R1.51105.51105.2   1
# 3  01088_E04_P010740_S00_N29_R1.51106.51106.3   1
# 4  01088_E04_P010740_S00_N29_R1.51132.51132.3   1
#
#                              ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  NNNIDMEVERPSNSEAHETDTAISYK/3  0.163  0.042   [2]      0   0.330      7
# 1    APARPAPDAPEDTGDSDEWVFDKK/3  0.084  0.004   [2]      0  -0.008      4
# 2            GQFAEHLLGAGFVSSR/2  0.139  0.017   [2]      0  -0.001     62
# 3     NVNIYRDSAIPVESDTDDEGAPR/3  0.111  0.016   [2]      0  -0.004     13
# 4     YSTPHAFTFNTSSPSSEGSLSQR/3  0.173  0.016   [2]      0   0.333     11
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.079  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 1    0.067  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 2    0.056  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 3    0.055  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 4    0.085  ...      -1        0          0        ()  Normal  Unk  Unk   1
#
#                               Proteins  LibFileOffset
# 0  sp|Q53SF7|COBL1_HUMAN(pre=K,post=E)      184092630
# 1  sp|Q14896|MYPC3_HUMAN(pre=K,post=L)       15329062
# 2  sp|Q9H2U1|DHX36_HUMAN(pre=K,post=N)       89299847
# 3   sp|Q96D46|NMD3_HUMAN(pre=K,post=I)      188431526
# 4   sp|P04049|RAF1_HUMAN(pre=R,post=Q)      293512030
#
# [5 rows x 22 columns]

# %%
lungT3 = pd.read_excel('./dot_under_0.2/NFRP_lung_target_3.xlsx')
lungT3.head()
# Out:
#                                     ### Query  Rk                      ID  \
# 0  01279_C03_P013163_B00_N19_R1.26505.26505.2   1        GFAFVTFESPADAK/2
# 1  01279_C03_P013163_B00_N19_R1.26510.26510.2   1   DPGGHYTLQEVEEGLAQHK/2
# 2  01279_C03_P013163_B00_N19_R1.26512.26512.2   1        EMGYAATEQEISLR/2
# 3  01279_C03_P013163_B00_N19_R1.26513.26513.2   1  LDMVEDTEGEPPFLPESFDR/2
# 4  01279_C03_P013163_B00_N19_R1.26516.26516.3   1        QAKEEAQAEIEQYR/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.173  0.006   [2]      0   0.497     93    0.059  ...      -1        0
# 1  0.142  0.016   [2]      0   0.493     19    0.059  ...      -1        0
# 2  0.195  0.022   [2]      0  -0.001     43    0.070  ...      -1        0
# 3  0.128  0.085   [2]      0   0.002      3    0.070  ...      -1        0
# 4  0.188  0.009   [2]      0   0.326     57    0.075  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# 1          0        ()  Normal  Unk  Unk   1
# 2          0        ()  Normal  Unk  Unk   1
# 3          0        ()  Normal  Unk  Unk   1
# 4          0        ()  Normal  Unk  Unk   1
#
#                               Proteins  LibFileOffset
# 0  sp|Q8N7X1|RMXL3_HUMAN(pre=R,post=A)       79968553
# 1   sp|P21549|SPYA_HUMAN(pre=K,post=P)       35513767
# 2  sp|O00478|BT3A3_HUMAN(pre=K,post=E)       56236005
# 3  sp|Q8TEA1|NSUN6_HUMAN(pre=K,post=I)      142904461
# 4  sp|O75348|VATG1_HUMAN(pre=K,post=L)      196099012
#
# [5 rows x 22 columns]

# %%
print(len(lungT1))
print(len(lungT2))
print(len(lungT3))
lungT = pd.concat([lungT1, lungT2])
lungT = pd.concat([lungT, lungT3])
print(len(lungT))

lungT = lungT.reset_index(drop=True)
lungT
# Out:
# 126374
# 138754
# 144572
# 409700
#                                          ### Query  Rk  \
# 0       01088_A01_P010740_S00_N01_R1.00038.00038.2   1
# 1       01088_A01_P010740_S00_N01_R1.00177.00177.2   1
# 2       01088_A01_P010740_S00_N01_R1.00178.00178.2   1
# 3       01088_A01_P010740_S00_N01_R1.00185.00185.2   1
# 4       01088_A01_P010740_S00_N01_R1.00189.00189.2   1
# ...                                            ...  ..
# 409695  01279_H04_P013163_B00_N32_R1.56784.56784.2   1
# 409696  01279_H04_P013163_B00_N32_R1.56789.56789.2   1
# 409697  01279_H04_P013163_B00_N32_R1.56790.56790.2   1
# 409698  01279_H04_P013163_B00_N32_R1.56795.56795.3   1
# 409699  01279_H04_P013163_B00_N32_R1.56798.56798.3   1
#
#                                    ID    Dot  Delta DelRk  DBias  MzDiff  \
# 0                       QPVQVPVTLVR/2  0.138  0.024   [2]      0   0.491
# 1                      GVDLTEPTQPTR/2  0.182  0.011   [2]      0   0.500
# 2                      LSYSTSQEFSSR/2  0.123  0.019   [2]      0   0.494
# 3                      DLEINAEEEPEK/2  0.152  0.022   [2]      0  -0.005
# 4                       IPILSTFLTAR/2  0.160  0.005   [2]      0   0.507
# ...                               ...    ...    ...   ...    ...     ...
# 409695        NINDVDTALSFYHMAGASLDK/2  0.071  0.041   [2]      0   0.009
# 409696             RQEEEAGALEAGEEAR/2  0.109  0.000   [2]      0  -0.009
# 409697     SYGGYEVVGGSSDSYLVPGMTYSK/2  0.097  0.001   [2]      0   0.005
# 409698  NMITQYWPDRETAPGDISPYTIPEEDR/3  0.096  0.040   [2]      0  -0.005
# 409699  ELQAQLQEQQVQVEMDMSKPDLTAALR/3  0.053  0.006   [2]      0  -0.006
#
#         #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0          13    0.060  ...      -1        0          0        ()  Normal
# 1          61    0.066  ...      -1        0          0        ()  Normal
# 2          48    0.046  ...      -1        0          0        ()  Normal
# 3          32    0.062  ...      -1        0          0        ()  Normal
# 4          19    0.080  ...      -1        0          0        ()  Normal
# ...       ...      ...  ...     ...      ...        ...       ...     ...
# 409695      5    0.031  ...      -1        0          0        ()  Normal
# 409696     36    0.046  ...      -1        0          0        ()  Normal
# 409697      6    0.065  ...      -1        0          0        ()  Normal
# 409698      4    0.064  ...      -1        0          0        ()  Normal
# 409699      6    0.045  ...      -1        0          0        ()  Normal
#
#        Inst Spec #Pr                             Proteins  LibFileOffset
# 0       Unk  Unk   1    sp|Q06330|SUH_HUMAN(pre=R,post=N)      204920315
# 1       Unk  Unk   1  sp|P20339|RAB5A_HUMAN(pre=R,post=N)       93428339
# 2       Unk  Unk   1  sp|Q5VUB5|F1711_HUMAN(pre=K,post=E)      165457641
# 3       Unk  Unk   1   sp|Q12955|ANK3_HUMAN(pre=R,post=K)       32499455
# 4       Unk  Unk   1   sp|Q9UBB6|NCDN_HUMAN(pre=K,post=G)      115380768
# ...     ...  ...  ..                                  ...            ...
# 409695  Unk  Unk   1  sp|Q9BPX6|MICU1_HUMAN(pre=K,post=V)      180981650
# 409696  Unk  Unk   1  sp|Q7Z406|MYH14_HUMAN(pre=R,post=R)      217265701
# 409697  Unk  Unk   1   sp|Q15517|CDSN_HUMAN(pre=K,post=G)      242380022
# 409698  Unk  Unk   1   sp|O95373|IPO7_HUMAN(pre=K,post=H)      183633657
# 409699  Unk  Unk   1   sp|P17661|DESM_HUMAN(pre=R,post=D)       55191415
#
# [409700 rows x 22 columns]

# %%
# sequence length
print(len(lungT))

seq1 = [] # 0~10
seq2 = [] # 11~20
seq3 = [] # 21~

for i in range(len(lungT)):
    if not i % 20000:
        print(i)
    ID = lungT.loc[i, 'ID']
    seq = ID[:-2]
    
    if len(seq) >= 0 and len(seq) <=10:
        d = lungT.loc[i, 'Dot']
        seq1.append(d)
    
    elif len(seq) >= 11 and len(seq) <= 20:
        d = lungT.loc[i, 'Dot']
        seq2.append(d)
    
    elif len(seq) >= 21:
        d = lungT.loc[i, 'Dot']
        seq3.append(d)
# Out:
# 409700
# 0
# 20000
# 40000
# 60000
# 80000
# 100000
# 120000
# 140000
# 160000
# 180000
# 200000
# 220000
# 240000
# 260000
# 280000
# 300000
# 320000
# 340000
# 360000
# 380000
# 400000

# %%
# charge state
print(len(lungT))

cs1 = [] # 2
cs2 = [] # 3
cs3 = [] # 4~

for i in range(len(lungT)):
    if not i % 30000:
        print(i)
    ID = lungT.loc[i, 'ID']
    charge = int(ID[-1])
    
    if charge == 2:
        c = lungT.loc[i, 'Dot']
        cs1.append(c)
    
    elif charge == 3:
        c = lungT.loc[i, 'Dot']
        cs2.append(c)
    
    elif charge >= 4:
        c = lungT.loc[i, 'Dot']
        cs3.append(c)
# Out:
# 409700
# 0
# 30000
# 60000
# 90000
# 120000
# 150000
# 180000
# 210000
# 240000
# 270000
# 300000
# 330000
# 360000
# 390000

# %%
# C-term
print(len(lungT))

ct1 = [] # 2
ct2 = [] # 3
ct3 = [] # 4~

for i in range(len(lungT)):
    if not i % 30000:
        print(i)
    ID = lungT.loc[i, 'ID']
    seq = ID[:-2]
    cterm = seq[-1]
    
    if cterm == 'R':
        ct = lungT.loc[i, 'Dot']
        ct1.append(ct)
    
    elif cterm == 'K':
        ct = lungT.loc[i, 'Dot']
        ct2.append(ct)
    
    else:
        ct = lungT.loc[i, 'Dot']
        ct3.append(ct)
# Out:
# 409700
# 0
# 30000
# 60000
# 90000
# 120000
# 150000
# 180000
# 210000
# 240000
# 270000
# 300000
# 330000
# 360000
# 390000

# %%
lungD1 = pd.read_excel('./dot_under_0.2/NFRP_lung_decoy_1.xlsx')
lungD1.head()
# Out:
#                                     ### Query  Rk              ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00011.00011.2   1   LISITSINDSK/2  0.173
# 1  01088_A01_P010740_S00_N01_R1.00056.00056.2   1  DAVDRDGPDLYR/2  0.132
# 2  01088_A01_P010740_S00_N01_R1.00092.00092.2   1  QNGWPDAEVDQR/2  0.159
# 3  01088_A01_P010740_S00_N01_R1.00106.00106.2   1   GPIPLLSGKIK/2  0.118
# 4  01088_A01_P010740_S00_N01_R1.00111.00111.2   1   TQLDNPALFPK/2  0.160
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.034   [2]      0  0.0051     38   0.0511  ...      -1        0
# 1  0.004   [2]      0  0.4930     44   0.0440  ...      -1        0
# 2  0.020   [2]      0  0.5050     32   0.0650  ...      -1        0
# 3  0.012   [2]      0  0.0070      3   0.0950  ...      -1        0
# 4  0.006   [2]      0  0.5060     98   0.0610  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# 1          0        ()  Normal  Unk  Unk   1
# 2          0        ()  Normal  Unk  Unk   1
# 3          0        ()  Normal  Unk  Unk   1
# 4          0        ()  Normal  Unk  Unk   1
#
#                                   Proteins  LibFileOffset
# 0   XXX_sp|Q8IWZ6|BBS7_HUMAN(pre=K,post=D)      638566818
# 1   XXX_sp|Q03395|ROM1_HUMAN(pre=R,post=I)      743802546
# 2   XXX_sp|Q9Y4U1|MMAC_HUMAN(pre=R,post=I)      601104496
# 3  XXX_sp|Q9Y548|YIPF1_HUMAN(pre=R,post=N)      471444793
# 4  XXX_sp|Q8WXF7|ATLA1_HUMAN(pre=K,post=H)      591663244
#
# [5 rows x 22 columns]

# %%
lungD2 = pd.read_excel('./dot_under_0.2/NFRP_lung_decoy_2.xlsx')
lungD2.head()
# Out:
#                                     ### Query  Rk                        ID  \
# 0  01088_E04_P010740_S00_N29_R1.51107.51107.2   1  EAISSGSESESDLNQPTYAPSK/2
# 1  01088_E04_P010740_S00_N29_R1.51108.51108.2   1       IMAQSMMELAAAGSTDR/2
# 2  01088_E04_P010740_S00_N29_R1.51117.51117.2   1              SDTNYYYDYK/2
# 3  01088_E04_P010740_S00_N29_R1.51124.51124.2   1    LGLPSEDNFHGAINTTSVSR/2
# 4  01088_E04_P010740_S00_N29_R1.51125.51125.2   1         QLTAWLHEDPSYTDR/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.093  0.010   [2]      0   0.495      4    0.069  ...      -1        0
# 1  0.103  0.002   [2]      0   0.498     18    0.046  ...      -1        0
# 2  0.101  0.071   [2]      0   0.495      2    0.066  ...      -1        0
# 3  0.146  0.021   [2]      0   0.498     27    0.053  ...      -1        0
# 4  0.163  0.019   [2]      0  -0.006     27    0.063  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# 1          0        ()  Normal  Unk  Unk   1
# 2          0        ()  Normal  Unk  Unk   1
# 3          0        ()  Normal  Unk  Unk   1
# 4          0        ()  Normal  Unk  Unk   1
#
#                                   Proteins  LibFileOffset
# 0   XXX_sp|Q15648|MED1_HUMAN(pre=K,post=S)      656241230
# 1   XXX_sp|Q8N7H5|PAF1_HUMAN(pre=K,post=G)      356272827
# 2  XXX_sp|Q13576|IQGA2_HUMAN(pre=K,post=E)      738549810
# 3  XXX_sp|Q92974|ARHG2_HUMAN(pre=K,post=R)      668932505
# 4  XXX_sp|O95395|GCNT3_HUMAN(pre=K,post=A)      356617454
#
# [5 rows x 22 columns]

# %%
lungD3 = pd.read_excel('./dot_under_0.2/NFRP_lung_decoy_3.xlsx')
lungD3.head()
# Out:
#                                     ### Query  Rk  \
# 0  01279_C03_P013163_B00_N19_R1.26489.26489.3   1
# 1  01279_C03_P013163_B00_N19_R1.26490.26490.3   1
# 2  01279_C03_P013163_B00_N19_R1.26493.26493.2   1
# 3  01279_C03_P013163_B00_N19_R1.26500.26500.4   1
# 4  01279_C03_P013163_B00_N19_R1.26502.26502.2   1
#
#                               ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0          EVYDSPPSPVDQTGASVNR/3  0.147  0.000   [2]      0  -0.001     24
# 1                 EEKASEKNESSK/3  0.163  0.022   [2]      0   0.324     25
# 2             MIELFGNYTAPDSGFK/2  0.128  0.015   [2]      0   0.496     27
# 3  AQDHNEPSFLTGPRAPPEWPGSSVTNR/4  0.131  0.022   [2]      0   0.247      3
# 4           QQQEVMQEQLESSEGDLR/2  0.097  0.031   [2]      0  -0.003      6
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.063  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 1    0.076  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 2    0.055  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 3    0.092  ...      -1        0          0        ()  Normal  Unk  Unk   1
# 4    0.046  ...      -1        0          0        ()  Normal  Unk  Unk   1
#
#                                   Proteins  LibFileOffset
# 0   XXX_sp|Q16625|OCLN_HUMAN(pre=K,post=V)      588693820
# 1  XXX_sp|Q7Z388|D19L4_HUMAN(pre=K,post=I)      662225307
# 2  XXX_sp|O75182|SIN3B_HUMAN(pre=R,post=E)      403139534
# 3  XXX_sp|Q9BV94|EDEM2_HUMAN(pre=K,post=E)      587443621
# 4  XXX_sp|Q7Z406|MYH14_HUMAN(pre=R,post=A)      517081190
#
# [5 rows x 22 columns]

# %%
print(len(lungD1))
print(len(lungD2))
print(len(lungD3))
lungD = pd.concat([lungD1, lungD2])
lungD = pd.concat([lungD, lungD3])
print(len(lungD))

lungD = lungD.reset_index(drop=True)
lungD
# Out:
# 222173
# 241703
# 243638
# 707514
#                                          ### Query  Rk  \
# 0       01088_A01_P010740_S00_N01_R1.00011.00011.2   1
# 1       01088_A01_P010740_S00_N01_R1.00056.00056.2   1
# 2       01088_A01_P010740_S00_N01_R1.00092.00092.2   1
# 3       01088_A01_P010740_S00_N01_R1.00106.00106.2   1
# 4       01088_A01_P010740_S00_N01_R1.00111.00111.2   1
# ...                                            ...  ..
# 707509  01279_H04_P013163_B00_N32_R1.56773.56773.3   1
# 707510  01279_H04_P013163_B00_N32_R1.56787.56787.3   1
# 707511  01279_H04_P013163_B00_N32_R1.56796.56796.3   1
# 707512  01279_H04_P013163_B00_N32_R1.56799.56799.3   1
# 707513  01279_H04_P013163_B00_N32_R1.56803.56803.3   1
#
#                                       ID    Dot  Delta DelRk  DBias  MzDiff  \
# 0                          LISITSINDSK/2  0.173  0.034   [2]      0  0.0051
# 1                         DAVDRDGPDLYR/2  0.132  0.004   [2]      0  0.4930
# 2                         QNGWPDAEVDQR/2  0.159  0.020   [2]      0  0.5050
# 3                          GPIPLLSGKIK/2  0.118  0.012   [2]      0  0.0070
# 4                          TQLDNPALFPK/2  0.160  0.006   [2]      0  0.5060
# ...                                  ...    ...    ...   ...    ...     ...
# 707509          TPTVGETDYTGTYVVRDGDPEK/3  0.182  0.010   [2]      0 -0.0090
# 707510  IHEFADADEVQAQPQQAPGQEAHSDTDVTK/3  0.135  0.059   [2]      0  0.0030
# 707511              TFEEIVIDESSAAEHSPR/3  0.130  0.037   [2]      0  0.3240
# 707512              DFYDMFSPRQVQPSTANK/3  0.148  0.018   [2]      0  0.3430
# 707513           DNLLEMNSQEEELEEELQAIR/3  0.095  0.001   [2]      0  0.3250
#
#         #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0          38   0.0511  ...      -1        0          0        ()  Normal
# 1          44   0.0440  ...      -1        0          0        ()  Normal
# 2          32   0.0650  ...      -1        0          0        ()  Normal
# 3           3   0.0950  ...      -1        0          0        ()  Normal
# 4          98   0.0610  ...      -1        0          0        ()  Normal
# ...       ...      ...  ...     ...      ...        ...       ...     ...
# 707509      9   0.1020  ...      -1        0          0        ()  Normal
# 707510      3   0.0870  ...      -1        0          0        ()  Normal
# 707511     17   0.0380  ...      -1        0          0        ()  Normal
# 707512     28   0.0630  ...      -1        0          0        ()  Normal
# 707513     11   0.0510  ...      -1        0          0        ()  Normal
#
#        Inst Spec #Pr                                 Proteins  LibFileOffset
# 0       Unk  Unk   1   XXX_sp|Q8IWZ6|BBS7_HUMAN(pre=K,post=D)      638566818
# 1       Unk  Unk   1   XXX_sp|Q03395|ROM1_HUMAN(pre=R,post=I)      743802546
# 2       Unk  Unk   1   XXX_sp|Q9Y4U1|MMAC_HUMAN(pre=R,post=I)      601104496
# 3       Unk  Unk   1  XXX_sp|Q9Y548|YIPF1_HUMAN(pre=R,post=N)      471444793
# 4       Unk  Unk   1  XXX_sp|Q8WXF7|ATLA1_HUMAN(pre=K,post=H)      591663244
# ...     ...  ...  ..                                      ...            ...
# 707509  Unk  Unk   1  XXX_sp|Q96F85|CNRP1_HUMAN(pre=K,post=S)      385625648
# 707510  Unk  Unk   1   XXX_sp|Q9NU22|MDN1_HUMAN(pre=R,post=Q)      695207575
# 707511  Unk  Unk   1   XXX_sp|P36575|ARRC_HUMAN(pre=K,post=K)      596162619
# 707512  Unk  Unk   1   XXX_sp|Q13188|STK3_HUMAN(pre=R,post=Q)      571657969
# 707513  Unk  Unk   1  XXX_sp|P35580|MYH10_HUMAN(pre=R,post=F)      462485438
#
# [707514 rows x 22 columns]

# %%
# sequence length
print(len(lungD))

seq4 = [] # 0~10
seq5 = [] # 11~20
seq6 = [] # 21~

for i in range(len(lungD)):
    if not i % 30000:
        print(i)
    ID = lungD.loc[i, 'ID']
    seq = ID[:-2]
    
    if len(seq) >= 0 and len(seq) <=10:
        d = lungD.loc[i, 'Dot']
        seq4.append(d)
    
    elif len(seq) >= 11 and len(seq) <= 20:
        d = lungD.loc[i, 'Dot']
        seq5.append(d)
    
    elif len(seq) >= 21:
        d = lungD.loc[i, 'Dot']
        seq6.append(d)
# Out:
# 707514
# 0
# 30000
# 60000
# 90000
# 120000
# 150000
# 180000
# 210000
# 240000
# 270000
# 300000
# 330000
# 360000
# 390000
# 420000
# 450000
# 480000
# 510000
# 540000
# 570000
# 600000
# 630000
# 660000
# 690000

# %%
# charge state
print(len(lungD))

cs4 = [] # 2
cs5 = [] # 3
cs6 = [] # 4~

for i in range(len(lungD)):
    if not i % 30000:
        print(i)
    ID = lungD.loc[i, 'ID']
    charge = int(ID[-1])
    
    if charge == 2:
        c = lungD.loc[i, 'Dot']
        cs4.append(c)
    
    elif charge == 3:
        c = lungD.loc[i, 'Dot']
        cs5.append(c)
    
    elif charge >= 4:
        c = lungD.loc[i, 'Dot']
        cs6.append(c)
# Out:
# 707514
# 0
# 30000
# 60000
# 90000
# 120000
# 150000
# 180000
# 210000
# 240000
# 270000
# 300000
# 330000
# 360000
# 390000
# 420000
# 450000
# 480000
# 510000
# 540000
# 570000
# 600000
# 630000
# 660000
# 690000

# %%
# C-term
print(len(lungD))

ct4 = [] # 2
ct5 = [] # 3
ct6 = [] # 4~

for i in range(len(lungD)):
    if not i % 30000:
        print(i)
    ID = lungD.loc[i, 'ID']
    seq = ID[:-2]
    cterm = seq[-1]
    
    if cterm == 'R':
        ct = lungD.loc[i, 'Dot']
        ct4.append(ct)
    
    elif cterm == 'K':
        ct = lungD.loc[i, 'Dot']
        ct5.append(ct)
    
    else:
        ct = lungD.loc[i, 'Dot']
        ct6.append(ct)
# Out:
# 707514
# 0
# 30000
# 60000
# 90000
# 120000
# 150000
# 180000
# 210000
# 240000
# 270000
# 300000
# 330000
# 360000
# 390000
# 420000
# 450000
# 480000
# 510000
# 540000
# 570000
# 600000
# 630000
# 660000
# 690000

# %%
seqT1 = plt.hist(seq1, bins = 50)
seqD1 = plt.hist(seq4, bins = 50)

# %%
print(seqT1[1][1] - seqT1[1][0])
print(seqD1[1][1] - seqD1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('sequence length 0~10')
plt.plot(seqT1[1][:-1] + 0.00175, seqT1[0])
plt.plot(seqD1[1][:-1] + 0.00175, seqD1[0])
plt.show()
# Out:
# 0.0035400000000000015
# 0.0035600000000000007

# %%
seqT2 = plt.hist(seq2, bins = 50)
seqD2 = plt.hist(seq5, bins = 50)

# %%
print(seqT2[1][1] - seqT2[1][0])
print(seqD2[1][1] - seqD2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('sequence length 11~20')
plt.plot(seqT2[1][:-1] + 0.00175, seqT2[0])
plt.plot(seqD2[1][:-1] + 0.00175, seqD2[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
seqT3 = plt.hist(seq3, bins = 50)
seqD3 = plt.hist(seq6, bins = 50)

# %%
print(seqT3[1][1] - seqT3[1][0])
print(seqD3[1][1] - seqD3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('sequence length 21~')
plt.plot(seqT3[1][:-1] + 0.00175, seqT3[0])
plt.plot(seqD3[1][:-1] + 0.00175, seqD3[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
csT1 = plt.hist(cs1, bins = 50)
csD1 = plt.hist(cs4, bins = 50)

# %%
print(csT1[1][1] - csT1[1][0])
print(csD1[1][1] - csD1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('charge state 2')
plt.plot(csT1[1][:-1] + 0.00175, csT1[0])
plt.plot(csD1[1][:-1] + 0.00175, csD1[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
csT2 = plt.hist(cs2, bins = 50)
csD2 = plt.hist(cs5, bins = 50)

# %%
print(csT2[1][1] - csT2[1][0])
print(csD2[1][1] - csD2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('charge state 3')
plt.plot(csT2[1][:-1] + 0.00175, csT2[0])
plt.plot(csD2[1][:-1] + 0.00175, csD2[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
csT3 = plt.hist(cs3, bins = 50)
csD3 = plt.hist(cs6, bins = 50)

# %%
print(csT3[1][1] - csT3[1][0])
print(csD3[1][1] - csD3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('charge state 4~')
plt.plot(csT3[1][:-1] + 0.00175, csT3[0])
plt.plot(csD3[1][:-1] + 0.00175, csD3[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
ctT1 = plt.hist(ct1, bins = 50)
ctD1 = plt.hist(ct4, bins = 50)

# %%
print(ctT1[1][1] - ctT1[1][0])
print(ctD1[1][1] - ctD1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('C-term R')
plt.plot(ctT1[1][:-1] + 0.00175, ctT1[0])
plt.plot(ctD1[1][:-1] + 0.00175, ctD1[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
ctT2 = plt.hist(ct2, bins = 50)
ctD2 = plt.hist(ct5, bins = 50)

# %%
print(ctT2[1][1] - ctT2[1][0])
print(ctD2[1][1] - ctD2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('C-term K')
plt.plot(ctT2[1][:-1] + 0.00175, ctT2[0])
plt.plot(ctD2[1][:-1] + 0.00175, ctD2[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007

# %%
ctT3 = plt.hist(ct3, bins = 50)
ctD3 = plt.hist(ct6, bins = 50)

# %%
print(ctT3[1][1] - ctT3[1][0])
print(ctD3[1][1] - ctD3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('C-term not R,K')
plt.plot(ctT3[1][:-1] + 0.00175, ctT3[0])
plt.plot(ctD3[1][:-1] + 0.00175, ctD3[0])
plt.show()
# Out:
# 0.0035400000000000015
# 0.0035400000000000015

# %%
t = plt.hist(lungT['Dot'], bins = 50)
d = plt.hist(lungD['Dot'], bins = 50)

# %%
print(t[1][1] - t[1][0])
print(d[1][1] - d[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('all')
plt.plot(t[1][:-1] + 0.00175, t[0])
plt.plot(d[1][:-1] + 0.00175, d[0])
plt.show()
# Out:
# 0.0035600000000000007
# 0.0035600000000000007
