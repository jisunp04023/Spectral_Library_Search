# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_target.xlsx')
NNt1_1.head()
# Out:
#                                     ### Query  Rk              ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00038.00038.2   1   QPVQVPVTLVR/2  0.138
# 1  01088_A01_P010740_S00_N01_R1.00107.00107.2   1     YLHPPTHLK/2  0.321
# 2  01088_A01_P010740_S00_N01_R1.00177.00177.2   1  GVDLTEPTQPTR/2  0.182
# 3  01088_A01_P010740_S00_N01_R1.00178.00178.2   1  LSYSTSQEFSSR/2  0.123
# 4  01088_A01_P010740_S00_N01_R1.00185.00185.2   1  DLEINAEEEPEK/2  0.152
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.024   [2]      0   0.491     13    0.060  ...      -1        0
# 1  0.052   [2]      0  -0.007     83    0.071  ...      -1        0
# 2  0.011   [2]      0   0.500     61    0.066  ...      -1        0
# 3  0.019   [2]      0   0.494     48    0.046  ...      -1        0
# 4  0.022   [2]      0  -0.005     32    0.062  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt1_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_target.xlsx')
NNt1_2.head()
# Out:
#                                     ### Query  Rk  \
# 0  01088_E04_P010740_S00_N29_R1.51102.51102.3   1
# 1  01088_E04_P010740_S00_N29_R1.51103.51103.3   1
# 2  01088_E04_P010740_S00_N29_R1.51105.51105.2   1
# 3  01088_E04_P010740_S00_N29_R1.51106.51106.3   1
# 4  01088_E04_P010740_S00_N29_R1.51114.51114.2   1
#
#                              ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  NNNIDMEVERPSNSEAHETDTAISYK/3  0.163  0.042   [2]      0   0.330      7
# 1    APARPAPDAPEDTGDSDEWVFDKK/3  0.084  0.004   [2]      0  -0.008      4
# 2            GQFAEHLLGAGFVSSR/2  0.139  0.017   [2]      0  -0.001     62
# 3     NVNIYRDSAIPVESDTDDEGAPR/3  0.111  0.016   [2]      0  -0.004     13
# 4               GWDSVQQSITMVR/2  0.301  0.039   [2]      0   0.009    114
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.079  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt1_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_target.xlsx')
NNt1_3.head()
# Out:
#                                     ### Query  Rk                 ID    Dot  \
# 0  01279_C03_P013163_B00_N19_R1.26492.26492.4   1  IKSEHPGLSIGDTAK/4  0.251
# 1  01279_C03_P013163_B00_N19_R1.26495.26495.3   1  IIYHLDGQETPYLVK/3  0.498
# 2  01279_C03_P013163_B00_N19_R1.26504.26504.2   1     FNSLNELVDYHR/2  0.759
# 3  01279_C03_P013163_B00_N19_R1.26505.26505.2   1   GFAFVTFESPADAK/2  0.173
# 4  01279_C03_P013163_B00_N19_R1.26508.26508.2   1       AEFNYSVGFK/2  0.254
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.101   [2]      0  -0.009     12    0.101  ...      -1        0
# 1  0.257   [2]      0   0.001     67    0.104  ...      -1        0
# 2  0.432   [2]      0   0.001    107    0.083  ...      -1        0
# 3  0.006   [2]      0   0.497     93    0.059  ...      -1        0
# 4  0.029   [2]      0  -0.003    104    0.072  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_decoy.xlsx')
NNd1_1.head()
# Out:
#                                     ### Query  Rk              ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00011.00011.2   1   LISITSINDSK/2  0.173
# 1  01088_A01_P010740_S00_N01_R1.00056.00056.2   1  DAVDRDGPDLYR/2  0.132
# 2  01088_A01_P010740_S00_N01_R1.00092.00092.2   1  QNGWPDAEVDQR/2  0.159
# 3  01088_A01_P010740_S00_N01_R1.00106.00106.2   1   GPIPLLSGKIK/2  0.118
# 4  01088_A01_P010740_S00_N01_R1.00111.00111.2   1   TQLDNPALFPK/2  0.160
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.034   [2]      0  0.0051     38   0.0511  ...      -1        0
# 1  0.004   [2]      0  0.4930     44   0.0440  ...      -1        0
# 2  0.020   [2]      0  0.5050     32   0.0650  ...      -1        0
# 3  0.012   [2]      0  0.0070      3   0.0950  ...      -1        0
# 4  0.006   [2]      0  0.5060     98   0.0610  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_decoy.xlsx')
NNd1_2.head()
# Out:
#                                     ### Query  Rk                        ID  \
# 0  01088_E04_P010740_S00_N29_R1.51107.51107.2   1  EAISSGSESESDLNQPTYAPSK/2
# 1  01088_E04_P010740_S00_N29_R1.51108.51108.2   1       IMAQSMMELAAAGSTDR/2
# 2  01088_E04_P010740_S00_N29_R1.51117.51117.2   1              SDTNYYYDYK/2
# 3  01088_E04_P010740_S00_N29_R1.51118.51118.2   1                LAYEAWVK/2
# 4  01088_E04_P010740_S00_N29_R1.51119.51119.3   1        VNYTDLHEQLELVGFK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.093  0.010   [2]      0   0.495      4    0.069  ...      -1        0
# 1  0.103  0.002   [2]      0   0.498     18    0.046  ...      -1        0
# 2  0.101  0.071   [2]      0   0.495      2    0.066  ...      -1        0
# 3  0.513  0.098   [2]      0  -0.007    108    0.083  ...      -1        0
# 4  0.255  0.121   [2]      0   0.009     34    0.063  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd1_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_decoy.xlsx')
NNd1_3.head()
# Out:
#                                     ### Query  Rk                     ID  \
# 0  01279_C03_P013163_B00_N19_R1.26484.26484.3   1       YSITGTHWNTWYVR/3
# 1  01279_C03_P013163_B00_N19_R1.26486.26486.3   1          ANALFEEELRR/3
# 2  01279_C03_P013163_B00_N19_R1.26489.26489.3   1  EVYDSPPSPVDQTGASVNR/3
# 3  01279_C03_P013163_B00_N19_R1.26490.26490.3   1         EEKASEKNESSK/3
# 4  01279_C03_P013163_B00_N19_R1.26493.26493.2   1     MIELFGNYTAPDSGFK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.358  0.165   [2]      0   0.009     81    0.075  ...      -1        0
# 1  0.282  0.075   [2]      0  -0.009     78    0.097  ...      -1        0
# 2  0.147  0.000   [2]      0  -0.001     24    0.063  ...      -1        0
# 3  0.163  0.022   [2]      0   0.324     25    0.076  ...      -1        0
# 4  0.128  0.015   [2]      0   0.496     27    0.055  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNt1 = list(NNt1_1['Dot']) + list(NNt1_2['Dot']) + list(NNt1_3['Dot'])
NNt1
# Out:
# [0.138,
#  0.321,
#  0.182,
#  0.123,
#  0.152,
#  0.16,
#  0.153,
#  0.137,
#  0.114,
#  0.182,
#  0.067,
#  0.163,
#  0.147,
#  0.22,
#  0.208,
#  0.202,
#  0.233,
#  0.034,
#  0.195,
#  0.022,
#  0.146,
#  0.205,
#  0.29,
#  0.187,
#  0.114,
#  0.194,
#  0.191,
#  0.254,
#  0.195,
#  0.191,
#  0.065,
#  0.185,
#  0.271,
#  0.239,
#  0.186,
#  0.166,
#  0.281,
#  0.198,
#  0.295,
#  0.16,
#  0.082,
#  0.195,
#  0.126,
#  0.227,
#  0.228,
#  0.123,
#  0.203,
#  0.171,
#  0.214,
#  0.185,
#  0.066,
#  0.315,
#  0.313,
#  0.2,
#  0.287,
#  0.228,
#  0.217,
#  0.256,
#  0.152,
#  0.195,
#  0.197,
#  0.128,
#  0.127,
#  0.304,
#  0.207,
#  0.159,
#  0.136,
#  0.11,
#  0.283,
#  0.169,
#  0.205,
#  0.172,
#  0.165,
#  0.241,
#  0.201,
#  0.196,
#  0.161,
#  0.138,
#  0.099,
#  0.22,
#  0.022,
#  0.041,
#  0.128,
#  0.145,
#  0.155,
#  0.238,
#  0.199,
#  0.209,
#  0.222,
#  0.176,
#  0.19,
#  0.14,
#  0.176,
#  0.239,
#  0.103,
#  0.199,
#  0.165,
#  0.279,
#  0.179,
#  0.166,
#  0.26,
# ...

# %%
NNd1 = list(NNd1_1['Dot']) + list(NNd1_2['Dot']) + list(NNd1_3['Dot'])
NNd1
# Out:
# [0.173,
#  0.132,
#  0.159,
#  0.118,
#  0.16,
#  0.22,
#  0.143,
#  0.321,
#  0.025,
#  0.09,
#  0.302,
#  0.188,
#  0.218,
#  0.161,
#  0.315,
#  0.1,
#  0.274,
#  0.127,
#  0.322,
#  0.138,
#  0.187,
#  0.159,
#  0.31,
#  0.1,
#  0.279,
#  0.175,
#  0.144,
#  0.273,
#  0.158,
#  0.15,
#  0.047,
#  0.272,
#  0.123,
#  0.094,
#  0.281,
#  0.187,
#  0.28,
#  0.477,
#  0.104,
#  0.053,
#  0.142,
#  0.209,
#  0.119,
#  0.295,
#  0.16,
#  0.187,
#  0.06,
#  0.189,
#  0.175,
#  0.251,
#  0.078,
#  0.07,
#  0.261,
#  0.223,
#  0.229,
#  0.129,
#  0.056,
#  0.17,
#  0.078,
#  0.299,
#  0.399,
#  0.198,
#  0.297,
#  0.196,
#  0.188,
#  0.169,
#  0.22,
#  0.259,
#  0.314,
#  0.209,
#  0.177,
#  0.187,
#  0.14,
#  0.074,
#  0.225,
#  0.301,
#  0.265,
#  0.226,
#  0.139,
#  0.268,
#  0.167,
#  0.078,
#  0.157,
#  0.137,
#  0.214,
#  0.222,
#  0.268,
#  0.188,
#  0.295,
#  0.445,
#  0.211,
#  0.04,
#  0.14,
#  0.27,
#  0.128,
#  0.065,
#  0.03,
#  0.292,
#  0.202,
#  0.102,
#  0.133,
#  0.149,
# ...

# %%
nnt1 = plt.hist(NNt1, bins = 50)
nnd1 = plt.hist(NNd1, bins = 50)

# %%
print(nnt1[1][1] - nnt1[1][0])
print(nnd1[1][1] - nnd1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + revDecoy_predicted delta > 0')
plt.plot(nnt1[1][:-1] + 0.009, nnt1[0])
plt.plot(nnd1[1][:-1] + 0.007, nnd1[0])
plt.show()
# Out:
# 0.018400000000000003
# 0.014659999999999996

# %%
NNt2_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_target_0.01.xlsx')
NNt2_1.head()
# Out:
#                                     ### Query  Rk              ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00038.00038.2   1   QPVQVPVTLVR/2  0.138
# 1  01088_A01_P010740_S00_N01_R1.00107.00107.2   1     YLHPPTHLK/2  0.321
# 2  01088_A01_P010740_S00_N01_R1.00177.00177.2   1  GVDLTEPTQPTR/2  0.182
# 3  01088_A01_P010740_S00_N01_R1.00178.00178.2   1  LSYSTSQEFSSR/2  0.123
# 4  01088_A01_P010740_S00_N01_R1.00185.00185.2   1  DLEINAEEEPEK/2  0.152
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.024   [2]      0   0.491     13    0.060  ...      -1        0
# 1  0.052   [2]      0  -0.007     83    0.071  ...      -1        0
# 2  0.011   [2]      0   0.500     61    0.066  ...      -1        0
# 3  0.019   [2]      0   0.494     48    0.046  ...      -1        0
# 4  0.022   [2]      0  -0.005     32    0.062  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt2_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_target_0.01.xlsx')
NNt2_2.head()
# Out:
#                                     ### Query  Rk  \
# 0  01088_E04_P010740_S00_N29_R1.51102.51102.3   1
# 1  01088_E04_P010740_S00_N29_R1.51105.51105.2   1
# 2  01088_E04_P010740_S00_N29_R1.51106.51106.3   1
# 3  01088_E04_P010740_S00_N29_R1.51114.51114.2   1
# 4  01088_E04_P010740_S00_N29_R1.51115.51115.2   1
#
#                              ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  NNNIDMEVERPSNSEAHETDTAISYK/3  0.163  0.042   [2]      0   0.330      7
# 1            GQFAEHLLGAGFVSSR/2  0.139  0.017   [2]      0  -0.001     62
# 2     NVNIYRDSAIPVESDTDDEGAPR/3  0.111  0.016   [2]      0  -0.004     13
# 3               GWDSVQQSITMVR/2  0.301  0.039   [2]      0   0.009    114
# 4                 ALNIEMLPGYR/2  0.251  0.033   [2]      0   0.005    100
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.079  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt2_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_target_0.01.xlsx')
NNt2_3.head()
# Out:
#                                     ### Query  Rk                     ID  \
# 0  01279_C03_P013163_B00_N19_R1.26492.26492.4   1      IKSEHPGLSIGDTAK/4
# 1  01279_C03_P013163_B00_N19_R1.26495.26495.3   1      IIYHLDGQETPYLVK/3
# 2  01279_C03_P013163_B00_N19_R1.26504.26504.2   1         FNSLNELVDYHR/2
# 3  01279_C03_P013163_B00_N19_R1.26508.26508.2   1           AEFNYSVGFK/2
# 4  01279_C03_P013163_B00_N19_R1.26510.26510.2   1  DPGGHYTLQEVEEGLAQHK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.251  0.101   [2]      0  -0.009     12    0.101  ...      -1        0
# 1  0.498  0.257   [2]      0   0.001     67    0.104  ...      -1        0
# 2  0.759  0.432   [2]      0   0.001    107    0.083  ...      -1        0
# 3  0.254  0.029   [2]      0  -0.003    104    0.072  ...      -1        0
# 4  0.142  0.016   [2]      0   0.493     19    0.059  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd2_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_decoy_0.01.xlsx')
NNd2_1.head()
# Out:
#                                     ### Query  Rk              ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00011.00011.2   1   LISITSINDSK/2  0.173
# 1  01088_A01_P010740_S00_N01_R1.00092.00092.2   1  QNGWPDAEVDQR/2  0.159
# 2  01088_A01_P010740_S00_N01_R1.00106.00106.2   1   GPIPLLSGKIK/2  0.118
# 3  01088_A01_P010740_S00_N01_R1.00115.00115.2   1   GYLEPGVVGRR/2  0.220
# 4  01088_A01_P010740_S00_N01_R1.00151.00151.2   1    TQQLDPIGVK/2  0.321
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.034   [2]      0  0.0051     38   0.0511  ...      -1        0
# 1  0.020   [2]      0  0.5050     32   0.0650  ...      -1        0
# 2  0.012   [2]      0  0.0070      3   0.0950  ...      -1        0
# 3  0.040   [2]      0 -0.0090     84   0.0480  ...      -1        0
# 4  0.099   [2]      0  0.5060    109   0.0820  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd2_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_decoy_0.01.xlsx')
NNd2_2.head()
# Out:
#                                     ### Query  Rk                      ID  \
# 0  01088_E04_P010740_S00_N29_R1.51117.51117.2   1            SDTNYYYDYK/2
# 1  01088_E04_P010740_S00_N29_R1.51118.51118.2   1              LAYEAWVK/2
# 2  01088_E04_P010740_S00_N29_R1.51119.51119.3   1      VNYTDLHEQLELVGFK/3
# 3  01088_E04_P010740_S00_N29_R1.51124.51124.2   1  LGLPSEDNFHGAINTTSVSR/2
# 4  01088_E04_P010740_S00_N29_R1.51125.51125.2   1       QLTAWLHEDPSYTDR/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.101  0.071   [2]      0   0.495      2    0.066  ...      -1        0
# 1  0.513  0.098   [2]      0  -0.007    108    0.083  ...      -1        0
# 2  0.255  0.121   [2]      0   0.009     34    0.063  ...      -1        0
# 3  0.146  0.021   [2]      0   0.498     27    0.053  ...      -1        0
# 4  0.163  0.019   [2]      0  -0.006     27    0.063  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd2_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_decoy_0.01.xlsx')
NNd2_3.head()
# Out:
#                                     ### Query  Rk                  ID    Dot  \
# 0  01279_C03_P013163_B00_N19_R1.26484.26484.3   1    YSITGTHWNTWYVR/3  0.358
# 1  01279_C03_P013163_B00_N19_R1.26486.26486.3   1       ANALFEEELRR/3  0.282
# 2  01279_C03_P013163_B00_N19_R1.26490.26490.3   1      EEKASEKNESSK/3  0.163
# 3  01279_C03_P013163_B00_N19_R1.26493.26493.2   1  MIELFGNYTAPDSGFK/2  0.128
# 4  01279_C03_P013163_B00_N19_R1.26496.26496.3   1        FVDEVNERFR/3  0.364
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.165   [2]      0   0.009     81    0.075  ...      -1        0
# 1  0.075   [2]      0  -0.009     78    0.097  ...      -1        0
# 2  0.022   [2]      0   0.324     25    0.076  ...      -1        0
# 3  0.015   [2]      0   0.496     27    0.055  ...      -1        0
# 4  0.064   [2]      0   0.333     68    0.094  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNt2 = list(NNt2_1['Dot']) + list(NNt2_2['Dot']) + list(NNt2_3['Dot'])
NNt2
# Out:
# [0.138,
#  0.321,
#  0.182,
#  0.123,
#  0.152,
#  0.137,
#  0.182,
#  0.067,
#  0.163,
#  0.147,
#  0.22,
#  0.208,
#  0.202,
#  0.034,
#  0.195,
#  0.022,
#  0.205,
#  0.29,
#  0.114,
#  0.194,
#  0.191,
#  0.254,
#  0.195,
#  0.191,
#  0.065,
#  0.185,
#  0.271,
#  0.239,
#  0.186,
#  0.166,
#  0.281,
#  0.198,
#  0.16,
#  0.082,
#  0.195,
#  0.126,
#  0.227,
#  0.228,
#  0.123,
#  0.203,
#  0.171,
#  0.185,
#  0.315,
#  0.313,
#  0.2,
#  0.287,
#  0.228,
#  0.217,
#  0.256,
#  0.152,
#  0.195,
#  0.197,
#  0.127,
#  0.207,
#  0.136,
#  0.283,
#  0.205,
#  0.165,
#  0.241,
#  0.201,
#  0.196,
#  0.138,
#  0.099,
#  0.22,
#  0.128,
#  0.145,
#  0.238,
#  0.199,
#  0.209,
#  0.222,
#  0.176,
#  0.19,
#  0.14,
#  0.176,
#  0.239,
#  0.199,
#  0.165,
#  0.279,
#  0.179,
#  0.166,
#  0.26,
#  0.12,
#  0.11,
#  0.158,
#  0.202,
#  0.181,
#  0.234,
#  0.3,
#  0.155,
#  0.133,
#  0.11,
#  0.172,
#  0.181,
#  0.164,
#  0.122,
#  0.137,
#  0.207,
#  0.231,
#  0.271,
#  0.312,
#  0.245,
# ...

# %%
NNd2 = list(NNd2_1['Dot']) + list(NNd2_2['Dot']) + list(NNd2_3['Dot'])
NNd2
# Out:
# [0.173,
#  0.159,
#  0.118,
#  0.22,
#  0.321,
#  0.09,
#  0.302,
#  0.188,
#  0.218,
#  0.161,
#  0.315,
#  0.1,
#  0.127,
#  0.322,
#  0.138,
#  0.187,
#  0.31,
#  0.1,
#  0.279,
#  0.175,
#  0.144,
#  0.15,
#  0.047,
#  0.272,
#  0.123,
#  0.094,
#  0.281,
#  0.28,
#  0.477,
#  0.142,
#  0.209,
#  0.119,
#  0.295,
#  0.16,
#  0.187,
#  0.175,
#  0.251,
#  0.078,
#  0.07,
#  0.261,
#  0.223,
#  0.129,
#  0.056,
#  0.17,
#  0.078,
#  0.399,
#  0.196,
#  0.188,
#  0.169,
#  0.22,
#  0.259,
#  0.314,
#  0.209,
#  0.177,
#  0.074,
#  0.225,
#  0.265,
#  0.226,
#  0.268,
#  0.167,
#  0.078,
#  0.157,
#  0.137,
#  0.214,
#  0.222,
#  0.268,
#  0.188,
#  0.295,
#  0.445,
#  0.211,
#  0.04,
#  0.14,
#  0.27,
#  0.128,
#  0.065,
#  0.03,
#  0.292,
#  0.202,
#  0.102,
#  0.149,
#  0.195,
#  0.117,
#  0.32,
#  0.117,
#  0.109,
#  0.155,
#  0.238,
#  0.257,
#  0.189,
#  0.381,
#  0.053,
#  0.088,
#  0.3,
#  0.203,
#  0.152,
#  0.216,
#  0.282,
#  0.14,
#  0.201,
#  0.269,
#  0.096,
#  0.134,
# ...

# %%
nnt2 = plt.hist(NNt2, bins = 50)
nnd2 = plt.hist(NNd2, bins = 50)

# %%
print(nnt2[1][1] - nnt2[1][0])
print(nnd2[1][1] - nnd2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + revDecoy_predicted delta > 0.01')
plt.plot(nnt2[1][:-1] + 0.009, nnt2[0])
plt.plot(nnd2[1][:-1] + 0.007, nnd2[0])
plt.show()
# Out:
# 0.018400000000000003
# 0.014659999999999996

# %%
NNt3_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_target_0.05.xlsx')
NNt3_1.head()
# Out:
#                                     ### Query  Rk               ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00107.00107.2   1      YLHPPTHLK/2  0.321
# 1  01088_A01_P010740_S00_N01_R1.00284.00284.2   1  AVIGIGIEEEDRK/2  0.182
# 2  01088_A01_P010740_S00_N01_R1.00385.00385.2   1  QDMGEEAEEEPQK/2  0.067
# 3  01088_A01_P010740_S00_N01_R1.00416.00416.2   1    VQPLPISTIIR/2  0.163
# 4  01088_A01_P010740_S00_N01_R1.00517.00517.2   1     VVLPTFILEK/2  0.147
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.052   [2]      0  -0.007     83    0.071  ...      -1        0
# 1  0.065   [2]      0  -0.002     51    0.047  ...      -1        0
# 2  0.067   [2]      0   0.498      1    0.067  ...      -1        0
# 3  0.140   [2]      0   0.010      5    0.048  ...      -1        0
# 4  0.073   [2]      0   0.002      6    0.066  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt3_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_target_0.05.xlsx')
NNt3_2.head()
# Out:
#                                     ### Query  Rk  \
# 0  01088_E04_P010740_S00_N29_R1.51116.51116.3   1
# 1  01088_E04_P010740_S00_N29_R1.51120.51120.2   1
# 2  01088_E04_P010740_S00_N29_R1.51131.51131.2   1
# 3  01088_E04_P010740_S00_N29_R1.51134.51134.2   1
# 4  01088_E04_P010740_S00_N29_R1.51144.51144.4   1
#
#                              ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0            YPIEHGIITNWDDMEK/3  0.434  0.240   [2]      0   0.334     30
# 1                 TLEEDEEELFK/2  0.597  0.253   [2]      0   0.002     54
# 2         VDTDGNGYISFNELNDLFK/2  0.773  0.610   [2]      0   0.496     13
# 3           AEDGSVIDYELIDQDAR/2  0.819  0.672   [2]      0   0.003     20
# 4  SMGGKEDLIWELLNQAQEHFGKDKSK/4  0.221  0.086   [2]      0  -0.003      6
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.082  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt3_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_target_0.05.xlsx')
NNt3_3.head()
# Out:
#                                     ### Query  Rk                      ID  \
# 0  01279_C03_P013163_B00_N19_R1.26492.26492.4   1       IKSEHPGLSIGDTAK/4
# 1  01279_C03_P013163_B00_N19_R1.26495.26495.3   1       IIYHLDGQETPYLVK/3
# 2  01279_C03_P013163_B00_N19_R1.26504.26504.2   1          FNSLNELVDYHR/2
# 3  01279_C03_P013163_B00_N19_R1.26513.26513.2   1  LDMVEDTEGEPPFLPESFDR/2
# 4  01279_C03_P013163_B00_N19_R1.26515.26515.3   1    VTSEELHYFVQNHFTSAR/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.251  0.101   [2]      0  -0.009     12    0.101  ...      -1        0
# 1  0.498  0.257   [2]      0   0.001     67    0.104  ...      -1        0
# 2  0.759  0.432   [2]      0   0.001    107    0.083  ...      -1        0
# 3  0.128  0.085   [2]      0   0.002      3    0.070  ...      -1        0
# 4  0.494  0.214   [2]      0   0.336     36    0.086  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd3_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_decoy_0.05.xlsx')
NNd3_1.head()
# Out:
#                                     ### Query  Rk               ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00151.00151.2   1     TQQLDPIGVK/2  0.321
# 1  01088_A01_P010740_S00_N01_R1.00488.00488.2   1  VESISSVQSSVVK/2  0.322
# 2  01088_A01_P010740_S00_N01_R1.00510.00510.2   1    EVSFNLLFPAR/2  0.310
# 3  01088_A01_P010740_S00_N01_R1.00632.00632.2   1    GPIPLLSGKIK/2  0.144
# 4  01088_A01_P010740_S00_N01_R1.00964.00964.2   1     ELIFTPLVVK/2  0.280
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.099   [2]      0   0.506    109    0.082  ...      -1        0
# 1  0.140   [2]      0   0.004     80    0.063  ...      -1        0
# 2  0.102   [2]      0  -0.006     66    0.056  ...      -1        0
# 3  0.097   [2]      0   0.004      3    0.075  ...      -1        0
# 4  0.192   [2]      0   0.004      7    0.083  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd3_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_decoy_0.05.xlsx')
NNd3_2.head()
# Out:
#                                     ### Query  Rk                          ID  \
# 0  01088_E04_P010740_S00_N29_R1.51117.51117.2   1                SDTNYYYDYK/2
# 1  01088_E04_P010740_S00_N29_R1.51118.51118.2   1                  LAYEAWVK/2
# 2  01088_E04_P010740_S00_N29_R1.51119.51119.3   1          VNYTDLHEQLELVGFK/3
# 3  01088_E04_P010740_S00_N29_R1.51148.51148.3   1   WQPGPMTLPYDGSDEDFEETMKK/3
# 4  01088_E04_P010740_S00_N29_R1.51155.51155.3   1  FLSQHLDWDADWMDEQMAVGPQVK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.101  0.071   [2]      0   0.495      2    0.066  ...      -1        0
# 1  0.513  0.098   [2]      0  -0.007    108    0.083  ...      -1        0
# 2  0.255  0.121   [2]      0   0.009     34    0.063  ...      -1        0
# 3  0.090  0.056   [2]      0   0.337      5    0.037  ...      -1        0
# 4  0.143  0.064   [2]      0   0.333      3    0.083  ...      -1        0
#
# ...

# %%
NNd3_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_decoy_0.05.xlsx')
NNd3_3.head()
# Out:
#                                     ### Query  Rk                  ID    Dot  \
# 0  01279_C03_P013163_B00_N19_R1.26484.26484.3   1    YSITGTHWNTWYVR/3  0.358
# 1  01279_C03_P013163_B00_N19_R1.26486.26486.3   1       ANALFEEELRR/3  0.282
# 2  01279_C03_P013163_B00_N19_R1.26496.26496.3   1        FVDEVNERFR/3  0.364
# 3  01279_C03_P013163_B00_N19_R1.26497.26497.3   1   EIFDQLLDDGLDDKK/3  0.322
# 4  01279_C03_P013163_B00_N19_R1.26503.26503.2   1  LLVSTGDDVEFEGYDK/2  0.228
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.165   [2]      0   0.009     81    0.075  ...      -1        0
# 1  0.075   [2]      0  -0.009     78    0.097  ...      -1        0
# 2  0.064   [2]      0   0.333     68    0.094  ...      -1        0
# 3  0.068   [2]      0   0.337     79    0.093  ...      -1        0
# 4  0.071   [2]      0   0.502     52    0.068  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNt3 = list(NNt3_1['Dot']) + list(NNt3_2['Dot']) + list(NNt3_3['Dot'])
NNt3
# Out:
# [0.321,
#  0.182,
#  0.067,
#  0.163,
#  0.147,
#  0.202,
#  0.195,
#  0.29,
#  0.114,
#  0.194,
#  0.191,
#  0.195,
#  0.065,
#  0.185,
#  0.271,
#  0.186,
#  0.198,
#  0.16,
#  0.315,
#  0.228,
#  0.256,
#  0.152,
#  0.207,
#  0.241,
#  0.138,
#  0.22,
#  0.128,
#  0.199,
#  0.209,
#  0.222,
#  0.176,
#  0.19,
#  0.239,
#  0.279,
#  0.179,
#  0.26,
#  0.202,
#  0.181,
#  0.3,
#  0.207,
#  0.271,
#  0.312,
#  0.239,
#  0.206,
#  0.244,
#  0.259,
#  0.29,
#  0.231,
#  0.233,
#  0.2,
#  0.411,
#  0.244,
#  0.292,
#  0.176,
#  0.117,
#  0.244,
#  0.28,
#  0.178,
#  0.311,
#  0.276,
#  0.197,
#  0.311,
#  0.224,
#  0.269,
#  0.294,
#  0.257,
#  0.25,
#  0.22,
#  0.3,
#  0.186,
#  0.274,
#  0.203,
#  0.159,
#  0.255,
#  0.261,
#  0.289,
#  0.251,
#  0.179,
#  0.266,
#  0.219,
#  0.082,
#  0.251,
#  0.191,
#  0.284,
#  0.232,
#  0.156,
#  0.321,
#  0.292,
#  0.14,
#  0.255,
#  0.406,
#  0.343,
#  0.28,
#  0.382,
#  0.312,
#  0.191,
#  0.369,
#  0.457,
#  0.182,
#  0.237,
#  0.22,
# ...

# %%
NNd3 = list(NNd3_1['Dot']) + list(NNd3_2['Dot']) + list(NNd3_3['Dot'])
NNd3
# Out:
# [0.321,
#  0.322,
#  0.31,
#  0.144,
#  0.28,
#  0.477,
#  0.142,
#  0.209,
#  0.187,
#  0.399,
#  0.188,
#  0.169,
#  0.259,
#  0.225,
#  0.265,
#  0.167,
#  0.137,
#  0.214,
#  0.222,
#  0.445,
#  0.211,
#  0.27,
#  0.128,
#  0.292,
#  0.195,
#  0.32,
#  0.117,
#  0.257,
#  0.381,
#  0.14,
#  0.226,
#  0.174,
#  0.197,
#  0.073,
#  0.117,
#  0.214,
#  0.188,
#  0.358,
#  0.179,
#  0.076,
#  0.271,
#  0.197,
#  0.23,
#  0.167,
#  0.189,
#  0.275,
#  0.162,
#  0.258,
#  0.498,
#  0.198,
#  0.431,
#  0.237,
#  0.42,
#  0.211,
#  0.256,
#  0.201,
#  0.164,
#  0.398,
#  0.193,
#  0.224,
#  0.225,
#  0.171,
#  0.227,
#  0.244,
#  0.145,
#  0.221,
#  0.155,
#  0.264,
#  0.182,
#  0.126,
#  0.219,
#  0.181,
#  0.158,
#  0.345,
#  0.205,
#  0.241,
#  0.278,
#  0.243,
#  0.249,
#  0.376,
#  0.132,
#  0.294,
#  0.09,
#  0.125,
#  0.252,
#  0.196,
#  0.162,
#  0.274,
#  0.088,
#  0.143,
#  0.342,
#  0.178,
#  0.149,
#  0.438,
#  0.459,
#  0.229,
#  0.328,
#  0.398,
#  0.22,
#  0.155,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + revDecoy_predicted delta > 0.05')
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.show()
# Out:
# 0.017800000000000003
# 0.014059999999999996

# %%
NNt4_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_target_0.1.xlsx')
NNt4_1.head()
# Out:
#                                     ### Query  Rk               ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00416.00416.2   1    VQPLPISTIIR/2  0.163
# 1  01088_A01_P010740_S00_N01_R1.01000.01000.2   1     FPVLVIEPTK/2  0.290
# 2  01088_A01_P010740_S00_N01_R1.01070.01070.2   1  GGDAFGDTSFLSR/2  0.195
# 3  01088_A01_P010740_S00_N01_R1.01133.01133.2   1    DLEEELDMKDR/2  0.271
# 4  01088_A01_P010740_S00_N01_R1.01365.01365.2   1    KAATALKDVVK/2  0.198
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.140   [2]      0   0.010      5    0.048  ...      -1        0
# 1  0.133   [2]      0   0.501     41    0.071  ...      -1        0
# 2  0.102   [2]      0  -0.006     20    0.043  ...      -1        0
# 3  0.134   [2]      0   0.003     37    0.059  ...      -1        0
# 4  0.101   [2]      0   0.500     10    0.079  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt4_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_target_0.1.xlsx')
NNt4_2.head()
# Out:
#                                     ### Query  Rk                     ID  \
# 0  01088_E04_P010740_S00_N29_R1.51116.51116.3   1     YPIEHGIITNWDDMEK/3
# 1  01088_E04_P010740_S00_N29_R1.51120.51120.2   1          TLEEDEEELFK/2
# 2  01088_E04_P010740_S00_N29_R1.51131.51131.2   1  VDTDGNGYISFNELNDLFK/2
# 3  01088_E04_P010740_S00_N29_R1.51134.51134.2   1    AEDGSVIDYELIDQDAR/2
# 4  01088_E04_P010740_S00_N29_R1.51167.51167.2   1   SDLEMQYETLQEELMALK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.434  0.240   [2]      0   0.334     30    0.082  ...      -1        0
# 1  0.597  0.253   [2]      0   0.002     54    0.093  ...      -1        0
# 2  0.773  0.610   [2]      0   0.496     13    0.119  ...      -1        0
# 3  0.819  0.672   [2]      0   0.003     20    0.110  ...      -1        0
# 4  0.474  0.306   [2]      0   0.499     17    0.080  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNt4_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_target_0.1.xlsx')
NNt4_3.head()
# Out:
#                                     ### Query  Rk                    ID  \
# 0  01279_C03_P013163_B00_N19_R1.26492.26492.4   1     IKSEHPGLSIGDTAK/4
# 1  01279_C03_P013163_B00_N19_R1.26495.26495.3   1     IIYHLDGQETPYLVK/3
# 2  01279_C03_P013163_B00_N19_R1.26504.26504.2   1        FNSLNELVDYHR/2
# 3  01279_C03_P013163_B00_N19_R1.26515.26515.3   1  VTSEELHYFVQNHFTSAR/3
# 4  01279_C03_P013163_B00_N19_R1.26521.26521.2   1   AVDTDGVEPMESVLEDR/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.251  0.101   [2]      0  -0.009     12    0.101  ...      -1        0
# 1  0.498  0.257   [2]      0   0.001     67    0.104  ...      -1        0
# 2  0.759  0.432   [2]      0   0.001    107    0.083  ...      -1        0
# 3  0.494  0.214   [2]      0   0.336     36    0.086  ...      -1        0
# 4  0.306  0.132   [2]      0   0.010     27    0.074  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd4_1 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_1_decoy_0.1.xlsx')
NNd4_1.head()
# Out:
#                                     ### Query  Rk               ID    Dot  \
# 0  01088_A01_P010740_S00_N01_R1.00488.00488.2   1  VESISSVQSSVVK/2  0.322
# 1  01088_A01_P010740_S00_N01_R1.00510.00510.2   1    EVSFNLLFPAR/2  0.310
# 2  01088_A01_P010740_S00_N01_R1.00964.00964.2   1     ELIFTPLVVK/2  0.280
# 3  01088_A01_P010740_S00_N01_R1.00996.00996.2   1     VGPQFVPLNK/2  0.477
# 4  01088_A01_P010740_S00_N01_R1.01064.01064.2   1     LLLLHLLATR/2  0.142
#
#    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.140   [2]      0   0.004     80    0.063  ...      -1        0
# 1  0.102   [2]      0  -0.006     66    0.056  ...      -1        0
# 2  0.192   [2]      0   0.004      7    0.083  ...      -1        0
# 3  0.101   [2]      0   0.499     89    0.089  ...      -1        0
# 4  0.126   [2]      0  -0.010      2    0.080  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd4_2 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_2_decoy_0.1.xlsx')
NNd4_2.head()
# Out:
#                                     ### Query  Rk                        ID  \
# 0  01088_E04_P010740_S00_N29_R1.51119.51119.3   1        VNYTDLHEQLELVGFK/3
# 1  01088_E04_P010740_S00_N29_R1.51208.51208.2   1            GIPLPMATYLNR/2
# 2  01088_E04_P010740_S00_N29_R1.51234.51234.2   1           MPQSIVSLPVTIK/2
# 3  01088_E04_P010740_S00_N29_R1.51273.51273.3   1  TPTVGETDYTGTYVVRDGDPEK/3
# 4  01088_E04_P010740_S00_N29_R1.51283.51283.3   1  LSVPQGSAPQALPQEQNLINYK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.255  0.121   [2]      0   0.009     34    0.063  ...      -1        0
# 1  0.349  0.142   [2]      0  -0.004    126    0.061  ...      -1        0
# 2  0.403  0.103   [2]      0   0.002     47    0.126  ...      -1        0
# 3  0.252  0.144   [2]      0  -0.002     11    0.073  ...      -1        0
# 4  0.281  0.122   [2]      0  -0.004     27    0.084  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd4_3 = pd.read_excel('./delta_cutoff/lung/NFRP(0.01Th)_3_decoy_0.1.xlsx')
NNd4_3.head()
# Out:
#                                     ### Query  Rk                    ID  \
# 0  01279_C03_P013163_B00_N19_R1.26484.26484.3   1      YSITGTHWNTWYVR/3
# 1  01279_C03_P013163_B00_N19_R1.26509.26509.2   1            FVSGAGKR/2
# 2  01279_C03_P013163_B00_N19_R1.26528.26528.2   1  PYGPELSAEDFVWHKDGK/2
# 3  01279_C03_P013163_B00_N19_R1.26627.26627.2   1            GYGTIGFK/2
# 4  01279_C03_P013163_B00_N19_R1.26628.26628.2   1             YVYSFTR/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.358  0.165   [2]      0   0.009     81    0.075  ...      -1        0
# 1  0.405  0.159   [2]      0  -0.003     49    0.100  ...      -1        0
# 2  0.245  0.105   [2]      0   0.492     24    0.062  ...      -1        0
# 3  0.327  0.127   [2]      0   0.001     51    0.084  ...      -1        0
# 4  0.356  0.148   [2]      0  -0.005     83    0.082  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNt4 = list(NNt4_1['Dot']) + list(NNt4_2['Dot']) + list(NNt4_3['Dot'])
NNt4
# Out:
# [0.163,
#  0.29,
#  0.195,
#  0.271,
#  0.198,
#  0.315,
#  0.241,
#  0.138,
#  0.209,
#  0.239,
#  0.279,
#  0.26,
#  0.202,
#  0.3,
#  0.244,
#  0.29,
#  0.411,
#  0.244,
#  0.244,
#  0.28,
#  0.311,
#  0.197,
#  0.294,
#  0.257,
#  0.25,
#  0.22,
#  0.274,
#  0.203,
#  0.261,
#  0.289,
#  0.266,
#  0.232,
#  0.406,
#  0.343,
#  0.28,
#  0.457,
#  0.22,
#  0.319,
#  0.381,
#  0.516,
#  0.271,
#  0.609,
#  0.604,
#  0.668,
#  0.442,
#  0.709,
#  0.419,
#  0.441,
#  0.276,
#  0.567,
#  0.778,
#  0.38,
#  0.643,
#  0.796,
#  0.582,
#  0.516,
#  0.811,
#  0.821,
#  0.499,
#  0.822,
#  0.859,
#  0.618,
#  0.831,
#  0.518,
#  0.812,
#  0.47,
#  0.608,
#  0.538,
#  0.81,
#  0.17,
#  0.309,
#  0.483,
#  0.772,
#  0.277,
#  0.604,
#  0.551,
#  0.784,
#  0.308,
#  0.767,
#  0.497,
#  0.198,
#  0.304,
#  0.233,
#  0.715,
#  0.416,
#  0.667,
#  0.522,
#  0.703,
#  0.482,
#  0.559,
#  0.335,
#  0.495,
#  0.223,
#  0.316,
#  0.688,
#  0.407,
#  0.552,
#  0.694,
#  0.685,
#  0.245,
#  0.412,
# ...

# %%
NNd4 = list(NNd4_1['Dot']) + list(NNd4_2['Dot']) + list(NNd4_3['Dot'])
NNd4
# Out:
# [0.322,
#  0.31,
#  0.28,
#  0.477,
#  0.142,
#  0.399,
#  0.214,
#  0.445,
#  0.211,
#  0.292,
#  0.381,
#  0.174,
#  0.214,
#  0.188,
#  0.271,
#  0.189,
#  0.258,
#  0.498,
#  0.198,
#  0.211,
#  0.145,
#  0.264,
#  0.219,
#  0.158,
#  0.345,
#  0.376,
#  0.294,
#  0.274,
#  0.143,
#  0.149,
#  0.438,
#  0.229,
#  0.301,
#  0.229,
#  0.169,
#  0.155,
#  0.251,
#  0.382,
#  0.145,
#  0.237,
#  0.197,
#  0.169,
#  0.182,
#  0.32,
#  0.122,
#  0.22,
#  0.243,
#  0.242,
#  0.274,
#  0.304,
#  0.295,
#  0.275,
#  0.314,
#  0.175,
#  0.272,
#  0.371,
#  0.132,
#  0.113,
#  0.111,
#  0.152,
#  0.17,
#  0.191,
#  0.157,
#  0.208,
#  0.171,
#  0.164,
#  0.288,
#  0.356,
#  0.485,
#  0.253,
#  0.401,
#  0.392,
#  0.24,
#  0.248,
#  0.163,
#  0.39,
#  0.149,
#  0.302,
#  0.259,
#  0.229,
#  0.252,
#  0.221,
#  0.345,
#  0.285,
#  0.378,
#  0.223,
#  0.4,
#  0.13,
#  0.312,
#  0.294,
#  0.213,
#  0.155,
#  0.268,
#  0.112,
#  0.406,
#  0.4,
#  0.218,
#  0.303,
#  0.216,
#  0.229,
#  0.225,
# ...

# %%
nnt4 = plt.hist(NNt4, bins = 50)
nnd4 = plt.hist(NNd4, bins = 50)

# %%
print(nnt4[1][1] - nnt4[1][0])
print(nnd4[1][1] - nnd4[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + revDecoy_predicted delta > 0.1')
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()
# Out:
# 0.016799999999999995
# 0.013060000000000002

# %%
print(len(NNt1))
print(len(NNd1))

print(len(NNt2))
print(len(NNd2))

print(len(NNt3))
print(len(NNd3))

print(len(NNt4))
print(len(NNd4))
# Out:
# 1284751
# 1298320
# 1109824
# 1017781
# 712124
# 392052
# 522868
# 111190

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt1:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd1:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.5190000000000003
nnt:  322103
nnd:  3218
FDR:  0.009990593071160467
"""
# Out:
# score:  0.001
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.002
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.003
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.004
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.005
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.006
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.007
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.008
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.009000000000000001
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.010000000000000002
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.011000000000000003
# nnt:  1284751
# nnd:  1298320
# FDR:  1.0105615796368324
#
#
# score:  0.012000000000000004
# nnt:  1284751
# nnd:  1298320
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt2:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd2:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.5170000000000003
nnt:  323973
nnd:  3189
FDR:  0.00984341287699901
"""
# Out:
# score:  0.001
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.002
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.003
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.004
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.005
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.006
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.007
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.008
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.009000000000000001
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.010000000000000002
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.011000000000000003
# nnt:  1109824
# nnd:  1017781
# FDR:  0.9170652283605328
#
#
# score:  0.012000000000000004
# nnt:  1109824
# nnd:  1017781
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.5080000000000003
nnt:  332184
nnd:  3303
FDR:  0.009943284444765551
"""
# Out:
# score:  0.001
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.002
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.003
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.004
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.005
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.006
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.007
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.008
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.009000000000000001
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.010000000000000002
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.011000000000000003
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# score:  0.012000000000000004
# nnt:  712124
# nnd:  392052
# FDR:  0.5505389510815533
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt4:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd4:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.4940000000000004
nnt:  343312
nnd:  3408
FDR:  0.009926830404996038
"""
# Out:
# score:  0.001
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.002
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.003
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.004
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.005
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.006
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.007
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.008
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.009000000000000001
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.010000000000000002
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.011000000000000003
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# score:  0.012000000000000004
# nnt:  522868
# nnd:  111190
# FDR:  0.21265405417810995
#
#
# ...
