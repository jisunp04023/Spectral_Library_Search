# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
one = pd.read_excel('three.xlsx')
one.head()
# Out:
#                                            ### Query  Rk               ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1        HSGPFQR/2
# 1  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  PRHNGFEGPALVK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01913.01913.2   1      PWDDLDLSR/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1  PERGTSLAHLEMR/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1   EERLNETDIHLK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.231  0.089   [2]      0   0.004     30    0.064  ...      -1        0
# 1  0.168  0.043   [2]      0  -0.002      5    0.103  ...      -1        0
# 2  0.184  0.022   [2]      0   0.495     48    0.056  ...      -1        0
# 3  0.381  0.182   [2]      0   0.003     12    0.098  ...      -1        0
# 4  0.277  0.074   [2]      0   0.001     97    0.074  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
Proteins = one['Proteins']
for i in range(1000):
    print(Proteins[i])
# Out:
# XXX_sp|Q15006|EMC2_HUMAN(pre=R,post=V)
# XXX_sp|Q9NSY1|BMP2K_HUMAN(pre=K,post=G)
# XXX_sp|Q99490|AGAP2_HUMAN(pre=R,post=E)
# XXX_sp|P40306|PSB10_HUMAN(pre=K,post=V)
# XXX_sp|Q14BN4|SLMAP_HUMAN(pre=R,post=D)
# XXX_sp|P05109|S10A8_HUMAN(pre=K,post=-)
# XXX_sp|P28288|ABCD3_HUMAN(pre=R,post=F)
# XXX_sp|A2RRP1|NBAS_HUMAN(pre=R,post=Q)
# XXX_sp|P50914|RL14_HUMAN(pre=R,post=C)
# XXX_sp|Q9Y5B9|SP16H_HUMAN(pre=R,post=R)
# XXX_sp|Q96EE3|SEH1_HUMAN(pre=R,post=R)
# XXX_sp|Q8TEM1|PO210_HUMAN(pre=R,post=V)
# XXX_sp|Q13099|IFT88_HUMAN(pre=K,post=K)
# XXX_sp|Q9NVN8|GNL3L_HUMAN(pre=K,post=E)
# XXX_sp|Q9UII2|ATIF1_HUMAN(pre=K,post=K)
# XXX_sp|Q15555|MARE2_HUMAN(pre=K,post=L)
# XXX_sp|Q9HCS7|SYF1_HUMAN(pre=K,post=R)
# XXX_sp|O43427|FIBP_HUMAN(pre=R,post=L)
# XXX_sp|O94822|LTN1_HUMAN(pre=R,post=V)
# XXX_sp|P52895|AK1C2_HUMAN(pre=K,post=R)
# XXX_sp|Q8WWM7|ATX2L_HUMAN(pre=K,post=M)
# XXX_sp|P32970|CD70_HUMAN(pre=R,post=I)
# XXX_sp|Q14406|CSHL_HUMAN(pre=R,post=Q)
# XXX_sp|Q4V328|GRAP1_HUMAN(pre=K,post=S)
# ...

# %%
old = open("Pdecoy_annotated_THIS.msp")
    
idx = 0
total = 0
dic = {}
    
while True:
    oldline = old.readline()
        
    if not oldline: break
        
    if oldline.startswith('Comment: '):
        total += 1
        #if not total % 1000:
            #print(total)
        
        comment = oldline.split('Protein="')
        protein = comment[1].split(' ')[0][:-1]
        #print(protein)
        
        oldline = old.readline()
        numpeak = int(oldline[11:-1])
        #print(numpeak)
        
        dic.update({protein : numpeak})
            
old.close
print(total)
dic
# Out:
# 374994
# {'XXX_sp|P55011|S12A2_HUMAN(pre=R,post=Q)': 52,
#  'XXX_sp|Q8WXD9|CSKI1_HUMAN(pre=R,post=Q)': 32,
#  'XXX_sp|Q96JP5|ZFP91_HUMAN(pre=R,post=R)': 27,
#  'XXX_sp|Q8N697|S15A4_HUMAN(pre=R,post=R)': 31,
#  'XXX_sp|Q5TF21|SOGA3_HUMAN(pre=R,post=N)': 25,
#  'XXX_sp|Q9NQS7|INCE_HUMAN(pre=R,post=K)': 62,
#  'XXX_sp|Q9Y4H2|IRS2_HUMAN(pre=R,post=T)': 57,
#  'XXX_sp|Q8TEJ3|SH3R3_HUMAN(pre=K,post=R)': 38,
#  'XXX_sp|Q6SPF0|SAMD1_HUMAN(pre=R,post=A)': 38,
#  'XXX_sp|O60779|S19A2_HUMAN(pre=R,post=T)': 20,
#  'XXX_sp|O76031|CLPX_HUMAN(pre=R,post=S)': 21,
#  'XXX_sp|Q9H9P5|UNKL_HUMAN(pre=K,post=Y)': 44,
#  'XXX_sp|Q8WUQ7|CATIN_HUMAN(pre=R,post=L)': 53,
#  'XXX_sp|A6NIH7|U119B_HUMAN(pre=K,post=K)': 42,
#  'XXX_sp|Q9BTD8|RBM42_HUMAN(pre=R,post=S)': 48,
#  'XXX_sp|Q9P258|RCC2_HUMAN(pre=K,post=A)': 49,
#  'XXX_sp|Q9H3U1|UN45A_HUMAN(pre=R,post=A)': 57,
#  'XXX_sp|P17542|TAL1_HUMAN(pre=R,post=G)': 22,
#  'XXX_sp|O60518|RNBP6_HUMAN(pre=R,post=D)': 12,
# ...

# %%
numpeaks = []

for i in Proteins:
    if i in dic:
        numpeaks.append(dic[i])
        
numpeaks
# Out:
# [12,
#  26,
#  14,
#  37,
#  66,
#  22,
#  32,
#  10,
#  10,
#  17,
#  56,
#  17,
#  25,
#  36,
#  30,
#  42,
#  11,
#  7,
#  31,
#  10,
#  40,
#  35,
#  27,
#  19,
#  32,
#  47,
#  60,
#  13,
#  18,
#  21,
#  43,
#  23,
#  18,
#  21,
#  30,
#  23,
#  14,
#  17,
#  28,
#  43,
#  13,
#  12,
#  11,
#  19,
#  10,
#  37,
#  43,
#  28,
#  24,
#  37,
#  20,
#  19,
#  33,
#  24,
#  26,
#  11,
#  15,
#  32,
#  17,
#  23,
#  21,
#  41,
#  26,
#  10,
#  34,
#  58,
#  25,
#  35,
#  24,
#  20,
#  20,
#  24,
#  36,
#  38,
#  25,
#  22,
#  21,
#  12,
#  38,
#  26,
#  23,
#  20,
#  55,
#  15,
#  26,
#  42,
#  66,
#  19,
#  35,
#  43,
#  34,
#  38,
#  16,
#  27,
#  9,
#  15,
#  18,
#  12,
#  29,
#  14,
#  19,
#  31,
#  34,
#  64,
#  19,
#  21,
#  15,
#  31,
#  31,
#  44,
#  11,
#  35,
#  13,
#  10,
#  26,
#  41,
#  25,
#  17,
#  53,
#  29,
#  17,
#  23,
#  27,
#  60,
#  19,
#  17,
#  21,
#  41,
#  23,
#  26,
#  28,
#  11,
#  16,
#  27,
#  13,
#  39,
#  16,
#  18,
#  35,
#  24,
#  30,
#  16,
#  43,
# ...

# %%
plt.hist(numpeaks, bins = 35)
plt.title('(1)')
plt.show()

# %%
plt.hist(numpeaks, bins = 35)
plt.title('(2)')
plt.show()

# %%
plt.hist(numpeaks, bins = 50)
plt.title('(3)')
plt.show()
