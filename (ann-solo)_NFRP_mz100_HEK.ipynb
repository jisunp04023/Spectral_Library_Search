# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1 = pd.read_excel('./target_decoy/ANN-SoLo/HEK/NFRP_mz100_target.xlsx')
NNt1.head()
# Out:
#    PSH                sequence  \
# 0  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 1  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 2  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 3  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 4  PSM  AAAAAAAAAAAAAAAGAGAGAK
#
#                                               PSM_ID  accession  unique  \
# 0  b1939_293T_proteinID_03B_QE3_122212.20232.2023...          0     NaN
# 1  b1939_293T_proteinID_03B_QE3_122212.47093.4709...          0     NaN
# 2  b1924_293T_proteinID_04A_QE3_122212.46500.4650...          0     NaN
# 3  b1928_293T_proteinID_08A_QE3_122212.43839.4383...          0     NaN
# 4  b1924_293T_proteinID_04A_QE3_122212.46412.4641...          1     NaN
#
#                                             database  database_version  \
# 0  file:///C:/2022-2/New_Decoy/BEST/Ntarget_filte...               NaN
# 1  file:///C:/2022-2/New_Decoy/BEST/Ntarget_filte...               NaN
# 2  file:///C:/2022-2/New_Decoy/BEST/Ntarget_filte...               NaN
# ...

# %%
NNd1 = pd.read_excel('./target_decoy/ANN-SoLo/HEK/NFRP_mz100_decoy.xlsx')
NNd1.head()
# Out:
#    PSH                    sequence  \
# 0  PSM  ASDGPSAGEPPAPPAAAAAAAAAAAR
# 1  PSM        PGPQAPGPSPPATAAAAAAR
# 2  PSM                 LLVTAAAAAAR
# 3  PSM        YHTPKETQPPSGSLAAAAAR
# 4  PSM        EEKGAVLGGPGAASAAAAAK
#
#                                               PSM_ID  accession  unique  \
# 0  b1937_293T_proteinID_01B_QE3_122212.49762.4976...     327592     NaN
# 1  b1927_293T_proteinID_07A_QE3_122212.55661.5566...     327599     NaN
# 2  b1932_293T_proteinID_12A_QE3_122212.23431.2343...     327601     NaN
# 3  b1932_293T_proteinID_12A_QE3_122212.31239.3123...     327603     NaN
# 4  b1947_293T_proteinID_11B_QE3_122212.41098.4109...     327605     NaN
#
#                                             database  database_version  \
# 0  file:///C:/2022-2/New_Decoy/BEST/Ntarget_filte...               NaN
# 1  file:///C:/2022-2/New_Decoy/BEST/Ntarget_filte...               NaN
# 2  file:///C:/2022-2/New_Decoy/BEST/Ntarget_filte...               NaN
# ...

# %%
nnt1 = plt.hist(NNt1['search_engine_score[1]'], bins = 50)
nnd1 = plt.hist(NNd1['search_engine_score[1]'], bins = 50)

# %%
print(nnt1[1][1] - nnt1[1][0])
print(nnd1[1][1] - nnd1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('(ANN-SoLo) NFRP_mz100: HEK')
plt.plot(nnt1[1][:-1] + 0.008, nnt1[0])
plt.plot(nnd1[1][:-1] + 0.006, nnd1[0])
plt.show()
# Out:
# 0.0168625630578026
# 0.012457351562334223

# %%
print(len(NNt1))
print(len(NNd1))
# Out:
# 691089
# 332263

# %%
NNt3 = NNt1['search_engine_score[1]']
NNd3 = NNd1['search_engine_score[1]']

score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.3130000000000002
nnt:  254843
nnd:  2523
FDR:  0.0099002130723622
"""
# Out:
# score:  0.001
# nnt:  672896
# nnd:  332256
# FDR:  0.49377021114704206
#
#
# score:  0.002
# nnt:  672787
# nnd:  332095
# FDR:  0.49361090508585925
#
#
# score:  0.003
# nnt:  672709
# nnd:  332001
# FDR:  0.49352840529857633
#
#
# score:  0.004
# nnt:  672606
# nnd:  331861
# FDR:  0.49339583649268665
#
#
# score:  0.005
# nnt:  672510
# nnd:  331739
# FDR:  0.49328485821772167
#
#
# score:  0.006
# nnt:  672393
# nnd:  331602
# FDR:  0.4931669425469926
#
#
# score:  0.007
# nnt:  672298
# nnd:  331486
# FDR:  0.49306408765160686
#
#
# score:  0.008
# nnt:  672171
# nnd:  331342
# FDR:  0.49294301598849105
#
#
# score:  0.009000000000000001
# nnt:  672036
# nnd:  331182
# FDR:  0.4928039569308787
#
#
# score:  0.010000000000000002
# nnt:  671904
# nnd:  331017
# FDR:  0.49265520074296326
#
#
# score:  0.011000000000000003
# nnt:  671748
# nnd:  330818
# FDR:  0.4924733679891864
#
#
# score:  0.012000000000000004
# nnt:  671592
# nnd:  330644
# FDR:  0.4923286757436062
#
#
# ...
