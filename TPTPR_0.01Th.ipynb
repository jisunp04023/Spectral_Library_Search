# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_target.xlsx')
NNt1_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.336  0.0113   [2]      0   0.330    104    0.107  ...      -1        0
# 1  0.470  0.2780   [2]      0  -0.001     10    0.138  ...      -1        0
# 2  0.600  0.3030   [2]      0  -0.002    120    0.106  ...      -1        0
# 3  0.601  0.3050   [2]      0  -0.003     43    0.091  ...      -1        0
# 4  0.571  0.3910   [2]      0  -0.002      6    0.188  ...      -1        0
#
# ...

# %%
NNt1_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_target.xlsx')
NNt1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55835.55835.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55836.55836.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55838.55838.4   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55839.55839.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55841.55841.2   1
#
#                                          ID    Dot  Delta DelRk  DBias  \
# 0  VEDGAQQC[160]LDC[160]GLC[160]FASPGSLSR/2  0.716  0.630   [2]      0
# 1              M[147]TC[160]EYTWPNHLLGSDK/2  0.102  0.017   [2]      0
# 2                HAHLTDTEIMTLVDETNMYEGVGR/4  0.155  0.001   [2]      0
# 3              KIEEAM[147]DGSETPQLFTVLPEK/3  0.458  0.260   [2]      0
# 4             LGQHVVGMAPLSVGSLDDEPGGEAETK/2  0.093  0.012   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.506      4    0.224  ...      -1        0          0        ()  Normal
# ...

# %%
NNd1_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_decoy.xlsx')
NNd1_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01911.01911.3   1
# 3  b1906_293T_proteinID_01A_QE3_122212.01913.01913.2   1
# 4  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1
#
#                               ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0                   QLGPKASGVK/3  0.204  0.008   [2]      0  -0.009     60
# 1                 AM[147]SIAYR/2  0.253  0.025   [2]      0   0.505     54
# 2  AEDSNEQC[160]QVPHEDSSTEPEVK/3  0.129  0.001   [2]      0   0.008      7
# 3               PLNDC[160]FSHK/2  0.257  0.004   [2]      0   0.007     65
# 4                     KHSEEHSE/3  0.174  0.071   [2]      0   0.327      4
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.073  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_decoy.xlsx')
NNd1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55834.55834.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55837.55837.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55845.55845.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55847.55847.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55848.55848.3   1
#
#                                              ID    Dot  Delta DelRk  DBias  \
# 0                    ATGSEAFTIIESTQEMLENMEARR/3  0.206  0.081   [2]      0
# 1  FSGIQNIC[160]VGNAC[160]IGPIEKC[160]EDIDVAR/3  0.183  0.033   [2]      0
# 2   PLC[160]VM[147]GDGHYNEPC[160]HC[160]QAQGK/3  0.035  0.016   [2]      0
# 3                          QFHVEVTC[160]SQIDK/3  0.214  0.007   [2]      0
# 4                          FGLNSM[147]WDAAVKK/3  0.270  0.044   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.339     27    0.059  ...      -1        0          0        ()  Normal
# ...

# %%
NNt1 = list(NNt1_1['Dot']) + list(NNt1_2['Dot'])
NNt1
# Out:
# [0.336,
#  0.47,
#  0.6,
#  0.601,
#  0.571,
#  0.399,
#  0.686,
#  0.242,
#  0.214,
#  0.28,
#  0.134,
#  0.271,
#  0.191,
#  0.44,
#  0.234,
#  0.258,
#  0.209,
#  0.393,
#  0.202,
#  0.065,
#  0.089,
#  0.568,
#  0.238,
#  0.14,
#  0.166,
#  0.237,
#  0.14,
#  0.156,
#  0.24,
#  0.051,
#  0.196,
#  0.337,
#  0.163,
#  0.154,
#  0.211,
#  0.307,
#  0.255,
#  0.247,
#  0.169,
#  0.172,
#  0.188,
#  0.273,
#  0.589,
#  0.138,
#  0.172,
#  0.264,
#  0.577,
#  0.11,
#  0.257,
#  0.213,
#  0.346,
#  0.603,
#  0.585,
#  0.304,
#  0.453,
#  0.278,
#  0.233,
#  0.275,
#  0.684,
#  0.385,
#  0.498,
#  0.224,
#  0.261,
#  0.266,
#  0.315,
#  0.201,
#  0.198,
#  0.451,
#  0.207,
#  0.187,
#  0.286,
#  0.258,
#  0.214,
#  0.218,
#  0.328,
#  0.091,
#  0.398,
#  0.575,
#  0.15,
#  0.639,
#  0.28,
#  0.139,
#  0.155,
#  0.23,
#  0.514,
#  0.324,
#  0.587,
#  0.216,
#  0.49,
#  0.292,
#  0.238,
#  0.214,
#  0.488,
#  0.081,
#  0.303,
#  0.309,
#  0.152,
#  0.23,
#  0.243,
#  0.157,
#  0.119,
# ...

# %%
NNd1 = list(NNd1_1['Dot']) + list(NNd1_2['Dot'])
NNd1
# Out:
# [0.204,
#  0.253,
#  0.129,
#  0.257,
#  0.174,
#  0.27,
#  0.267,
#  0.288,
#  0.244,
#  0.18,
#  0.161,
#  0.261,
#  0.266,
#  0.235,
#  0.42,
#  0.185,
#  0.366,
#  0.374,
#  0.273,
#  0.229,
#  0.214,
#  0.311,
#  0.158,
#  0.204,
#  0.419,
#  0.216,
#  0.217,
#  0.279,
#  0.186,
#  0.255,
#  0.219,
#  0.06,
#  0.207,
#  0.153,
#  0.21,
#  0.167,
#  0.2,
#  0.172,
#  0.226,
#  0.18,
#  0.292,
#  0.163,
#  0.267,
#  0.086,
#  0.313,
#  0.174,
#  0.248,
#  0.211,
#  0.197,
#  0.252,
#  0.327,
#  0.169,
#  0.212,
#  0.313,
#  0.253,
#  0.19,
#  0.235,
#  0.265,
#  0.306,
#  0.247,
#  0.319,
#  0.22,
#  0.246,
#  0.131,
#  0.274,
#  0.235,
#  0.188,
#  0.257,
#  0.285,
#  0.331,
#  0.23,
#  0.349,
#  0.101,
#  0.172,
#  0.288,
#  0.126,
#  0.342,
#  0.18,
#  0.281,
#  0.243,
#  0.254,
#  0.184,
#  0.189,
#  0.274,
#  0.301,
#  0.228,
#  0.187,
#  0.293,
#  0.175,
#  0.208,
#  0.217,
#  0.262,
#  0.249,
#  0.275,
#  0.234,
#  0.21,
#  0.217,
#  0.248,
#  0.295,
#  0.298,
#  0.192,
# ...

# %%
nnt1 = plt.hist(NNt1, bins = 50)
nnd1 = plt.hist(NNd1, bins = 50)

# %%
print(nnt1[1][1] - nnt1[1][0])
print(nnd1[1][1] - nnd1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted + Target_predicted_revDecoy delta > 0')
plt.plot(nnt1[1][:-1] + 0.0085, nnt1[0])
plt.plot(nnd1[1][:-1] + 0.007, nnd1[0])
plt.show()
# Out:
# 0.01798
# 0.01492

# %%
NNt2_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_target_0.01.xlsx')
NNt2_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.336  0.0113   [2]      0   0.330    104    0.107  ...      -1        0
# 1  0.470  0.2780   [2]      0  -0.001     10    0.138  ...      -1        0
# 2  0.600  0.3030   [2]      0  -0.002    120    0.106  ...      -1        0
# 3  0.601  0.3050   [2]      0  -0.003     43    0.091  ...      -1        0
# 4  0.571  0.3910   [2]      0  -0.002      6    0.188  ...      -1        0
#
# ...

# %%
NNt2_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_target_0.01.xlsx')
NNt2_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55835.55835.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55836.55836.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55839.55839.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55841.55841.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55842.55842.3   1
#
#                                          ID    Dot  Delta DelRk  DBias  \
# 0  VEDGAQQC[160]LDC[160]GLC[160]FASPGSLSR/2  0.716  0.630   [2]      0
# 1              M[147]TC[160]EYTWPNHLLGSDK/2  0.102  0.017   [2]      0
# 2              KIEEAM[147]DGSETPQLFTVLPEK/3  0.458  0.260   [2]      0
# 3             LGQHVVGMAPLSVGSLDDEPGGEAETK/2  0.093  0.012   [2]      0
# 4              DLPTIPGVTSPSSDEPPMEASQSHLR/3  0.464  0.321   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.506      4    0.224  ...      -1        0          0        ()  Normal
# ...

# %%
NNd2_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_decoy_0.01.xlsx')
NNd2_1.head()
# Out:
#                                            ### Query  Rk                ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1    AM[147]SIAYR/2
# 1  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1        KHSEEHSE/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01937.01937.3   1  EVDQTLLQDPNAIK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01940.01940.2   1     AAVTGSPSSHR/2
# 4  b1906_293T_proteinID_01A_QE3_122212.01942.01942.3   1   IESEVIPIEGLSK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.253  0.025   [2]      0   0.505     54    0.068  ...      -1        0
# 1  0.174  0.071   [2]      0   0.327      4    0.086  ...      -1        0
# 2  0.270  0.041   [2]      0  -0.007    106    0.078  ...      -1        0
# 3  0.267  0.049   [2]      0   0.501    121    0.064  ...      -1        0
# 4  0.288  0.019   [2]      0   0.005     68    0.084  ...      -1        0
#
# ...

# %%
NNd2_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_decoy_0.01.xlsx')
NNd2_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55834.55834.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55837.55837.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55845.55845.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55848.55848.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55880.55880.4   1
#
#                                              ID    Dot  Delta DelRk  DBias  \
# 0                    ATGSEAFTIIESTQEMLENMEARR/3  0.206  0.081   [2]      0
# 1  FSGIQNIC[160]VGNAC[160]IGPIEKC[160]EDIDVAR/3  0.183  0.033   [2]      0
# 2   PLC[160]VM[147]GDGHYNEPC[160]HC[160]QAQGK/3  0.035  0.016   [2]      0
# 3                          FGLNSM[147]WDAAVKK/3  0.270  0.044   [2]      0
# 4                   TQEEDEATSGNMISGEEEEEEERKR/4  0.205  0.064   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.339     27    0.059  ...      -1        0          0        ()  Normal
# ...

# %%
NNt2 = list(NNt2_1['Dot']) + list(NNt2_2['Dot'])
NNt2
# Out:
# [0.336,
#  0.47,
#  0.6,
#  0.601,
#  0.571,
#  0.399,
#  0.686,
#  0.242,
#  0.214,
#  0.28,
#  0.134,
#  0.271,
#  0.191,
#  0.44,
#  0.234,
#  0.258,
#  0.393,
#  0.202,
#  0.065,
#  0.568,
#  0.238,
#  0.166,
#  0.237,
#  0.14,
#  0.156,
#  0.24,
#  0.051,
#  0.337,
#  0.154,
#  0.307,
#  0.255,
#  0.247,
#  0.169,
#  0.589,
#  0.138,
#  0.264,
#  0.577,
#  0.257,
#  0.213,
#  0.346,
#  0.603,
#  0.585,
#  0.304,
#  0.453,
#  0.278,
#  0.233,
#  0.275,
#  0.684,
#  0.385,
#  0.498,
#  0.224,
#  0.261,
#  0.266,
#  0.315,
#  0.201,
#  0.451,
#  0.207,
#  0.187,
#  0.286,
#  0.258,
#  0.214,
#  0.218,
#  0.328,
#  0.091,
#  0.398,
#  0.575,
#  0.15,
#  0.639,
#  0.28,
#  0.155,
#  0.23,
#  0.514,
#  0.324,
#  0.587,
#  0.216,
#  0.49,
#  0.292,
#  0.214,
#  0.488,
#  0.081,
#  0.303,
#  0.309,
#  0.152,
#  0.243,
#  0.157,
#  0.119,
#  0.422,
#  0.23,
#  0.538,
#  0.33,
#  0.203,
#  0.333,
#  0.178,
#  0.663,
#  0.128,
#  0.259,
#  0.573,
#  0.541,
#  0.266,
#  0.482,
#  0.201,
# ...

# %%
NNd2 = list(NNd2_1['Dot']) + list(NNd2_2['Dot'])
NNd2
# Out:
# [0.253,
#  0.174,
#  0.27,
#  0.267,
#  0.288,
#  0.244,
#  0.161,
#  0.266,
#  0.235,
#  0.42,
#  0.185,
#  0.366,
#  0.374,
#  0.273,
#  0.229,
#  0.214,
#  0.311,
#  0.204,
#  0.419,
#  0.217,
#  0.279,
#  0.186,
#  0.255,
#  0.219,
#  0.207,
#  0.153,
#  0.21,
#  0.167,
#  0.2,
#  0.172,
#  0.226,
#  0.292,
#  0.163,
#  0.267,
#  0.086,
#  0.313,
#  0.174,
#  0.248,
#  0.211,
#  0.197,
#  0.252,
#  0.327,
#  0.169,
#  0.212,
#  0.313,
#  0.235,
#  0.265,
#  0.306,
#  0.319,
#  0.246,
#  0.131,
#  0.274,
#  0.235,
#  0.257,
#  0.285,
#  0.331,
#  0.23,
#  0.288,
#  0.126,
#  0.342,
#  0.18,
#  0.281,
#  0.184,
#  0.189,
#  0.274,
#  0.301,
#  0.293,
#  0.175,
#  0.208,
#  0.217,
#  0.262,
#  0.275,
#  0.234,
#  0.21,
#  0.217,
#  0.248,
#  0.295,
#  0.298,
#  0.192,
#  0.289,
#  0.215,
#  0.197,
#  0.252,
#  0.186,
#  0.185,
#  0.3,
#  0.231,
#  0.18,
#  0.279,
#  0.301,
#  0.255,
#  0.249,
#  0.169,
#  0.224,
#  0.189,
#  0.245,
#  0.281,
#  0.388,
#  0.272,
#  0.301,
#  0.298,
# ...

# %%
nnt2 = plt.hist(NNt2, bins = 50)
nnd2 = plt.hist(NNd2, bins = 50)

# %%
print(nnt2[1][1] - nnt2[1][0])
print(nnd2[1][1] - nnd2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted + Target_predicted_revDecoy delta > 0.01')
plt.plot(nnt2[1][:-1] + 0.0085, nnt2[0])
plt.plot(nnd2[1][:-1] + 0.007, nnd2[0])
plt.show()
# Out:
# 0.017959999999999997
# 0.01492

# %%
NNt3_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_target_0.05.xlsx')
NNt3_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01917.01917.2   1   HGGYKPSDEHK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.470  0.278   [2]      0  -0.001     10    0.138  ...      -1        0
# 1  0.600  0.303   [2]      0  -0.002    120    0.106  ...      -1        0
# 2  0.601  0.305   [2]      0  -0.003     43    0.091  ...      -1        0
# 3  0.571  0.391   [2]      0  -0.002      6    0.188  ...      -1        0
# 4  0.686  0.232   [2]      0  -0.003    132    0.059  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr   Proteins  LibFileOffset
# ...

# %%
NNt3_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_target_0.05.xlsx')
NNt3_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55835.55835.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55839.55839.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55842.55842.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55844.55844.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55852.55852.2   1
#
#                                          ID    Dot  Delta DelRk  DBias  \
# 0  VEDGAQQC[160]LDC[160]GLC[160]FASPGSLSR/2  0.716  0.630   [2]      0
# 1              KIEEAM[147]DGSETPQLFTVLPEK/3  0.458  0.260   [2]      0
# 2              DLPTIPGVTSPSSDEPPMEASQSHLR/3  0.464  0.321   [2]      0
# 3                               SEIDLLNIR/2  0.666  0.291   [2]      0
# 4                    PVTTPEEIAQVATISANGDK/2  0.634  0.505   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.506      4    0.224  ...      -1        0          0        ()  Normal
# ...

# %%
NNd3_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_decoy_0.05.xlsx')
NNd3_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01943.01943.2   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01946.01946.2   1
# 3  b1906_293T_proteinID_01A_QE3_122212.01954.01954.3   1
# 4  b1906_293T_proteinID_01A_QE3_122212.01959.01959.4   1
#
#                          ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0                KHSEEHSE/3  0.174  0.071   [2]      0   0.327      4
# 1               YYPSGSLVK/2  0.244  0.088   [2]      0  -0.005    112
# 2                 QVTGMGK/2  0.161  0.094   [2]      0   0.491      5
# 3  SIQAAAHLSPSIAPDC[160]R/3  0.266  0.053   [2]      0   0.339    102
# 4             HHVIEEEHHKK/4  0.420  0.097   [2]      0  -0.001     14
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.086  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd3_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_decoy_0.05.xlsx')
NNd3_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55834.55834.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55880.55880.4   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55924.55924.2   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55929.55929.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55934.55934.2   1
#
#                             ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0   ATGSEAFTIIESTQEMLENMEARR/3  0.206  0.081   [2]      0   0.339     27
# 1  TQEEDEATSGNMISGEEEEEEERKR/4  0.205  0.064   [2]      0   0.006      8
# 2  AGIIGQLM[147]DIPLPFVITSNK/2  0.109  0.109   [2]      0   0.505      1
# 3       LQDGINENEKSQEDFQEQLR/2  0.152  0.115   [2]      0   0.500      6
# 4                  LLINILYHK/2  0.527  0.132   [2]      0  -0.006     42
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.059  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt3 = list(NNt3_1['Dot']) + list(NNt3_2['Dot'])
NNt3
# Out:
# [0.47,
#  0.6,
#  0.601,
#  0.571,
#  0.686,
#  0.242,
#  0.44,
#  0.393,
#  0.202,
#  0.568,
#  0.337,
#  0.154,
#  0.307,
#  0.247,
#  0.589,
#  0.577,
#  0.346,
#  0.603,
#  0.585,
#  0.453,
#  0.275,
#  0.684,
#  0.385,
#  0.498,
#  0.224,
#  0.451,
#  0.398,
#  0.575,
#  0.15,
#  0.639,
#  0.514,
#  0.324,
#  0.587,
#  0.49,
#  0.214,
#  0.488,
#  0.303,
#  0.309,
#  0.422,
#  0.23,
#  0.538,
#  0.333,
#  0.178,
#  0.663,
#  0.573,
#  0.541,
#  0.482,
#  0.201,
#  0.652,
#  0.519,
#  0.126,
#  0.272,
#  0.685,
#  0.294,
#  0.431,
#  0.626,
#  0.717,
#  0.512,
#  0.511,
#  0.628,
#  0.684,
#  0.742,
#  0.716,
#  0.312,
#  0.39,
#  0.482,
#  0.539,
#  0.786,
#  0.655,
#  0.629,
#  0.237,
#  0.344,
#  0.667,
#  0.225,
#  0.553,
#  0.747,
#  0.563,
#  0.618,
#  0.636,
#  0.801,
#  0.266,
#  0.519,
#  0.646,
#  0.632,
#  0.296,
#  0.26,
#  0.327,
#  0.654,
#  0.561,
#  0.232,
#  0.621,
#  0.194,
#  0.43,
#  0.658,
#  0.534,
#  0.553,
#  0.282,
#  0.281,
#  0.526,
#  0.511,
#  0.719,
# ...

# %%
NNd3 = list(NNd3_1['Dot']) + list(NNd3_2['Dot'])
NNd3
# Out:
# [0.174,
#  0.244,
#  0.161,
#  0.266,
#  0.42,
#  0.374,
#  0.229,
#  0.311,
#  0.204,
#  0.419,
#  0.167,
#  0.172,
#  0.163,
#  0.267,
#  0.252,
#  0.327,
#  0.313,
#  0.235,
#  0.319,
#  0.274,
#  0.285,
#  0.288,
#  0.189,
#  0.274,
#  0.301,
#  0.293,
#  0.175,
#  0.262,
#  0.275,
#  0.234,
#  0.217,
#  0.298,
#  0.3,
#  0.279,
#  0.255,
#  0.169,
#  0.245,
#  0.388,
#  0.301,
#  0.273,
#  0.32,
#  0.3,
#  0.334,
#  0.329,
#  0.363,
#  0.347,
#  0.251,
#  0.37,
#  0.127,
#  0.371,
#  0.33,
#  0.249,
#  0.388,
#  0.306,
#  0.342,
#  0.282,
#  0.457,
#  0.348,
#  0.35,
#  0.328,
#  0.407,
#  0.369,
#  0.239,
#  0.285,
#  0.334,
#  0.337,
#  0.281,
#  0.574,
#  0.257,
#  0.363,
#  0.253,
#  0.289,
#  0.311,
#  0.226,
#  0.428,
#  0.188,
#  0.45,
#  0.315,
#  0.21,
#  0.23,
#  0.076,
#  0.356,
#  0.138,
#  0.328,
#  0.297,
#  0.306,
#  0.37,
#  0.266,
#  0.31,
#  0.375,
#  0.246,
#  0.295,
#  0.22,
#  0.297,
#  0.281,
#  0.355,
#  0.299,
#  0.247,
#  0.357,
#  0.376,
#  0.33,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted + Target_predicted_revDecoy delta > 0.05')
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.show()
# Out:
# 0.01738
# 0.014319999999999992

# %%
NNt4_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_target_0.1.xlsx')
NNt4_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01917.01917.2   1   HGGYKPSDEHK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.470  0.278   [2]      0  -0.001     10    0.138  ...      -1        0
# 1  0.600  0.303   [2]      0  -0.002    120    0.106  ...      -1        0
# 2  0.601  0.305   [2]      0  -0.003     43    0.091  ...      -1        0
# 3  0.571  0.391   [2]      0  -0.002      6    0.188  ...      -1        0
# 4  0.686  0.232   [2]      0  -0.003    132    0.059  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr   Proteins  LibFileOffset
# ...

# %%
NNt4_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_target_0.1.xlsx')
NNt4_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55835.55835.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55839.55839.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55842.55842.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55844.55844.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55852.55852.2   1
#
#                                          ID    Dot  Delta DelRk  DBias  \
# 0  VEDGAQQC[160]LDC[160]GLC[160]FASPGSLSR/2  0.716  0.630   [2]      0
# 1              KIEEAM[147]DGSETPQLFTVLPEK/3  0.458  0.260   [2]      0
# 2              DLPTIPGVTSPSSDEPPMEASQSHLR/3  0.464  0.321   [2]      0
# 3                               SEIDLLNIR/2  0.666  0.291   [2]      0
# 4                    PVTTPEEIAQVATISANGDK/2  0.634  0.505   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.506      4    0.224  ...      -1        0          0        ()  Normal
# ...

# %%
NNd4_1 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_1_decoy_0.1.xlsx')
NNd4_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01966.01966.2   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01977.01977.3   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01987.01987.3   1
# 3  b1906_293T_proteinID_01A_QE3_122212.02028.02028.3   1
# 4  b1906_293T_proteinID_01A_QE3_122212.02063.02063.4   1
#
#                        ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  \
# 0              AAVNVLGK/2  0.374  0.139   [2]      0  -0.001     31    0.107
# 1  GSNEHEEIDLFGC[160]IK/3  0.311  0.107   [2]      0   0.343     76    0.069
# 2         LTQGTLHSGDELK/3  0.419  0.136   [2]      0   0.328    132    0.093
# 3      NQNWDHADGLQNVNYR/3  0.267  0.136   [2]      0   0.000     26    0.050
# 4    SHDPIVSPRGPLSSSGTK/4  0.313  0.146   [2]      0   0.251     26    0.104
#
#    ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr Proteins  \
# 0  ...      -1        0          0        ()  Normal  Unk  Unk   1     XXX_
# ...

# %%
NNd4_2 = pd.read_excel('./delta_cutoff/0.01Th(TPTPR)/TPTPR(0.01)_2_decoy_0.1.xlsx')
NNd4_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55924.55924.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55929.55929.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55934.55934.2   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55986.55986.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.56100.56100.2   1
#
#                             ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  AGIIGQLM[147]DIPLPFVITSNK/2  0.109  0.109   [2]      0   0.505      1
# 1       LQDGINENEKSQEDFQEQLR/2  0.152  0.115   [2]      0   0.500      6
# 2                  LLINILYHK/2  0.527  0.132   [2]      0  -0.006     42
# 3               QEAVTVISSFLK/2  0.311  0.105   [2]      0  -0.004    135
# 4                   EFSTLAKR/2  0.420  0.107   [2]      0   0.495    122
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.109  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt4 = list(NNt4_1['Dot']) + list(NNt4_2['Dot'])
NNt4
# Out:
# [0.47,
#  0.6,
#  0.601,
#  0.571,
#  0.686,
#  0.44,
#  0.393,
#  0.568,
#  0.589,
#  0.577,
#  0.603,
#  0.585,
#  0.453,
#  0.684,
#  0.385,
#  0.498,
#  0.451,
#  0.398,
#  0.575,
#  0.639,
#  0.514,
#  0.324,
#  0.587,
#  0.49,
#  0.488,
#  0.303,
#  0.422,
#  0.23,
#  0.538,
#  0.663,
#  0.573,
#  0.541,
#  0.482,
#  0.652,
#  0.519,
#  0.272,
#  0.685,
#  0.294,
#  0.431,
#  0.626,
#  0.717,
#  0.512,
#  0.511,
#  0.628,
#  0.684,
#  0.742,
#  0.716,
#  0.482,
#  0.539,
#  0.786,
#  0.655,
#  0.629,
#  0.237,
#  0.667,
#  0.553,
#  0.747,
#  0.563,
#  0.618,
#  0.636,
#  0.801,
#  0.519,
#  0.646,
#  0.632,
#  0.327,
#  0.654,
#  0.561,
#  0.621,
#  0.43,
#  0.658,
#  0.534,
#  0.553,
#  0.526,
#  0.511,
#  0.719,
#  0.645,
#  0.72,
#  0.499,
#  0.575,
#  0.429,
#  0.575,
#  0.217,
#  0.658,
#  0.128,
#  0.16,
#  0.642,
#  0.631,
#  0.603,
#  0.27,
#  0.594,
#  0.685,
#  0.463,
#  0.635,
#  0.715,
#  0.61,
#  0.655,
#  0.4,
#  0.605,
#  0.362,
#  0.758,
#  0.54,
#  0.687,
# ...

# %%
NNd4 = list(NNd4_1['Dot']) + list(NNd4_2['Dot'])
NNd4
# Out:
# [0.374,
#  0.311,
#  0.419,
#  0.267,
#  0.313,
#  0.175,
#  0.275,
#  0.301,
#  0.32,
#  0.457,
#  0.348,
#  0.239,
#  0.285,
#  0.334,
#  0.281,
#  0.45,
#  0.23,
#  0.138,
#  0.37,
#  0.266,
#  0.242,
#  0.284,
#  0.312,
#  0.363,
#  0.242,
#  0.198,
#  0.446,
#  0.436,
#  0.259,
#  0.424,
#  0.549,
#  0.411,
#  0.28,
#  0.236,
#  0.414,
#  0.446,
#  0.343,
#  0.148,
#  0.47,
#  0.329,
#  0.461,
#  0.274,
#  0.241,
#  0.446,
#  0.317,
#  0.388,
#  0.295,
#  0.413,
#  0.26,
#  0.23,
#  0.506,
#  0.395,
#  0.33,
#  0.334,
#  0.524,
#  0.543,
#  0.143,
#  0.346,
#  0.483,
#  0.445,
#  0.272,
#  0.498,
#  0.518,
#  0.457,
#  0.484,
#  0.408,
#  0.215,
#  0.48,
#  0.442,
#  0.292,
#  0.481,
#  0.233,
#  0.319,
#  0.294,
#  0.282,
#  0.409,
#  0.371,
#  0.294,
#  0.137,
#  0.479,
#  0.42,
#  0.309,
#  0.452,
#  0.339,
#  0.301,
#  0.441,
#  0.423,
#  0.427,
#  0.312,
#  0.299,
#  0.167,
#  0.538,
#  0.387,
#  0.287,
#  0.384,
#  0.282,
#  0.333,
#  0.222,
#  0.463,
#  0.32,
#  0.456,
# ...

# %%
nnt4 = plt.hist(NNt4, bins = 50)
nnd4 = plt.hist(NNd4, bins = 50)

# %%
print(nnt4[1][1] - nnt4[1][0])
print(nnd4[1][1] - nnd4[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted + Target_predicted_revDecoy delta > 0.1')
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()
# Out:
# 0.016380000000000006
# 0.013319999999999999

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted')
plt.plot(nnt1[1][:-1] + 0.0085, nnt1[0])
plt.plot(nnt2[1][:-1] + 0.0085, nnt2[0])
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted_revDecoy')
plt.plot(nnd1[1][:-1] + 0.007, nnd1[0])
plt.plot(nnd2[1][:-1] + 0.007, nnd2[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()

# %%
print(len(NNt1))
print(len(NNd1))

print(len(NNt2))
print(len(NNd2))

print(len(NNt3))
print(len(NNd3))

print(len(NNt4))
print(len(NNd4))
# Out:
# 716377
# 333655
# 631146
# 252743
# 449033
# 86090
# 365303
# 22108

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt1:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd1:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.4910000000000004
nnt:  265090
nnd:  2633
FDR:  0.009932475762948433
"""
# Out:
# score:  0.001
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.002
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.003
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.004
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.005
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.006
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.007
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.008
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.009000000000000001
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.010000000000000002
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.011000000000000003
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# score:  0.012000000000000004
# nnt:  716377
# nnd:  333655
# FDR:  0.46575336729124467
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt2:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd2:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.4900000000000004
nnt:  265768
nnd:  2631
FDR:  0.009899611691400018
"""
# Out:
# score:  0.001
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.002
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.003
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.004
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.005
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.006
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.007
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.008
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.009000000000000001
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.010000000000000002
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.011000000000000003
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# score:  0.012000000000000004
# nnt:  631146
# nnd:  252743
# FDR:  0.4004509257762863
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.48100000000000037
nnt:  272081
nnd:  2678
FDR:  0.009842657149892863
"""
# Out:
# score:  0.001
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.002
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.003
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.004
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.005
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.006
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.007
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.008
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.009000000000000001
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.010000000000000002
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.011000000000000003
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# score:  0.012000000000000004
# nnt:  449033
# nnd:  86090
# FDR:  0.19172310275636756
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt4:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd4:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.45700000000000035
nnt:  286575
nnd:  2842
FDR:  0.009917124661955858
"""
# Out:
# score:  0.001
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.002
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.003
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.004
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.005
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.006
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.007
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.008
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.009000000000000001
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.010000000000000002
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.011000000000000003
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# score:  0.012000000000000004
# nnt:  365303
# nnd:  22108
# FDR:  0.06051962343588747
#
#
# ...

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Target_predicted + Target_predicted_revDecoy 0.01Th')
plt.plot(nnt1[1][:-1] + 0.0085, nnt1[0])
plt.plot(nnt2[1][:-1] + 0.0085, nnt2[0])
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])

plt.plot(nnd1[1][:-1] + 0.007, nnd1[0])
plt.plot(nnd2[1][:-1] + 0.007, nnd2[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()
