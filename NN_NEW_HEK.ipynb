# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./target_decoy/HEK/NN_NEW_1_target.xlsx')
NNt1_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1     RDPNNYRPR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1      VVYRPHGR/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1      HESGASIK/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.351  0.0567   [2]      0  0.0097    110    0.134  ...      -1        0
# 1  0.242  0.0230   [2]      0  0.3340     70    0.112  ...      -1        0
# 2  0.283  0.0200   [2]      0 -0.0010     76    0.121  ...      -1        0
# 3  0.877  0.4170   [2]      0 -0.0010     10    0.314  ...      -1        0
# 4  0.917  0.5650   [2]      0 -0.0020    128    0.135  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr Proteins  LibFileOffset
# ...

# %%
NNt1_2 = pd.read_excel('./target_decoy/HEK/NN_NEW_2_target.xlsx')
NNt1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55667.55667.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55671.55671.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55675.55675.2   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55676.55676.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55681.55681.3   1
#
#                             ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0              HLVSPEALDLLDK/3  0.863  0.544   [2]      0   0.004     96
# 1  IC[160]EEQEQALQEMGLHLSQSK/2  0.420  0.305   [2]      0   0.003     15
# 2             LTLQTTSDGVMLDK/2  0.247  0.033   [2]      0  -0.006    139
# 3            FIMLYQVTEVYEQMK/2  0.202  0.028   [2]      0   0.494     47
# 4       LPFC[160]AMGVSSVIHPK/3  0.925  0.469   [2]      0   0.001    140
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.190  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_1 = pd.read_excel('./target_decoy/HEK/NN_NEW_1_decoy.xlsx')
NNd1_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01911.01911.3   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1
# 3  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1
# 4  b1906_293T_proteinID_01A_QE3_122212.01941.01941.2   1
#
#                               ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  AEDSNEQC[160]QVPHEDSSTEPEVK/3  0.079  0.019   [2]      0   0.008      8
# 1               PMQHHGAVPGPRGR/4  0.317  0.106   [2]      0   0.002     20
# 2                 FDLHEILVYGYK/3  0.242  0.011   [2]      0  -0.001    130
# 3                     KHSEEHSE/3  0.289  0.034   [2]      0   0.327      6
# 4                   VDLGDDVTHR/2  0.151  0.012   [2]      0   0.507    135
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.042  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_2 = pd.read_excel('./target_decoy/HEK/NN_NEW_2_decoy.xlsx')
NNd1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55669.55669.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55673.55673.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55674.55674.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55677.55677.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55687.55687.3   1
#
#                                      ID    Dot  Delta DelRk  DBias  MzDiff  \
# 0                GLTLAVGPLSYAC[160]HR/3  0.326  0.057   [2]      0   0.008
# 1                      MQWFEQLAEVVNVK/2  0.294  0.013   [2]      0  -0.010
# 2  EEAEQAPRVPESC[160]PQSAPLPQC[160]AK/3  0.273  0.107   [2]      0   0.005
# 3      MDSSFSPRYQFEYM[147]YTPAGADRHNK/3  0.151  0.058   [2]      0   0.005
# 4               DFTTQLFLEEVESFSLEEKDK/3  0.171  0.020   [2]      0   0.329
#
#    #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst  \
# 0     78    0.138  ...      -1        0          0        ()  Normal  Unk
# ...

# %%
NNt3 = list(NNt1_1['Dot']) + list(NNt1_2['Dot'])
NNt3
# Out:
# [0.351,
#  0.242,
#  0.283,
#  0.877,
#  0.917,
#  0.887,
#  0.921,
#  0.262,
#  0.566,
#  0.691,
#  0.29,
#  0.245,
#  0.469,
#  0.237,
#  0.527,
#  0.222,
#  0.44,
#  0.185,
#  0.334,
#  0.454,
#  0.323,
#  0.21,
#  0.335,
#  0.834,
#  0.156,
#  0.174,
#  0.263,
#  0.213,
#  0.116,
#  0.24,
#  0.169,
#  0.136,
#  0.312,
#  0.302,
#  0.157,
#  0.276,
#  0.317,
#  0.438,
#  0.148,
#  0.197,
#  0.263,
#  0.233,
#  0.374,
#  0.286,
#  0.266,
#  0.329,
#  0.243,
#  0.209,
#  0.294,
#  0.758,
#  0.136,
#  0.283,
#  0.897,
#  0.185,
#  0.325,
#  0.883,
#  0.976,
#  0.784,
#  0.517,
#  0.298,
#  0.329,
#  0.792,
#  0.283,
#  0.591,
#  0.308,
#  0.637,
#  0.6,
#  0.345,
#  0.283,
#  0.424,
#  0.347,
#  0.356,
#  0.24,
#  0.879,
#  0.215,
#  0.304,
#  0.417,
#  0.315,
#  0.112,
#  0.362,
#  0.702,
#  0.768,
#  0.159,
#  0.304,
#  0.828,
#  0.29,
#  0.191,
#  0.272,
#  0.368,
#  0.36,
#  0.89,
#  0.238,
#  0.582,
#  0.214,
#  0.401,
#  0.473,
#  0.22,
#  0.608,
#  0.231,
#  0.765,
#  0.296,
# ...

# %%
NNd3 = list(NNd1_1['Dot']) + list(NNd1_2['Dot'])
NNd3
# Out:
# [0.079,
#  0.317,
#  0.242,
#  0.289,
#  0.151,
#  0.344,
#  0.209,
#  0.525,
#  0.379,
#  0.737,
#  0.24,
#  0.458,
#  0.462,
#  0.307,
#  0.282,
#  0.041,
#  0.218,
#  0.251,
#  0.278,
#  0.565,
#  0.354,
#  0.184,
#  0.342,
#  0.195,
#  0.249,
#  0.206,
#  0.201,
#  0.159,
#  0.513,
#  0.091,
#  0.256,
#  0.37,
#  0.142,
#  0.198,
#  0.329,
#  0.434,
#  0.242,
#  0.217,
#  0.332,
#  0.103,
#  0.333,
#  0.227,
#  0.224,
#  0.358,
#  0.13,
#  0.353,
#  0.261,
#  0.292,
#  0.371,
#  0.36,
#  0.321,
#  0.387,
#  0.255,
#  0.364,
#  0.298,
#  0.452,
#  0.215,
#  0.202,
#  0.249,
#  0.135,
#  0.323,
#  0.317,
#  0.19,
#  0.38,
#  0.489,
#  0.125,
#  0.342,
#  0.149,
#  0.269,
#  0.34,
#  0.334,
#  0.258,
#  0.421,
#  0.44,
#  0.197,
#  0.283,
#  0.258,
#  0.294,
#  0.196,
#  0.209,
#  0.089,
#  0.216,
#  0.415,
#  0.176,
#  0.221,
#  0.269,
#  0.249,
#  0.213,
#  0.291,
#  0.407,
#  0.243,
#  0.336,
#  0.325,
#  0.271,
#  0.298,
#  0.218,
#  0.18,
#  0.596,
#  0.333,
#  0.213,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('NN_NEW: HEK')
plt.plot(nnt3[1][:-1] + 0.0095, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.0085, nnd3[0])
plt.show()
# Out:
# 0.01954
# 0.017879999999999997

# %%
print(len(NNt3))
print(len(NNd3))
# Out:
# 738387
# 312550

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.6010000000000004
nnt:  309935
nnd:  3074
FDR:  0.009918208656653814
"""
# Out:
# score:  0.001
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.002
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.003
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.004
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.005
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.006
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.007
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.008
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.009000000000000001
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.010000000000000002
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.011000000000000003
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# score:  0.012000000000000004
# nnt:  738387
# nnd:  312550
# FDR:  0.4232875172504391
#
#
# ...
