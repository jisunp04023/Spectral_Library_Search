# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import sys

# %%
df1 = pd.read_excel('C:/2022-2/New_Decoy/BEST/result/HEK/TPRP_EXPAND_1.xlsx')
df1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1     FIVGHSVPK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1      HAVSEGTK/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
#
#      Dot    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.344  0.00652   [2]      0   0.330    655   0.0951  ...      -1        0
# 1  0.267  0.01500   [2]      0   0.330    496   0.0740  ...      -1        0
# 2  0.763  0.00000   [4]      0  -0.001    469   0.1010  ...      -1        0
# 3  0.470  0.12700   [2]      0  -0.001    363   0.0900  ...      -1        0
# 4  0.600  0.30300   [2]      0  -0.002    366   0.0900  ...      -1        0
#
# ...

# %%
df2 = pd.read_excel('C:/2022-2/New_Decoy/BEST/result/HEK/TPRP_EXPAND_2.xlsx')
df2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.54539.54539.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.54540.54540.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.54542.54542.2   1
# 3  b1932_293T_proteinID_12A_QE3_122212.54545.54545.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.54546.54546.2   1
#
#                            ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0        GM[147]LREDAVLEYLK/3  0.629  0.314   [2]      0   0.002    400
# 1           VVSEDFLQDVSASTK/2  0.555  0.293   [3]      0   0.503    281
# 2             AAFTAFEEAQLPR/2  0.714  0.481   [3]      0   0.002    410
# 3  ANMIIIGNDISFSDSPLGAINWTR/3  0.233  0.004   [2]      0   0.003    102
# 4              NFSGAELEGLVR/2  0.376  0.006   [3]      0   0.004    551
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.085  ...      -1        0          0        ()  Normal  Unk  Unk   0
# ...

# %%
list1_1 = df1['### Query'].values.tolist()
list1_2 = df2['### Query'].values.tolist()
print(len(list1_1))
print(len(list1_2))
list1_1 ########################################################################
# Out:
# 535295
# 535294
# ['b1906_293T_proteinID_01A_QE3_122212.01873.01873.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01882.01882.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01886.01886.2',
#  'b1906_293T_proteinID_01A_QE3_122212.01899.01899.4',
#  'b1906_293T_proteinID_01A_QE3_122212.01905.01905.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01909.01909.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01910.01910.4',
#  'b1906_293T_proteinID_01A_QE3_122212.01911.01911.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01913.01913.2',
#  'b1906_293T_proteinID_01A_QE3_122212.01914.01914.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01917.01917.2',
#  'b1906_293T_proteinID_01A_QE3_122212.01926.01926.4',
#  'b1906_293T_proteinID_01A_QE3_122212.01927.01927.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01934.01934.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01937.01937.3',
#  'b1906_293T_proteinID_01A_QE3_122212.01938.01938.4',
#  'b1906_293T_proteinID_01A_QE3_122212.01940.01940.2',
# ...

# %%
from pprint import pprint

with open('PIF_00335.txt', 'r') as f:
    data= f.readlines()
    
column_name = data[0].strip().split()

data_split = [x.strip().split('\t') for x in data[1:]]

df = pd.DataFrame(data_split, columns = column_name)
df.head()
# Out:
#                                        file  scan          pmz cs matchedSum  \
# 0  b1906_293T_proteinID_01A_QE3_122212.1873  1873   396.548828  3  5600703.1
# 1  b1906_293T_proteinID_01A_QE3_122212.1882  1882   328.856812  3  3953552.5
# 2  b1906_293T_proteinID_01A_QE3_122212.1886  1886   414.713043  2  5696248.4
# 3  b1906_293T_proteinID_01A_QE3_122212.1891  1891  1143.890015  2  1519959.7
# 4  b1906_293T_proteinID_01A_QE3_122212.1892  1892   308.679016  2  1914568.1
#
#   observedSum     PIF
# 0   5609240.6  0.9985
# 1   4335148.6  0.9120
# 2   6138996.1  0.9279
# 3   1519959.7  1.0000
# 4   2341071.2  0.8178

# %%
df_pif = df[['file', 'cs', 'PIF']]
print(len(df_pif))
df_pif
# Out:
# 1121149
#                                               file cs     PIF
# 0         b1906_293T_proteinID_01A_QE3_122212.1873  3  0.9985
# 1         b1906_293T_proteinID_01A_QE3_122212.1882  3  0.9120
# 2         b1906_293T_proteinID_01A_QE3_122212.1886  2  0.9279
# 3         b1906_293T_proteinID_01A_QE3_122212.1891  2  1.0000
# 4         b1906_293T_proteinID_01A_QE3_122212.1892  2  0.8178
# ...                                            ... ..     ...
# 1121144  b1948_293T_proteinID_12B_QE3_122212.76955  3  1.0000
# 1121145  b1948_293T_proteinID_12B_QE3_122212.76956  2  0.6691
# 1121146  b1948_293T_proteinID_12B_QE3_122212.76961  2  0.7970
# 1121147  b1948_293T_proteinID_12B_QE3_122212.76972  2  0.8492
# 1121148  b1948_293T_proteinID_12B_QE3_122212.76978  2  0.9165
#
# [1121149 rows x 3 columns]

# %%
list2 = df_pif.values.tolist()
list2
# Out:
# [['b1906_293T_proteinID_01A_QE3_122212.1873', '3', '0.9985'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1882', '3', '0.9120'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1886', '2', '0.9279'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1891', '2', '1.0000'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1892', '2', '0.8178'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1898', '2', '0.8920'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1899', '4', '0.9446'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1900', '2', '1.0000'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1901', '2', '1.0000'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1902', '2', '0.9907'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1903', '2', '0.7317'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1904', '2', '0.8155'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1905', '3', '0.5965'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1909', '3', '0.9866'],
#  ['b1906_293T_proteinID_01A_QE3_122212.1910', '4', '0.9580'],
# ...

# %%
PIF = {}

for i in list2:
    n = i[0].split('.')
    p1 = n[0] + '.' + n[1].zfill(5) + '.' + n[1].zfill(5) + '.' + i[1]
    p2 = float(i[2])
    PIF[p1] = p2

# %%
PIF ########################################################################
# Out:
# {'b1906_293T_proteinID_01A_QE3_122212.01873.01873.3': 0.9985,
#  'b1906_293T_proteinID_01A_QE3_122212.01882.01882.3': 0.912,
#  'b1906_293T_proteinID_01A_QE3_122212.01886.01886.2': 0.9279,
#  'b1906_293T_proteinID_01A_QE3_122212.01891.01891.2': 1.0,
#  'b1906_293T_proteinID_01A_QE3_122212.01892.01892.2': 0.8178,
#  'b1906_293T_proteinID_01A_QE3_122212.01898.01898.2': 0.892,
#  'b1906_293T_proteinID_01A_QE3_122212.01899.01899.4': 0.9446,
#  'b1906_293T_proteinID_01A_QE3_122212.01900.01900.2': 1.0,
#  'b1906_293T_proteinID_01A_QE3_122212.01901.01901.2': 1.0,
#  'b1906_293T_proteinID_01A_QE3_122212.01902.01902.2': 0.9907,
#  'b1906_293T_proteinID_01A_QE3_122212.01903.01903.2': 0.7317,
#  'b1906_293T_proteinID_01A_QE3_122212.01904.01904.2': 0.8155,
#  'b1906_293T_proteinID_01A_QE3_122212.01905.01905.3': 0.5965,
#  'b1906_293T_proteinID_01A_QE3_122212.01909.01909.3': 0.9866,
#  'b1906_293T_proteinID_01A_QE3_122212.01910.01910.4': 0.958,
# ...

# %%
FINAL1 = []

for i in list1_1:
    FINAL1.append(PIF[i])
    
FINAL2 = []

for i in list1_2:
    FINAL2.append(PIF[i])

print(len(FINAL1))
print(len(FINAL2))
# Out:
# 535295
# 535294

# %%
FINAL1 #OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Out:
# [0.9985,
#  0.912,
#  0.9279,
#  0.9446,
#  0.5965,
#  0.9866,
#  0.958,
#  0.9581,
#  0.9377,
#  1.0,
#  1.0,
#  0.9618,
#  0.9504,
#  0.6566,
#  0.9693,
#  0.9912,
#  0.808,
#  0.9774,
#  0.9609,
#  0.8487,
#  0.9392,
#  0.7827,
#  0.9971,
#  0.9836,
#  0.7887,
#  1.0,
#  0.974,
#  0.85,
#  0.864,
#  0.811,
#  0.7996,
#  0.7262,
#  0.9239,
#  0.9275,
#  0.8924,
#  0.8924,
#  0.9329,
#  0.689,
#  1.0,
#  0.7148,
#  0.835,
#  0.8889,
#  0.9991,
#  0.987,
#  0.7871,
#  0.9577,
#  0.9434,
#  0.9229,
#  0.8988,
#  0.9967,
#  0.979,
#  0.9665,
#  0.2547,
#  0.7912,
#  0.95,
#  1.0,
#  0.8133,
#  0.9554,
#  0.9827,
#  1.0,
#  0.8932,
#  0.9404,
#  0.7479,
#  0.9213,
#  0.6627,
#  0.88,
#  0.729,
#  0.9927,
#  1.0,
#  0.9875,
#  1.0,
#  0.9093,
#  0.7333,
#  0.6663,
#  0.6129,
#  1.0,
#  0.981,
#  0.812,
#  0.83,
#  0.8906,
#  0.8833,
#  0.616,
#  0.9187,
#  0.6403,
#  0.8118,
#  0.7945,
#  0.5596,
#  0.0756,
#  0.7621,
#  0.7988,
#  0.8003,
#  0.7209,
#  0.4733,
#  0.6838,
#  0.5925,
# ...

# %%
final1 = pd.DataFrame(FINAL1, columns = ['PIF'])
final2 = pd.DataFrame(FINAL2, columns = ['PIF'])
print(len(final1))
print(len(final2))
final1
# Out:
# 535295
# 535294
#            PIF
# 0       0.9985
# 1       0.9120
# 2       0.9279
# 3       0.9446
# 4       0.5965
# ...        ...
# 535290  0.2429
# 535291  0.8819
# 535292  0.8697
# 535293  0.9539
# 535294  0.9205
#
# [535295 rows x 1 columns]

# %%
df1
# Out:
#                                                 ### Query  Rk  \
# 0       b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1
# 1       b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1
# 2       b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1
# 3       b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1
# 4       b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1
# ...                                                   ...  ..
# 535290  b1932_293T_proteinID_12A_QE3_122212.54532.54532.2   1
# 535291  b1932_293T_proteinID_12A_QE3_122212.54533.54533.2   1
# 535292  b1932_293T_proteinID_12A_QE3_122212.54534.54534.3   1
# 535293  b1932_293T_proteinID_12A_QE3_122212.54536.54536.2   1
# 535294  b1932_293T_proteinID_12A_QE3_122212.54538.54538.2   1
#
#                       ID    Dot    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  \
# 0          LSVEADINGLR/3  0.344  0.00652   [2]      0   0.330    655   0.0951
# ...

# %%
df2
# Out:
#                                                 ### Query  Rk  \
# 0       b1932_293T_proteinID_12A_QE3_122212.54539.54539.3   1
# 1       b1932_293T_proteinID_12A_QE3_122212.54540.54540.2   1
# 2       b1932_293T_proteinID_12A_QE3_122212.54542.54542.2   1
# 3       b1932_293T_proteinID_12A_QE3_122212.54545.54545.3   1
# 4       b1932_293T_proteinID_12A_QE3_122212.54546.54546.2   1
# ...                                                   ...  ..
# 535289  b1948_293T_proteinID_12B_QE3_122212.76735.76735.2   1
# 535290  b1948_293T_proteinID_12B_QE3_122212.76744.76744.2   1
# 535291  b1948_293T_proteinID_12B_QE3_122212.76802.76802.2   1
# 535292  b1948_293T_proteinID_12B_QE3_122212.76875.76875.2   1
# 535293  b1948_293T_proteinID_12B_QE3_122212.76978.76978.2   1
#
#                                 ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0             GM[147]LREDAVLEYLK/3  0.629  0.314   [2]      0   0.002    400
# ...

# %%
result1 = pd.concat([df1, final1], axis = 1)
result2 = pd.concat([df2, final2], axis = 1)
result1
# Out:
#                                                 ### Query  Rk  \
# 0       b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1
# 1       b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1
# 2       b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1
# 3       b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1
# 4       b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1
# ...                                                   ...  ..
# 535290  b1932_293T_proteinID_12A_QE3_122212.54532.54532.2   1
# 535291  b1932_293T_proteinID_12A_QE3_122212.54533.54533.2   1
# 535292  b1932_293T_proteinID_12A_QE3_122212.54534.54534.3   1
# 535293  b1932_293T_proteinID_12A_QE3_122212.54536.54536.2   1
# 535294  b1932_293T_proteinID_12A_QE3_122212.54538.54538.2   1
#
#                       ID    Dot    Delta DelRk  DBias  MzDiff  #Cand  MeanDot  \
# 0          LSVEADINGLR/3  0.344  0.00652   [2]      0   0.330    655   0.0951
# ...

# %%
result1.to_excel('C:/2022-2/New_Decoy/BEST/result/HEK/TPRP_EXPAND_1_PIF.xlsx', header=True, index=False)

# %%
result2
# Out:
#                                                 ### Query  Rk  \
# 0       b1932_293T_proteinID_12A_QE3_122212.54539.54539.3   1
# 1       b1932_293T_proteinID_12A_QE3_122212.54540.54540.2   1
# 2       b1932_293T_proteinID_12A_QE3_122212.54542.54542.2   1
# 3       b1932_293T_proteinID_12A_QE3_122212.54545.54545.3   1
# 4       b1932_293T_proteinID_12A_QE3_122212.54546.54546.2   1
# ...                                                   ...  ..
# 535289  b1948_293T_proteinID_12B_QE3_122212.76735.76735.2   1
# 535290  b1948_293T_proteinID_12B_QE3_122212.76744.76744.2   1
# 535291  b1948_293T_proteinID_12B_QE3_122212.76802.76802.2   1
# 535292  b1948_293T_proteinID_12B_QE3_122212.76875.76875.2   1
# 535293  b1948_293T_proteinID_12B_QE3_122212.76978.76978.2   1
#
#                                 ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0             GM[147]LREDAVLEYLK/3  0.629  0.314   [2]      0   0.002    400
# ...

# %%
result2.to_excel('C:/2022-2/New_Decoy/BEST/result/HEK/TPRP_EXPAND_2_PIF.xlsx', header=True, index=False)
