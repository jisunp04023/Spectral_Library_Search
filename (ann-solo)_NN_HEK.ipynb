# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./target_decoy/ANN-SoLo/HEK/NN_1_target.xlsx')
NNt1_1.head()
# Out:
#    PSH                sequence  \
# 0  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 1  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 2  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 3  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 4  PSM            AAAAAAAAAVSR
#
#                                               PSM_ID  accession  unique  \
# 0  b1939_293T_proteinID_03B_QE3_122212.47093.4709...          0     NaN
# 1  b1924_293T_proteinID_04A_QE3_122212.46500.4650...          0     NaN
# 2  b1924_293T_proteinID_04A_QE3_122212.46412.4641...          1     NaN
# 3  b1941_293T_proteinID_05B_QE3_122212.45063.4506...          1     NaN
# 4  b1922_293T_proteinID_02A_QE3_122212.7951.7951....          4     NaN
#
#                                             database  database_version  \
# 0  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 1  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 2  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# ...

# %%
NNt1_2 = pd.read_excel('./target_decoy/ANN-SoLo/HEK/NN_2_target.xlsx')
NNt1_2.head()
# Out:
#    PSH                sequence  \
# 0  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 1  PSM  AAAAAAAAAAAAAAAGAGAGAK
# 2  PSM    AAAAAATAPPSPGPAQPGPR
# 3  PSM              AAAAADLANR
# 4  PSM         AAAAALSQQQSLQER
#
#                                               PSM_ID  accession  unique  \
# 0  b1943_293T_proteinID_07B_QE3_122212.53343.5334...          0     NaN
# 1  b1928_293T_proteinID_08A_QE3_122212.43839.4383...          0     NaN
# 2  b1946_293T_proteinID_10B_QE3_122212.12690.1269...         11     NaN
# 3  b1929_293T_proteinID_09A_QE3_122212.7633.7633....         14     NaN
# 4  b1948_293T_proteinID_12B_QE3_122212.16616.1661...         16     NaN
#
#                                             database  database_version  \
# 0  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 1  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 2  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# ...

# %%
NNd1_1 = pd.read_excel('./target_decoy/ANN-SoLo/HEK/NN_1_decoy.xlsx')
NNd1_1.head()
# Out:
#    PSH                          sequence  \
# 0  PSM  ASHQVC[160]LALLTAPGLPPLDGSGAAAAR
# 1  PSM                         DLSGAAAAR
# 2  PSM                       QVEDINAAAAK
# 3  PSM                       QVEDINAAAAK
# 4  PSM                       QVEDINAAAAK
#
#                                               PSM_ID  accession  unique  \
# 0  b1925_293T_proteinID_05A_QE3_122212.56852.5685...     374987     NaN
# 1  b1937_293T_proteinID_01B_QE3_122212.30193.3019...     374988     NaN
# 2  b1906_293T_proteinID_01A_QE3_122212.8367.8367....     374991     NaN
# 3  b1940_293T_proteinID_04B_QE3_122212.6907.6907....     374991     NaN
# 4  b1925_293T_proteinID_05A_QE3_122212.6177.6177....     374991     NaN
#
#                                             database  database_version  \
# 0  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 1  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# ...

# %%
NNd1_2 = pd.read_excel('./target_decoy/ANN-SoLo/HEK/NN_2_decoy.xlsx')
NNd1_2.head()
# Out:
#    PSH              sequence  \
# 0  PSM  PGPQAPGPSPPATAAAAAAR
# 1  PSM  PGPQAPGPSPPATAAAAAAR
# 2  PSM           LLVTAAAAAAR
# 3  PSM  EEKGAVLGGPGAASAAAAAK
# 4  PSM     FLAINNENALVFAAAAK
#
#                                               PSM_ID  accession  unique  \
# 0  b1944_293T_proteinID_08B_QE3_122212.9326.9326....     374970     NaN
# 1  b1929_293T_proteinID_09A_QE3_122212.8981.8981....     374970     NaN
# 2  b1932_293T_proteinID_12A_QE3_122212.23431.2343...     374971     NaN
# 3  b1947_293T_proteinID_11B_QE3_122212.41098.4109...     374975     NaN
# 4  b1946_293T_proteinID_10B_QE3_122212.72248.7224...     374983     NaN
#
#                                             database  database_version  \
# 0  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 1  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# 2  file:///C:/2022-2/New_Decoy/BEST/Ntarget__Nrev...               NaN
# ...

# %%
NNt3 = list(NNt1_1['search_engine_score[1]']) + list(NNt1_2['search_engine_score[1]'])
NNt3
# Out:
# [0.906185205247311,
#  0.746324987499974,
#  0.87382644745594,
#  0.894327319518197,
#  0.932253939885413,
#  0.949260336594306,
#  0.869448724202811,
#  0.779732093331404,
#  0.328830425627529,
#  0.23596971668303,
#  0.169155502342619,
#  0.885497963172383,
#  0.370343615533784,
#  0.316696257796138,
#  0.239207918231841,
#  0.328503200784325,
#  0.251019216608256,
#  0.435270826332271,
#  0.333907978783827,
#  0.273686657659709,
#  0.795736744024907,
#  0.775888174539431,
#  0.280093187466263,
#  0.326779269380494,
#  0.395107740303501,
#  0.792684908141382,
#  0.407175303436815,
#  0.718112993024988,
#  0.838858475923189,
#  0.246290035545825,
#  0.243960394524037,
#  0.242912056855857,
#  0.17025044071488,
#  0.116272563114762,
#  0.154455446172505,
#  0.862434478593058,
#  0.678695395123213,
#  0.830541638715658,
#  0.233919627906288,
#  0.808270239707781,
#  0.0818870142102241,
#  0.186418167315423,
#  0.162818870856426,
#  0.159860217245295,
#  0.225719274953007,
# ...

# %%
NNd3 = list(NNd1_1['search_engine_score[1]']) + list(NNd1_2['search_engine_score[1]'])
NNd3
# Out:
# [0.0624344795942306,
#  0.367617937852628,
#  0.347699473379179,
#  0.275014558807015,
#  0.316319160163402,
#  0.212416594848036,
#  0.204373577609658,
#  0.164112470112741,
#  0.228188706561923,
#  0.354921374469995,
#  0.382434472558088,
#  0.290902738226577,
#  0.231473502703011,
#  0.236565478146076,
#  0.291508446622174,
#  0.357437390630366,
#  0.328526496508857,
#  0.308118808519793,
#  0.160046596312895,
#  0.256517172791063,
#  0.273686662199907,
#  0.132929528132081,
#  0.0791147365234792,
#  0.290110654663294,
#  0.386721020093318,
#  0.298241119366139,
#  0.159091441404598,
#  0.243610940873622,
#  0.179498307406902,
#  0.302294701337814,
#  0.161164820194244,
#  0.183506110683083,
#  0.253814790048636,
#  0.2674665087834,
#  0.311170644010417,
#  0.321700638276524,
#  0.272475246223621,
#  0.372440306004136,
#  0.367338379321154,
#  0.354199187248013,
#  0.351729757036082,
#  0.442795573791954,
#  0.543063484714366,
#  0.39103086257819,
#  0.338264420628547,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('(ANN-SoLo) NN: HEK')
plt.plot(nnt3[1][:-1] + 0.0095, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.0075, nnd3[0])
plt.show()
# Out:
# 0.01988444955451996
# 0.015219569101682283

# %%
print(len(NNt3))
print(len(NNd3))
# Out:
# 814380
# 235125

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.4850000000000004
nnt:  300047
nnd:  2929
FDR:  0.0097618039840425
"""
# Out:
# score:  0.001
# nnt:  810483
# nnd:  235099
# FDR:  0.29007270972987714
#
#
# score:  0.002
# nnt:  810351
# nnd:  235062
# FDR:  0.29007430113617433
#
#
# score:  0.003
# nnt:  810219
# nnd:  235026
# FDR:  0.2900771272952128
#
#
# score:  0.004
# nnt:  810067
# nnd:  234992
# FDR:  0.2900895851824602
#
#
# score:  0.005
# nnt:  809922
# nnd:  234953
# FDR:  0.29009336701558913
#
#
# score:  0.006
# nnt:  809773
# nnd:  234920
# FDR:  0.29010599266708076
#
#
# score:  0.007
# nnt:  809606
# nnd:  234887
# FDR:  0.29012507318374614
#
#
# score:  0.008
# nnt:  809481
# nnd:  234849
# FDR:  0.2901229306185074
#
#
# score:  0.009000000000000001
# nnt:  809330
# nnd:  234807
# FDR:  0.2901251652601535
#
#
# score:  0.010000000000000002
# nnt:  809186
# nnd:  234759
# FDR:  0.29011747608090105
#
#
# score:  0.011000000000000003
# nnt:  809000
# nnd:  234714
# FDR:  0.2901285537700865
#
#
# score:  0.012000000000000004
# nnt:  808833
# nnd:  234682
# FDR:  0.2901488935293194
#
#
# ...
