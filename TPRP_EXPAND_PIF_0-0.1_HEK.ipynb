# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./target_decoy/HEK/TPRP_EXPAND_coelution/TPRP_EXPAND_1_PIF_01_target.xlsx')
NNt1_1.head()
# Out:
#                                            ### Query  Rk                ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.02036.02036.4   1  TLDVDHNQLTAFPR/4
# 1  b1906_293T_proteinID_01A_QE3_122212.03022.03022.2   1       GLQTSQDAR/2
# 2  b1906_293T_proteinID_01A_QE3_122212.03028.03028.3   1      SIALSIILVR/3
# 3  b1906_293T_proteinID_01A_QE3_122212.03425.03425.4   1  TGALPGPGPLSNPR/4
# 4  b1906_293T_proteinID_01A_QE3_122212.04112.04112.3   1    AHVTGPVEDNEK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  KSScore  OpModMass  \
# 0  0.239  0.013   [2]      0   0.259    306    0.083  ...        0          0
# 1  0.553  0.212   [3]      0  -0.006    650    0.080  ...        0          0
# 2  0.350  0.187   [2]      0   0.339      8    0.121  ...        0          0
# 3  0.309  0.004   [2]      0   0.004    317    0.091  ...        0          0
# 4  0.606  0.285   [2]      0  -0.006    455    0.084  ...        0          0
#
# ...

# %%
NNt1_2 = pd.read_excel('./target_decoy/HEK/TPRP_EXPAND_coelution/TPRP_EXPAND_2_PIF_01_target.xlsx')
NNt1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55358.55358.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55399.55399.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55610.55610.4   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55752.55752.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.56283.56283.2   1
#
#                          ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0       FLNATC[160]DEYFTR/2  0.228  0.014   [2]      0   0.497    116
# 1  GSPLGDIPVFIAMIQASGVAAR/3  0.219  0.037   [3]      0   0.329    110
# 2       KLFIGGLSFETTDESLR/4  0.280  0.007   [2]      0   0.254    163
# 3     MDSFDEDLARPSGLLAQER/2  0.167  0.069   [2]      0   0.007     76
# 4            QLAVQSLAFNLK/2  0.244  0.005   [2]      0   0.493    181
#
#    MeanDot  ...  KSScore  OpModMass  OpModLoc  Status  Inst Spec #Pr  \
# 0    0.075  ...        0          0        ()  Normal   Unk  Unk   0
# ...

# %%
NNd1_1 = pd.read_excel('./target_decoy/HEK/TPRP_EXPAND_coelution/TPRP_EXPAND_1_PIF_01_decoy.xlsx')
NNd1_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.02394.02394.4   1
# 1  b1906_293T_proteinID_01A_QE3_122212.02609.02609.3   1
# 2  b1906_293T_proteinID_01A_QE3_122212.02699.02699.4   1
# 3  b1906_293T_proteinID_01A_QE3_122212.03721.03721.3   1
# 4  b1906_293T_proteinID_01A_QE3_122212.04187.04187.2   1
#
#                          ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  LSC[160]QELDLC[160]SLK/4  0.433  0.134   [2]      0   0.009    470
# 1               NTPSMVHPR/3  0.313  0.010   [2]      0  -0.003    653
# 2            EPASSSLLHAPK/4  0.442  0.046   [2]      0   0.260    277
# 3             QLGAVHVALVR/3  0.282  0.012   [2]      0   0.010     29
# 4         VQASPTASC[160]K/2  0.278  0.034   [2]      0   0.492    411
#
#    MeanDot  ...  KSScore  OpModMass  OpModLoc  Status  Inst Spec #Pr Proteins  \
# 0    0.099  ...        0          0        ()  Normal   Unk  Unk   1     XXX_
# ...

# %%
NNd1_2 = pd.read_excel('./target_decoy/HEK/TPRP_EXPAND_coelution/TPRP_EXPAND_2_PIF_01_decoy.xlsx')
NNd1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55827.55827.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.57123.57123.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.57186.57186.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.58393.58393.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.58644.58644.2   1
#
#                               ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0                  LSVLEEEEKKK/2  0.253  0.000   [2]      0   0.506    188
# 1           AHFTADFSFSEFETAVKK/3  0.193  0.003   [2]      0   0.008    227
# 2  EC[160]TVSC[160]QSWASVLWQLR/3  0.170  0.006   [2]      0   0.330    132
# 3                DPSSQPSYYFNWK/2  0.237  0.031   [3]      0   0.010    118
# 4                 ALPAVQNPLNYR/2  0.323  0.021   [3]      0   0.505    299
#
#    MeanDot  ...  KSScore  OpModMass  OpModLoc  Status  Inst Spec #Pr  \
# 0    0.098  ...        0          0        ()  Normal   Unk  Unk   1
# ...

# %%
NNt3 = list(NNt1_1['Dot']) + list(NNt1_2['Dot'])
NNt3
# Out:
# [0.239,
#  0.553,
#  0.35,
#  0.309,
#  0.606,
#  0.257,
#  0.533,
#  0.413,
#  0.334,
#  0.352,
#  0.39,
#  0.243,
#  0.42,
#  0.36,
#  0.43,
#  0.449,
#  0.314,
#  0.475,
#  0.432,
#  0.44,
#  0.33,
#  0.428,
#  0.553,
#  0.352,
#  0.225,
#  0.291,
#  0.269,
#  0.36,
#  0.283,
#  0.315,
#  0.291,
#  0.419,
#  0.397,
#  0.289,
#  0.317,
#  0.626,
#  0.196,
#  0.644,
#  0.307,
#  0.312,
#  0.221,
#  0.262,
#  0.528,
#  0.287,
#  0.361,
#  0.368,
#  0.455,
#  0.634,
#  0.369,
#  0.253,
#  0.354,
#  0.356,
#  0.363,
#  0.456,
#  0.338,
#  0.501,
#  0.394,
#  0.35,
#  0.331,
#  0.605,
#  0.337,
#  0.603,
#  0.276,
#  0.46,
#  0.39,
#  0.412,
#  0.321,
#  0.375,
#  0.255,
#  0.293,
#  0.517,
#  0.309,
#  0.288,
#  0.51,
#  0.408,
#  0.287,
#  0.558,
#  0.322,
#  0.351,
#  0.375,
#  0.278,
#  0.262,
#  0.323,
#  0.403,
#  0.273,
#  0.419,
#  0.257,
#  0.372,
#  0.547,
#  0.367,
#  0.551,
#  0.537,
#  0.406,
#  0.506,
#  0.562,
#  0.217,
#  0.517,
#  0.446,
#  0.368,
#  0.441,
#  0.363,
# ...

# %%
NNd3 = list(NNd1_1['Dot']) + list(NNd1_2['Dot'])
NNd3
# Out:
# [0.433,
#  0.313,
#  0.442,
#  0.282,
#  0.278,
#  0.264,
#  0.334,
#  0.292,
#  0.259,
#  0.32,
#  0.425,
#  0.263,
#  0.218,
#  0.374,
#  0.318,
#  0.444,
#  0.486,
#  0.344,
#  0.578,
#  0.275,
#  0.303,
#  0.334,
#  0.289,
#  0.329,
#  0.275,
#  0.387,
#  0.267,
#  0.412,
#  0.358,
#  0.307,
#  0.385,
#  0.373,
#  0.388,
#  0.346,
#  0.306,
#  0.247,
#  0.348,
#  0.122,
#  0.162,
#  0.31,
#  0.419,
#  0.352,
#  0.337,
#  0.247,
#  0.134,
#  0.353,
#  0.341,
#  0.334,
#  0.416,
#  0.29,
#  0.4,
#  0.293,
#  0.343,
#  0.303,
#  0.474,
#  0.322,
#  0.397,
#  0.299,
#  0.335,
#  0.227,
#  0.276,
#  0.389,
#  0.268,
#  0.46,
#  0.295,
#  0.214,
#  0.242,
#  0.113,
#  0.301,
#  0.44,
#  0.332,
#  0.305,
#  0.314,
#  0.268,
#  0.236,
#  0.366,
#  0.362,
#  0.314,
#  0.474,
#  0.507,
#  0.379,
#  0.317,
#  0.271,
#  0.297,
#  0.393,
#  0.312,
#  0.265,
#  0.356,
#  0.286,
#  0.492,
#  0.46,
#  0.337,
#  0.347,
#  0.319,
#  0.333,
#  0.37,
#  0.516,
#  0.257,
#  0.257,
#  0.286,
#  0.28,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('TPRP_EXPAND PIF 0~0.1: HEK')
plt.plot(nnt3[1][:-1] + 0.0075, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.show()
# Out:
# 0.015919999999999997
# 0.01432

# %%
print(len(NNt3))
print(len(NNd3))
# Out:
# 11637
# 7534

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.6750000000000005
nnt:  192
nnd:  1
FDR:  0.005208333333333333
"""
# Out:
# score:  0.001
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.002
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.003
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.004
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.005
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.006
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.007
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.008
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.009000000000000001
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.010000000000000002
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.011000000000000003
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.012000000000000004
# nnt:  11637
# nnd:  7534
# FDR:  0.6474177193434734
#
#
# score:  0.013000000000000005
# nnt:  11637
# ...
