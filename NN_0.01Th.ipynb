# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1 = pd.read_excel('./0725/0.01Th/NN_target_0.005.xlsx')
NNt1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1     RDPNNYRPR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1      VVYRPHGR/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1      HESGASIK/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.351  0.0567   [2]      0  0.0097    104    0.134  ...      -1        0
# 1  0.242  0.0230   [2]      0  0.3340     66    0.112  ...      -1        0
# 2  0.283  0.0200   [2]      0 -0.0010     66    0.112  ...      -1        0
# 3  0.877  0.4170   [2]      0 -0.0010      6    0.394  ...      -1        0
# 4  0.917  0.5650   [2]      0 -0.0020    104    0.140  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd1 = pd.read_excel('./0725/0.01Th/NN_decoy_0.005.xlsx')
NNd1.head()
# Out:
#                                            ### Query  Rk                ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1  PMQHHGAVPGPRGR/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1    FDLHEILVYGYK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1        KHSEEHSE/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01941.01941.2   1      VDLGDDVTHR/2
# 4  b1906_293T_proteinID_01A_QE3_122212.01942.01942.3   1   IESEVIPIEGLSK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.317  0.106   [2]      0   0.002     16    0.145  ...      -1        0
# 1  0.242  0.011   [2]      0  -0.001    110    0.110  ...      -1        0
# 2  0.289  0.034   [2]      0   0.327      4    0.229  ...      -1        0
# 3  0.151  0.012   [2]      0   0.507    125    0.043  ...      -1        0
# 4  0.344  0.010   [2]      0   0.005     68    0.156  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
nnt1 = plt.hist(NNt1['Dot'], bins = 50)
nnd1 = plt.hist(NNd1['Dot'], bins = 50)

# %%
print(nnt1[1][1] - nnt1[1][0])
print(nnd1[1][1] - nnd1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget + Ndecoy delta > 0.005')
plt.plot(nnt1[1][:-1] + 0.0095, nnt1[0])
plt.plot(nnd1[1][:-1] + 0.0085, nnd1[0])
plt.show()
# Out:
# 0.01952
# 0.017879999999999997

# %%
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget + Ndecoy delta 0.005 >')
plt.show()

# %%
NNt2 = pd.read_excel('./0725/0.01Th/NN_target_0.01.xlsx')
NNt2.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1     RDPNNYRPR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1      VVYRPHGR/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1      HESGASIK/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.351  0.0567   [2]      0  0.0097    104    0.134  ...      -1        0
# 1  0.242  0.0230   [2]      0  0.3340     66    0.112  ...      -1        0
# 2  0.283  0.0200   [2]      0 -0.0010     66    0.112  ...      -1        0
# 3  0.877  0.4170   [2]      0 -0.0010      6    0.394  ...      -1        0
# 4  0.917  0.5650   [2]      0 -0.0020    104    0.140  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd2 = pd.read_excel('./0725/0.01Th/NN_decoy_0.01.xlsx')
NNd2.head()
# Out:
#                                            ### Query  Rk                ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1  PMQHHGAVPGPRGR/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1    FDLHEILVYGYK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1        KHSEEHSE/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01941.01941.2   1      VDLGDDVTHR/2
# 4  b1906_293T_proteinID_01A_QE3_122212.01955.01955.2   1      VEGNQNIQYR/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.317  0.106   [2]      0   0.002     16    0.145  ...      -1        0
# 1  0.242  0.011   [2]      0  -0.001    110    0.110  ...      -1        0
# 2  0.289  0.034   [2]      0   0.327      4    0.229  ...      -1        0
# 3  0.151  0.012   [2]      0   0.507    125    0.043  ...      -1        0
# 4  0.439  0.027   [2]      0   0.003    121    0.188  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
nnt2 = plt.hist(NNt2['Dot'], bins = 50)
nnd2 = plt.hist(NNd2['Dot'], bins = 50)

# %%
print(nnt2[1][1] - nnt2[1][0])
print(nnd2[1][1] - nnd2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget + Ndecoy delta > 0.01')
plt.plot(nnt2[1][:-1] + 0.0095, nnt2[0])
plt.plot(nnd2[1][:-1] + 0.0085, nnd2[0])
plt.show()
# Out:
# 0.01952
# 0.017879999999999997

# %%
NNt3 = pd.read_excel('./0725/0.01Th/NN_target_0.05.xlsx')
NNt3.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1     RDPNNYRPR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.351  0.0567   [2]      0  0.0097    104    0.134  ...      -1        0
# 1  0.877  0.4170   [2]      0 -0.0010      6    0.394  ...      -1        0
# 2  0.917  0.5650   [2]      0 -0.0020    104    0.140  ...      -1        0
# 3  0.887  0.4520   [2]      0 -0.0030     28    0.137  ...      -1        0
# 4  0.921  0.6080   [2]      0 -0.0020      4    0.441  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd3 = pd.read_excel('./0725/0.01Th/NN_decoy_0.05.xlsx')
NNd3.head()
# Out:
#                                            ### Query  Rk                   ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1     PMQHHGAVPGPRGR/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01966.01966.2   1           AAVNVLGK/2
# 2  b1906_293T_proteinID_01A_QE3_122212.01967.01967.3   1      PQPGMELPAHQVR/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01991.01991.3   1  SSLNEPKTASDAADEVK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01998.01998.4   1        QIEKNEAFVKK/4
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.317  0.106   [2]      0   0.002     16    0.145  ...      -1        0
# 1  0.462  0.085   [2]      0  -0.001     52    0.249  ...      -1        0
# 2  0.307  0.068   [2]      0   0.001    138    0.101  ...      -1        0
# 3  0.342  0.118   [2]      0   0.330     53    0.068  ...      -1        0
# 4  0.159  0.123   [2]      0   0.004      2    0.097  ...      -1        0
#
# ...

# %%
nnt3 = plt.hist(NNt3['Dot'], bins = 50)
nnd3 = plt.hist(NNd3['Dot'], bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget + Ndecoy delta > 0.05')
plt.plot(nnt3[1][:-1] + 0.009, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.0085, nnd3[0])
plt.show()
# Out:
# 0.01892
# 0.017279999999999997

# %%
NNt4 = pd.read_excel('./0725/0.01Th/NN_target_0.1.xlsx')
NNt4.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01914.01914.3   1   SRPETGRPRPK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.877  0.417   [2]      0  -0.001      6    0.394  ...      -1        0
# 1  0.917  0.565   [2]      0  -0.002    104    0.140  ...      -1        0
# 2  0.887  0.452   [2]      0  -0.003     28    0.137  ...      -1        0
# 3  0.921  0.608   [2]      0  -0.002      4    0.441  ...      -1        0
# 4  0.566  0.165   [2]      0  -0.002     84    0.185  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd4 = pd.read_excel('./0725/0.01Th/NN_decoy_0.1.xlsx')
NNd4.head()
# Out:
#                                            ### Query  Rk                   ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1     PMQHHGAVPGPRGR/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01991.01991.3   1  SSLNEPKTASDAADEVK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01998.01998.4   1        QIEKNEAFVKK/4
# 3  b1906_293T_proteinID_01A_QE3_122212.02028.02028.3   1   NQNWDHADGLQNVNYR/3
# 4  b1906_293T_proteinID_01A_QE3_122212.02065.02065.2   1        LQHQFQDHLDR/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.317  0.106   [2]      0   0.002     16    0.145  ...      -1        0
# 1  0.342  0.118   [2]      0   0.330     53    0.068  ...      -1        0
# 2  0.159  0.123   [2]      0   0.004      2    0.097  ...      -1        0
# 3  0.332  0.270   [2]      0   0.000     16    0.049  ...      -1        0
# 4  0.360  0.123   [2]      0   0.508    102    0.061  ...      -1        0
#
# ...

# %%
nnt4 = plt.hist(NNt4['Dot'], bins = 50)
nnd4 = plt.hist(NNd4['Dot'], bins = 50)

# %%
print(nnt4[1][1] - nnt4[1][0])
print(nnd4[1][1] - nnd4[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget + Ndecoy delta > 0.1')
plt.plot(nnt4[1][:-1] + 0.0085, nnt4[0])
plt.plot(nnd4[1][:-1] + 0.008, nnd4[0])
plt.show()
# Out:
# 0.017879999999999993
# 0.016280000000000003

# %%
print(len(NNt1))
print(len(NNd1))

print(len(NNt2))
print(len(NNd2))

print(len(NNt3))
print(len(NNd3))

print(len(NNt4))
print(len(NNd4))
# Out:
# 620975
# 309735
# 578705
# 272074
# 373276
# 23785
# 285348
# 23785

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget')
plt.plot(nnt1[1][:-1] + 0.0095, nnt1[0])
plt.plot(nnt2[1][:-1] + 0.0095, nnt2[0])
plt.plot(nnt3[1][:-1] + 0.009, nnt3[0])
plt.plot(nnt4[1][:-1] + 0.0085, nnt4[0])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ndecoy')
plt.plot(nnd1[1][:-1] + 0.0085, nnd1[0])
plt.plot(nnd2[1][:-1] + 0.0085, nnd2[0])
plt.plot(nnd3[1][:-1] + 0.0085, nnd3[0])
plt.plot(nnd4[1][:-1] + 0.008, nnd4[0])
plt.show()

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt1['Dot'] >= score
    nnt = NNt1[nntarget]
    
    nndecoy = NNd1['Dot'] >= score
    nnd = NNd1[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.6150000000000004

nnt:  216358
nnd:  2132

FDR:  0.00985403821444088
"""
# Out:
# score:  0.001
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.002
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.003
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.004
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.005
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.006
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.007
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.008
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.009000000000000001
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.010000000000000002
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.011000000000000003
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# score:  0.012000000000000004
# nnt:  620975
# nnd:  309735
# FDR:  0.49878819598212487
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt2['Dot'] >= score
    nnt = NNt2[nntarget]
    
    nndecoy = NNd2['Dot'] >= score
    nnd = NNd2[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.6140000000000004

nnt:  216718
nnd:  2133

FDR:  0.009842283520519754
"""
# Out:
# score:  0.001
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.002
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.003
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.004
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.005
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.006
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.007
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.008
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.009000000000000001
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.010000000000000002
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.011000000000000003
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# score:  0.012000000000000004
# nnt:  578705
# nnd:  272074
# FDR:  0.4701428188800857
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt3['Dot'] >= score
    nnt = NNt3[nntarget]
    
    nndecoy = NNd3['Dot'] >= score
    nnd = NNd3[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.5640000000000004

nnt:  233739
nnd:  2321

FDR:  0.009929879053131913
"""
# Out:
# score:  0.001
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.002
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.003
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.004
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.005
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.006
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.007
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.008
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.009000000000000001
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.010000000000000002
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.011000000000000003
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# score:  0.012000000000000004
# nnt:  373276
# nnd:  23785
# FDR:  0.06371960693963716
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt4['Dot'] >= score
    nnt = NNt4[nntarget]
    
    nndecoy = NNd4['Dot'] >= score
    nnd = NNd4[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.5650000000000004

nnt:  230052
nnd:  2294

FDR:  0.009971658581538086
"""
# Out:
# score:  0.001
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.002
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.003
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.004
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.005
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.006
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.007
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.008
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.009000000000000001
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.010000000000000002
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.011000000000000003
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# score:  0.012000000000000004
# nnt:  285348
# nnd:  23785
# FDR:  0.08335436028989164
#
#
# ...

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget + Ndecoy 0.01Th')
plt.plot(nnt1[1][:-1] + 0.0095, nnt1[0])
plt.plot(nnt2[1][:-1] + 0.0095, nnt2[0])
plt.plot(nnt3[1][:-1] + 0.009, nnt3[0])
plt.plot(nnt4[1][:-1] + 0.0085, nnt4[0])

plt.plot(nnd1[1][:-1] + 0.0085, nnd1[0])
plt.plot(nnd2[1][:-1] + 0.0085, nnd2[0])
plt.plot(nnd3[1][:-1] + 0.0085, nnd3[0])
plt.plot(nnd4[1][:-1] + 0.008, nnd4[0])
plt.show()
