# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./target_decoy/HEK/NRP_1_target.xlsx')
NNt1_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1     RDPNNYRPR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1      VVYRPHGR/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1      HESGASIK/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.351  0.0465   [2]      0  0.0097    109    0.113  ...      -1        0
# 1  0.242  0.0280   [2]      0  0.3340     62    0.095  ...      -1        0
# 2  0.283  0.0200   [2]      0 -0.0010     64    0.099  ...      -1        0
# 3  0.877  0.5320   [2]      0 -0.0010     10    0.230  ...      -1        0
# 4  0.917  0.5650   [2]      0 -0.0020    125    0.123  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr Proteins  LibFileOffset
# ...

# %%
NNt1_2 = pd.read_excel('./target_decoy/HEK/NRP_2_target.xlsx')
NNt1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55759.55759.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55762.55762.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55764.55764.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55766.55766.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55771.55771.3   1
#
#                            ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0       C[160]M[147]PTFQFFK/2  0.555  0.155   [2]      0   0.000     99
# 1            TPVTQVNEVTGTLR/2  0.201  0.002   [2]      0  -0.004     99
# 2  QREEYQPATPGLGMFVEVKDPEDK/3  0.867  0.625   [2]      0   0.339     43
# 3         TQLEELEDELQATEDAK/2  0.240  0.058   [2]      0  -0.003     38
# 4        LYSSSDDVIELTPSNFNR/3  0.869  0.442   [2]      0   0.002     73
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.132  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_1 = pd.read_excel('./target_decoy/HEK/NRP_1_decoy.xlsx')
NNd1_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01911.01911.3   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01913.01913.2   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1
# 3  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1
# 4  b1906_293T_proteinID_01A_QE3_122212.01943.01943.2   1
#
#                               ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0  AEDSNEQC[160]QVPHEDSSTEPEVK/3  0.151  0.070   [2]      0   0.008      8
# 1              PDALIGC[160]ENK/2  0.276  0.014   [2]      0   0.494    103
# 2                PERGTSLAHLEMR/4  0.381  0.182   [2]      0   0.003     20
# 3                 EERLNETDIHLK/3  0.277  0.062   [2]      0   0.001    126
# 4                    YYPSGSLVK/2  0.232  0.026   [2]      0  -0.005    146
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.054  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_2 = pd.read_excel('./target_decoy/HEK/NRP_2_decoy.xlsx')
NNd1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55765.55765.2   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55767.55767.3   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55768.55768.2   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55775.55775.2   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55776.55776.2   1
#
#                              ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0   ETGDPLGC[160]VYTPLM[147]K/2  0.284  0.046   [2]      0  -0.002     75
# 1  IPC[160]DFTEHFEEGSYLGFVQVK/3  0.274  0.043   [2]      0   0.004     47
# 2               GSPAYTQTLGEQR/2  0.238  0.014   [2]      0   0.503    195
# 3    C[160]PEC[160]TSSMSASEYK/2  0.135  0.052   [2]      0   0.000      2
# 4  GQGFC[160]TC[160]NLMHGEEHR/2  0.074  0.034   [2]      0   0.501      4
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.071  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNt3 = list(NNt1_1['Dot']) + list(NNt1_2['Dot'])
NNt3
# Out:
# [0.351,
#  0.242,
#  0.283,
#  0.877,
#  0.917,
#  0.887,
#  0.921,
#  0.566,
#  0.691,
#  0.256,
#  0.29,
#  0.245,
#  0.469,
#  0.139,
#  0.268,
#  0.237,
#  0.527,
#  0.44,
#  0.185,
#  0.334,
#  0.454,
#  0.47,
#  0.323,
#  0.372,
#  0.709,
#  0.335,
#  0.221,
#  0.452,
#  0.244,
#  0.213,
#  0.226,
#  0.834,
#  0.501,
#  0.174,
#  0.263,
#  0.213,
#  0.155,
#  0.234,
#  0.177,
#  0.17,
#  0.503,
#  0.24,
#  0.169,
#  0.136,
#  0.312,
#  0.076,
#  0.302,
#  0.302,
#  0.276,
#  0.317,
#  0.303,
#  0.395,
#  0.438,
#  0.148,
#  0.197,
#  0.263,
#  0.233,
#  0.196,
#  0.101,
#  0.298,
#  0.374,
#  0.212,
#  0.266,
#  0.329,
#  0.243,
#  0.209,
#  0.294,
#  0.758,
#  0.352,
#  0.283,
#  0.897,
#  0.185,
#  0.296,
#  0.315,
#  0.364,
#  0.325,
#  0.883,
#  0.976,
#  0.784,
#  0.517,
#  0.298,
#  0.329,
#  0.792,
#  0.283,
#  0.591,
#  0.261,
#  0.308,
#  0.637,
#  0.6,
#  0.21,
#  0.399,
#  0.345,
#  0.283,
#  0.424,
#  0.347,
#  0.356,
#  0.24,
#  0.879,
#  0.215,
#  0.245,
# ...

# %%
NNd3 = list(NNd1_1['Dot']) + list(NNd1_2['Dot'])
NNd3
# Out:
# [0.151,
#  0.276,
#  0.381,
#  0.277,
#  0.232,
#  0.285,
#  0.227,
#  0.426,
#  0.218,
#  0.046,
#  0.285,
#  0.334,
#  0.39,
#  0.207,
#  0.26,
#  0.159,
#  0.068,
#  0.227,
#  0.166,
#  0.158,
#  0.176,
#  0.248,
#  0.294,
#  0.289,
#  0.247,
#  0.293,
#  0.153,
#  0.146,
#  0.283,
#  0.309,
#  0.235,
#  0.253,
#  0.226,
#  0.227,
#  0.142,
#  0.177,
#  0.294,
#  0.237,
#  0.235,
#  0.124,
#  0.259,
#  0.123,
#  0.339,
#  0.287,
#  0.305,
#  0.299,
#  0.213,
#  0.241,
#  0.344,
#  0.249,
#  0.276,
#  0.249,
#  0.235,
#  0.189,
#  0.239,
#  0.269,
#  0.285,
#  0.253,
#  0.292,
#  0.301,
#  0.236,
#  0.292,
#  0.303,
#  0.24,
#  0.277,
#  0.353,
#  0.286,
#  0.291,
#  0.268,
#  0.219,
#  0.252,
#  0.328,
#  0.288,
#  0.293,
#  0.308,
#  0.296,
#  0.179,
#  0.414,
#  0.316,
#  0.356,
#  0.175,
#  0.215,
#  0.306,
#  0.344,
#  0.306,
#  0.346,
#  0.244,
#  0.324,
#  0.282,
#  0.327,
#  0.093,
#  0.228,
#  0.292,
#  0.34,
#  0.343,
#  0.255,
#  0.364,
#  0.255,
#  0.315,
#  0.341,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('NRP: HEK')
plt.plot(nnt3[1][:-1] + 0.0095, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.show()
# Out:
# 0.01954
# 0.014299999999999997

# %%
print(len(NNt3))
print(len(NNd3))
# Out:
# 917718
# 134030

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.46700000000000036
nnt:  399539
nnd:  3991
FDR:  0.009989012336718067
"""
# Out:
# score:  0.001
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.002
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.003
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.004
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.005
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.006
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.007
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.008
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.009000000000000001
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.010000000000000002
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.011000000000000003
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# score:  0.012000000000000004
# nnt:  917718
# nnd:  134030
# FDR:  0.14604704277348815
#
#
# ...
