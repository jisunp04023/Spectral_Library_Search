# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_target.xlsx')
NNt1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1      RYPAHLAR/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.374  0.0582   [2]      0   0.330     84   0.0949  ...      -1        0
# 1  0.157  0.0210   [2]      0   0.334     35   0.0670  ...      -1        0
# 2  0.479  0.1990   [2]      0  -0.002     85   0.0930  ...      -1        0
# 3  0.579  0.2430   [2]      0  -0.003     19   0.1080  ...      -1        0
# 4  0.611  0.4520   [2]      0  -0.002      4   0.2180  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd1 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_decoy.xlsx')
NNd1.head()
# Out:
#                                            ### Query  Rk               ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1        HSGPFQR/2
# 1  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  PRHNGFEGPALVK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01913.01913.2   1      PWDDLDLSR/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1  PERGTSLAHLEMR/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1   EERLNETDIHLK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.231  0.089   [2]      0   0.004     30    0.064  ...      -1        0
# 1  0.168  0.043   [2]      0  -0.002      5    0.103  ...      -1        0
# 2  0.184  0.022   [2]      0   0.495     48    0.056  ...      -1        0
# 3  0.381  0.182   [2]      0   0.003     12    0.098  ...      -1        0
# 4  0.277  0.074   [2]      0   0.001     97    0.074  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
nnt1 = plt.hist(NNt1['Dot'], bins = 50)
nnd1 = plt.hist(NNd1['Dot'], bins = 50)

# %%
print(nnt1[1][1] - nnt1[1][0])
print(nnd1[1][1] - nnd1[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + reDecoy_predicted delta > 0')
plt.plot(nnt1[1][:-1] + 0.0085, nnt1[0])
plt.plot(nnd1[1][:-1] + 0.0075, nnd1[0])
plt.show()
# Out:
# 0.01796
# 0.01524

# %%
NNt2 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_target_0.01.xlsx')
NNt2.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1      RYPAHLAR/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.374  0.0582   [2]      0   0.330     84   0.0949  ...      -1        0
# 1  0.157  0.0210   [2]      0   0.334     35   0.0670  ...      -1        0
# 2  0.479  0.1990   [2]      0  -0.002     85   0.0930  ...      -1        0
# 3  0.579  0.2430   [2]      0  -0.003     19   0.1080  ...      -1        0
# 4  0.611  0.4520   [2]      0  -0.002      4   0.2180  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd2 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_decoy_0.01.xlsx')
NNd2.head()
# Out:
#                                            ### Query  Rk               ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1        HSGPFQR/2
# 1  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  PRHNGFEGPALVK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01913.01913.2   1      PWDDLDLSR/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1  PERGTSLAHLEMR/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1   EERLNETDIHLK/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.231  0.089   [2]      0   0.004     30    0.064  ...      -1        0
# 1  0.168  0.043   [2]      0  -0.002      5    0.103  ...      -1        0
# 2  0.184  0.022   [2]      0   0.495     48    0.056  ...      -1        0
# 3  0.381  0.182   [2]      0   0.003     12    0.098  ...      -1        0
# 4  0.277  0.074   [2]      0   0.001     97    0.074  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
nnt2 = plt.hist(NNt2['Dot'], bins = 50)
nnd2 = plt.hist(NNd2['Dot'], bins = 50)

# %%
print(nnt2[1][1] - nnt2[1][0])
print(nnd2[1][1] - nnd2[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + reDecoy_predicted delta > 0.01')
plt.plot(nnt2[1][:-1] + 0.0085, nnt2[0])
plt.plot(nnd2[1][:-1] + 0.0075, nnd2[0])
plt.show()
# Out:
# 0.017940000000000005
# 0.01524

# %%
NNt3 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_target_0.05.xlsx')
NNt3.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
# 4  b1906_293T_proteinID_01A_QE3_122212.01917.01917.2   1   HGGYKPSDEHK/2
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.374  0.0582   [2]      0   0.330     84   0.0949  ...      -1        0
# 1  0.479  0.1990   [2]      0  -0.002     85   0.0930  ...      -1        0
# 2  0.579  0.2430   [2]      0  -0.003     19   0.1080  ...      -1        0
# 3  0.611  0.4520   [2]      0  -0.002      4   0.2180  ...      -1        0
# 4  0.772  0.4010   [2]      0  -0.003     63   0.0750  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd3 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_decoy_0.05.xlsx')
NNd3.head()
# Out:
#                                            ### Query  Rk               ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1        HSGPFQR/2
# 1  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1  PERGTSLAHLEMR/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1   EERLNETDIHLK/3
# 3  b1906_293T_proteinID_01A_QE3_122212.01934.01934.3   1       KHSEEHSE/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01943.01943.2   1      YYPSGSLVK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.231  0.089   [2]      0   0.004     30    0.064  ...      -1        0
# 1  0.381  0.182   [2]      0   0.003     12    0.098  ...      -1        0
# 2  0.277  0.074   [2]      0   0.001     97    0.074  ...      -1        0
# 3  0.168  0.090   [2]      0   0.327      4    0.070  ...      -1        0
# 4  0.232  0.072   [2]      0  -0.005     70    0.056  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
nnt3 = plt.hist(NNt3['Dot'], bins = 50)
nnd3 = plt.hist(NNd3['Dot'], bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + reDecoy_predicted delta > 0.05')
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.show()
# Out:
# 0.017360000000000007
# 0.014640000000000007

# %%
NNt4 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_target_0.1.xlsx')
NNt4.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01910.01910.4   1   HGGYKPSDEHK/4
# 3  b1906_293T_proteinID_01A_QE3_122212.01917.01917.2   1   HGGYKPSDEHK/2
# 4  b1906_293T_proteinID_01A_QE3_122212.01956.01956.2   1  DGNLASTLGQHK/2
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.479  0.199   [2]      0  -0.002     85    0.093  ...      -1        0
# 1  0.579  0.243   [2]      0  -0.003     19    0.108  ...      -1        0
# 2  0.611  0.452   [2]      0  -0.002      4    0.218  ...      -1        0
# 3  0.772  0.401   [2]      0  -0.003     63    0.075  ...      -1        0
# 4  0.342  0.135   [2]      0   0.003     87    0.066  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
NNd4 = pd.read_excel('./delta_cutoff/0.01Th(NFRP)/NFRP(0.01Th)_decoy_0.1.xlsx')
NNd4.head()
# Out:
#                                            ### Query  Rk                  ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1     PERGTSLAHLEMR/4
# 1  b1906_293T_proteinID_01A_QE3_122212.01959.01959.4   1       HHVIEEEHHKK/4
# 2  b1906_293T_proteinID_01A_QE3_122212.01966.01966.2   1          AAVNVLGK/2
# 3  b1906_293T_proteinID_01A_QE3_122212.01968.01968.2   1           VSGDAIK/2
# 4  b1906_293T_proteinID_01A_QE3_122212.02028.02028.3   1  NQNWDHADGLQNVNYR/3
#
#      Dot  Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.381  0.182   [2]      0   0.003     12    0.098  ...      -1        0
# 1  0.438  0.196   [2]      0  -0.001      9    0.172  ...      -1        0
# 2  0.426  0.174   [2]      0  -0.001     29    0.119  ...      -1        0
# 3  0.181  0.127   [2]      0  -0.004      3    0.094  ...      -1        0
# 4  0.294  0.185   [2]      0   0.000      7    0.087  ...      -1        0
#
#    OpModMass  OpModLoc  Status Inst Spec #Pr  \
# ...

# %%
nnt4 = plt.hist(NNt4['Dot'], bins = 50)
nnd4 = plt.hist(NNd4['Dot'], bins = 50)

# %%
print(nnt4[1][1] - nnt4[1][0])
print(nnd4[1][1] - nnd4[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + reDecoy_predicted delta > 0.1')
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()
# Out:
# 0.016340000000000007
# 0.01364

# %%
print(len(NNt1))
print(len(NNd1))

print(len(NNt2))
print(len(NNd2))

print(len(NNt3))
print(len(NNd3))

print(len(NNt4))
print(len(NNd4))
# Out:
# 560465
# 466141
# 489986
# 361242
# 328432
# 137357
# 252702
# 40438

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered')
plt.plot(nnt1[1][:-1] + 0.0085, nnt1[0])
plt.plot(nnt2[1][:-1] + 0.0085, nnt2[0])
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])
plt.show()

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('reDecoy_predicted')
plt.plot(nnd1[1][:-1] + 0.0075, nnd1[0])
plt.plot(nnd2[1][:-1] + 0.0075, nnd2[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt1['Dot'] >= score
    nnt = NNt1[nntarget]
    
    nndecoy = NNd1['Dot'] >= score
    nnd = NNd1[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.5270000000000004
nnt:  183927
nnd:  1805
FDR:  0.00981367607800921
"""
# Out:
# score:  0.001
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.002
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.003
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.004
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.005
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.006
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.007
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.008
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.009000000000000001
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.010000000000000002
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.011000000000000003
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# score:  0.012000000000000004
# nnt:  560465
# nnd:  466141
# FDR:  0.8317040314738654
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt2['Dot'] >= score
    nnt = NNt2[nntarget]
    
    nndecoy = NNd2['Dot'] >= score
    nnd = NNd2[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.5250000000000004
nnt:  184722
nnd:  1832
FDR:  0.009917605915916892
"""
# Out:
# score:  0.001
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.002
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.003
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.004
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.005
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.006
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.007
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.008
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.009000000000000001
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.010000000000000002
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.011000000000000003
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# score:  0.012000000000000004
# nnt:  489986
# nnd:  361242
# FDR:  0.7372496357038772
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt3['Dot'] >= score
    nnt = NNt3[nntarget]
    
    nndecoy = NNd3['Dot'] >= score
    nnd = NNd3[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.5210000000000004
nnt:  186029
nnd:  1830
FDR:  0.009837175924183863
"""
# Out:
# score:  0.001
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.002
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.003
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.004
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.005
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.006
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.007
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.008
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.009000000000000001
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.010000000000000002
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.011000000000000003
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# score:  0.012000000000000004
# nnt:  328432
# nnd:  137357
# FDR:  0.4182205144443903
#
#
# ...

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ' , score)
    
    nntarget = NNt4['Dot'] >= score
    nnt = NNt4[nntarget]
    
    nndecoy = NNd4['Dot'] >= score
    nnd = NNd4[nndecoy]
    
    print('nnt: ', len(nnt))
    print('nnd: ', len(nnd))
    print('FDR: ', len(nnd) / len(nnt))
    print('\n')
    
    if (len(nnd) / len(nnt)) <= 0.01:
        print(len(nnd))
        print(len(nnt))
        print(len(nnd) / len(nnt))
        print(score)
        break
"""
결과
score:  0.5090000000000003
nnt:  189729
nnd:  1889
FDR:  0.009956306099752805
"""
# Out:
# score:  0.001
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.002
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.003
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.004
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.005
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.006
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.007
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.008
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.009000000000000001
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.010000000000000002
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.011000000000000003
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# score:  0.012000000000000004
# nnt:  252702
# nnd:  40438
# FDR:  0.16002247706785067
#
#
# ...

# %%
plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('Ntarget_filtered + reDecoy_predicted 0.01Th')
plt.plot(nnt1[1][:-1] + 0.0085, nnt1[0])
plt.plot(nnt2[1][:-1] + 0.0085, nnt2[0])
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnt4[1][:-1] + 0.008, nnt4[0])

plt.plot(nnd1[1][:-1] + 0.0075, nnd1[0])
plt.plot(nnd2[1][:-1] + 0.0075, nnd2[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.plot(nnd4[1][:-1] + 0.0065, nnd4[0])
plt.show()
