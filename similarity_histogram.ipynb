# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NT = []

file = open("Similarity_NT2.txt", "r")
while True:
    line = file.readline()
    if not line: break
    if not line == "\n":
        NT.append(float(line[:-1]))
file.close()

# %%
print(NT)
# Out:
# [0.41525769867120094, 0.5661859425516175, 0.484482517351495, 0.35152523240351913, 0.260763296257318, 0.3628815249782298, 0.2859371093789382, 0.43763397558160944, 0.5152688648534821, 0.4504466007688807, 0.5805073121167428, 0.2969213858458162, 0.3916153542175079, 0.6163204364926888, 0.405192544003345, 0.3221417549545447, 0.5984614966095553, 0.3249353118096468, 0.26820487340312305, 0.3852501517307773, 0.31649615261650643, 0.23345061186603894, 0.23286112222661504, 0.27255227330439175, 0.5274250364766986, 0.26583892211891885, 0.33961589781452795, 0.3543226292122081, 0.24327220457813556, 0.25353661245215, 0.28932689902208303, 0.32202637552209135, 0.4400770180717755, 0.32489435994231974, 0.2952749862089926, 0.26387313912849986, 0.23987811553619365, 0.25587935525258665, 0.21301854932512626, 0.24079785774620382, 0.3066711373409466, 0.4144154368467585, 0.3981880859403984, 0.36991072634832123, 0.28217857567404675, 0.30967533095935523, 0.34754263194219764, 0.38099476808121474, 0.2418781330404180
# ...

# %%
#plt.figure(figsize=(10,10))
plt.title('Ntarget')
plt.hist(NT, bins = 50, alpha = 1.0)
plt.plot(tmp[1][:-1]+0.009,tmp[0])
plt.show()

# %%
tmp = plt.hist(NT,bins=50)

# %%
tmp[0]
# Out:
# array([1.58724e+05, 2.47084e+05, 2.83342e+05, 3.04275e+05, 3.17027e+05,
#        3.28050e+05, 3.39488e+05, 3.51894e+05, 3.62338e+05, 3.68375e+05,
#        3.69811e+05, 3.60921e+05, 3.40995e+05, 3.12165e+05, 2.76361e+05,
#        2.36024e+05, 1.95110e+05, 1.54755e+05, 1.19342e+05, 8.88130e+04,
#        6.41730e+04, 4.47730e+04, 3.04200e+04, 2.03830e+04, 1.32590e+04,
#        8.53500e+03, 5.51300e+03, 3.48100e+03, 2.29800e+03, 1.54800e+03,
#        9.88000e+02, 6.87000e+02, 4.84000e+02, 3.62000e+02, 2.66000e+02,
#        2.10000e+02, 1.73000e+02, 1.16000e+02, 8.00000e+01, 6.10000e+01,
#        5.00000e+01, 3.30000e+01, 2.30000e+01, 1.40000e+01, 1.20000e+01,
#        6.00000e+00, 2.00000e+00, 2.00000e+00, 0.00000e+00, 2.00000e+00])

# %%
tmp[1][1]-tmp[1][0]
# Out:
# 0.018049932679365208

# %%
ND = []

file = open("Similarity_ND.txt", "r")
while True:
    line = file.readline()
    if not line: break
    if not line == "\n":
        ND.append(float(line[:-1]))
file.close()

# %%
tmp2 = plt.hist(ND,bins=50)

# %%
tmp2[1][1]-tmp2[1][0]
# Out:
# 0.017725620016846234

# %%
plt.title('Ndecoy')
plt.hist(ND, bins = 50, alpha = 1.0)
plt.plot(tmp2[1][:-1]+0.008, tmp2[0])
plt.show()

# %%
PT = []

file = open("Similarity_PT.txt", "r")
while True:
    line = file.readline()
    if not line: break
    if not line == "\n":
        PT.append(float(line[:-1]))
file.close()

# %%
tmp3 = plt.hist(PT,bins=50)

# %%
tmp3[1][1]-tmp3[1][0]
# Out:
# 0.019761790848989425

# %%
plt.title('Ptarget')
plt.hist(PT, bins = 50, alpha = 1.0)
plt.plot(tmp3[1][:-1]+0.009, tmp3[0])
plt.show()

# %%
PD = []

file = open("Similarity_PD.txt", "r")
while True:
    line = file.readline()
    if not line: break
    if not line == "\n":
        PD.append(float(line[:-1]))
file.close()

# %%
tmp4 = plt.hist(PD,bins=50)

# %%
tmp4[1][1]-tmp4[1][0]
# Out:
# 0.019875088932396298

# %%
plt.title('Pdecoy')
plt.hist(PD, bins = 50, alpha = 1.0)
plt.plot(tmp4[1][:-1]+0.009, tmp4[0])
plt.show()

# %%
plt.title('Ntarget, Ndecoy')
plt.plot(tmp[1][:-1]+0.009,tmp[0], color = 'blue')
plt.plot(tmp2[1][:-1]+0.008, tmp2[0], color = 'red')
plt.show()

# %%
plt.title('Ptarget, Pdecoy')
plt.plot(tmp3[1][:-1]+0.009, tmp3[0], color = 'blue')
plt.plot(tmp4[1][:-1]+0.009, tmp4[0], color = 'red')
plt.show()
