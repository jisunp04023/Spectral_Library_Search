# %%
with open('Target_predicted__Target_predicted_revDecoy.msp', 'w') as f:
    a = open("Target_predicted_Na.msp")
    b = open("Target_predicted_revDecoy.msp")
    
    while True:
        aline = a.readline()
        
        if not aline: break
        
        f.write(aline)
    
    while True:
        bline = b.readline()
        
        if not bline: break
            
        f.write(bline)

# %%
best = open("Target_predicted__Target_predicted_revDecoy.msp")

for i in range (0, 3000):
    bestline = best.readline()
    print(bestline)

best.close()
# Out:
# Name: AAAAAAAAAAAAAAAGAGAGAK/2
#
# MW: 798.9189858349997
#
# Comment: Parent=798.9189858349997 Collision_energy=29 Mods=0 ModString=AAAAAAAAAAAAAAAGAGAGAK///2 iRT=74.8855209350586 proteotypicity=10.95544719696045
#
# Num peaks: 46
#
# 143.081497	0.062393	"b4^2/0.0ppm, b2/0.0ppm"
#
# 147.112808	0.075095	"y1/0.0ppm"
#
# 178.600067	0.008768	"b5^2/0.0ppm"
#
# 214.118622	0.267019	"b6^2/0.0ppm, b3/0.0ppm"
#
# 218.149918	0.036375	"y2/0.0ppm"
#
# 249.637177	0.023927	"b7^2/0.0ppm"
#
# 275.171387	0.112356	"y3/0.0ppm"
#
# 285.155731	0.462492	"b8^2/0.0ppm, b4/0.0ppm"
#
# 320.674286	0.044954	"b9^2/0.0ppm"
#
# 346.208496	0.102261	"y4/0.0ppm"
#
# 356.192841	0.756568	"b10^2/0.0ppm, b5/0.0ppm"
#
# 391.711395	0.070129	"b11^2/0.0ppm"
#
# 403.229950	0.191162	"y5/0.0ppm"
#
# 427.229950	0.984350	"b12^2/0.0ppm, b6/0.0ppm"
#
# 462.748505	0.040936	"b13^2/0.0ppm"
#
# 474.267059	0.132961	"y6/0.0ppm"
#
# 498.267059	1.025283	"b14^2/0.0ppm, b7/0.0ppm"
#
# 531.288513	0.434355	"y7/0.0ppm"
#
# ...
