# %%
import numpy as np
import pandas as pd
import glob
import sys

# 파일 union
all_data = pd.DataFrame()

for f in glob.glob('C:/2022-2/New_Decoy/BEST/PEAK/PP(3Th)/b1*.xlsx'):
    df = pd.read_excel(f)
    all_data = all_data.append(df, ignore_index=True)

print(all_data.shape)
# Out:
# (1088038, 22)

# %%
all_data.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1
# 3  b1906_293T_proteinID_01A_QE3_122212.01891.01891.2   1
# 4  b1906_293T_proteinID_01A_QE3_122212.01898.01898.2   1
#
#                        ID    Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  \
# 0           LSVEADINGLR/3  0.374  0.0235   [2]      0   0.330   1566   0.0769
# 1             FEAAFGHSK/3  0.242  0.0190   [2]      0  -2.974    475   0.0670
# 2              MAGQFAAK/2  0.405  0.0490   [2]      0   2.503    824   0.0740
# 3  IAELEEEQSQGSTTNSDWMK/2  0.202  0.0020   [2]      0   1.882    297   0.0520
# 4   GAEEEVLVTLSGGAPWGFR/2  0.231  0.0010   [2]      0   0.350    651   0.0530
#
#    ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
#all_data.to_excel('C:/2022-2/New_Decoy/BEST/result/PP(3Th).xlsx', header=True, index=False)

# %%
a = all_data.loc[:544019, :]
b = all_data.loc[544020:, :]
b
# Out:
#                                                  ### Query  Rk  \
# 544020   b1932_293T_proteinID_12A_QE3_122212.53813.53813.2   1
# 544021   b1932_293T_proteinID_12A_QE3_122212.53814.53814.4   1
# 544022   b1932_293T_proteinID_12A_QE3_122212.53816.53816.2   1
# 544023   b1932_293T_proteinID_12A_QE3_122212.53817.53817.2   1
# 544024   b1932_293T_proteinID_12A_QE3_122212.53818.53818.3   1
# ...                                                    ...  ..
# 1088033  b1948_293T_proteinID_12B_QE3_122212.76921.76921.2   1
# 1088034  b1948_293T_proteinID_12B_QE3_122212.76930.76930.2   1
# 1088035  b1948_293T_proteinID_12B_QE3_122212.76941.76941.2   1
# 1088036  b1948_293T_proteinID_12B_QE3_122212.76961.76961.2   1
# 1088037  b1948_293T_proteinID_12B_QE3_122212.76978.76978.2   1
#
#                                        ID    Dot  Delta DelRk  DBias  MzDiff  \
# 544020                         FVMKDDDK/2  0.426  0.012   [2]      0  -1.447
# ...

# %%
a.to_excel('C:/2022-1/New_Decoy/BEST/result/PP(3Th)_1.xlsx', header=True, index=False)
b.to_excel('C:/2022-1/New_Decoy/BEST/result/PP(3Th)_2.xlsx', header=True, index=False)
