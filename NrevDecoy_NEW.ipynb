# %%
f = open('NrevDecoy.msp')

for i in range(1000):
    line = f.readline()
    print(line)
# Out:
# Name: AGAGAGAAAAAAAAAAAAAAAK/2_0
#
# MW: 1597.8526
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.AGAGAGAAAAAAAAAAAAAAAK.Q Charge=2 Parent=798.9263 CE=42.09 NCE=29.43 Q-value=0.0000 Nprot=1 Protein="XXX_sp|P55011|S12A2_HUMAN(pre=R,post=Q)" Nrep=134/200 Theo_mz_diff=1.2ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.1424 Unassigned_20ppm=0.0416 num_unassigned_peaks_20ppm=44 max_unassigned_ab_20ppm=0.41 top_20_num_unassigned_peaks_20ppm=1/20
#
# Num peaks: 117
#
# 101.0708	97764.4	"a2/-1.6ppm"
#
# 110.0712	259243.2	"?"
#
# 116.0704	26069.5	"?"
#
# 120.0806	208924.4	"?"
#
# 129.0656	259764.2	"b2/-2.1ppm"
#
# 129.0657	25535.9	"Int/AG/-1.2ppm,Int/GA/-1.2ppm"
#
# 129.1021	361336.8	"IKD/-1.1ppm,y1-H2O/-1.1ppm"
#
# 130.086	120990.5	"y1-NH3/-1.9ppm"
#
# 136.0754	401263.5	"?"
#
# 141.1019	54146.8	"?"
#
# 147.1125	239262.1	"y1/-2.1ppm"
#
# 155.0811	52239.2	"?"
#
# 169.0969	272722.9	"?"
#
# 173.1282	164845.6	"?"
#
# 175.1187	257521.5	"IKF/-1.4ppm"
#
# 183.149	72741.8	"?"
#
# 200.1025	958104.7	"b3/-1.9ppm"
#
# 201.1054	26387.6	"b3+i/-1.4ppm"
#
# 201.123	103584.8	"y2-NH3/-1.8ppm"
#
# 212.1027	28649.9	"?"
#
# 213.0865	47385.4	"?"
#
# 218.1496	44120.9	"y2/-1.5ppm"
#
# 226.1184	53687.9	"?"
#
# 242.113	40070.1	"?"
#
# 244.1652	50732.7	"?"
#
# 254.1495	363209.3	"y3-H2O-NH3/-1.9ppm"
#
# 257.1238	36446.7	"?"
#
# 257.124	1224329.9	"b4/-1.5ppm,y3-H2O+CO/-1.5ppm"
#
# 258.1271	73896.6	"b4+i/-0.4ppm,y3-H2O+CO+i/-0.4ppm"
#
# 271.1395	19571.4	"?"
#
# 271.1762	293322.1	"y3-H2O/-1.2ppm,a4/-1.2ppm"
#
# 283.1403	32984.4	"?"
#
# 283.1759	28564.5	"?"
#
# 289.1864	242734.1	"y3/-2.1ppm"
#
# 297.1552	20175.3	"?"
#
# 313.1502	95582.2	"?"
#
# 325.1864	775584.9	"y4-H2O-NH3/-1.9ppm"
#
# 326.1898	42391.8	"y4-H2O-NH3+i/-0.1ppm"
#
# 328.1609	1600454.8	"b5/-1.8ppm,y4-H2O+CO/-1.8ppm"
#
# 328.1613	41814.3	"?"
#
# 329.1626	149618.5	"b5+i/-4.8ppm,y4-H2O+CO+i/-4.8ppm"
#
# 342.1762	33653.3	"?"
#
# 342.2127	405507.9	"y4-H2O/-2.5ppm,a5/-2.5ppm"
#
# 354.1762	22267.2	"?"
#
# 357.1884	308594.3	"a6/0.9ppm"
#
# 360.2242	147454.5	"y4/0.0ppm"
#
# 367.1713	27548.3	"?"
#
# 367.1716	25666.3	"b6-H2O/-1.9ppm"
#
# 368.1925	46015.5	"?"
#
# 382.2078	731886	"?"
#
# 383.2103	62534.8	"?"
#
# 384.1872	44375.8	"?"
#
# 385.1823	1773724.2	"b6/-1.5ppm"
#
# 386.1849	230900.2	"b6+i/-2.0ppm"
#
# 428.2269	132956.4	"a7/3.7ppm"
#
# 431.2609	495643.6	"y5/-0.9ppm"
#
# 432.2637	30190.2	"y5+i/-0.7ppm"
#
# 438.2086	29863.6	"?"
#
# 438.2091	73528.3	"b7-H2O/-0.8ppm"
#
# 441.245	61334	"y5-H2O+CO/-1.5ppm"
#
# 453.2448	455874.2	"?"
#
# 454.2491	43076.5	"?"
#
# 456.2194	1568386.1	"b7/-1.3ppm"
#
# 457.222	235075.2	"b7+i/-1.7ppm"
#
# 496.2504	29551.8	"?"
#
# 502.2983	239881.5	"y6/-0.2ppm"
#
# 509.2465	23055	"?"
#
# 509.2466	74590.4	"b8-H2O/-0.0ppm"
#
# 512.282	67415.4	"y6-H2O+CO/-1.5ppm"
#
# 524.2817	231866.9	"?"
#
# 525.2848	22162.9	"?"
#
# 527.2563	1182016.9	"b8/-1.6ppm"
#
# 527.2572	26445.4	"?"
#
# 528.2595	209164.7	"b8+i/-1.0ppm"
#
# 555.2883	61569.5	"?"
#
# 573.3351	741356.3	"y7/-0.6ppm"
#
# 574.3386	87145	"y7+i/0.7ppm"
#
# 580.2824	36950.8	"b9-H2O/-2.1ppm"
#
# 583.3197	37299.4	"y7-H2O+CO/-0.3ppm"
#
# 595.3178	93112.3	"?"
#
# 598.2932	780743.7	"b9/-1.7ppm"
#
# 598.294	28506.8	"?"
#
# 599.2963	146597.5	"b9+i/-1.2ppm"
#
# 626.3245	57194.1	"?"
#
# 644.3718	551164.1	"y8/-1.2ppm"
#
# 645.3749	73691.5	"y8+i/-0.8ppm"
#
# 654.3576	46118.5	"y8-H2O+CO/1.0ppm"
#
# 666.3549	23063.4	"?"
#
# 669.3304	456267.1	"b10/-1.6ppm"
#
# 669.331	27664.2	"?"
#
# 670.3334	90213.5	"b10+i/-1.3ppm"
#
# 697.3611	33964.2	"?"
#
# 715.4087	556586	"y9/-1.6ppm"
#
# 716.4114	95708.4	"y9+i/-1.6ppm"
#
# 725.3928	40435.1	"y9-H2O+CO/-1.9ppm"
#
# 740.3669	18991.8	"?"
#
# 740.3682	237790.1	"b11/-0.5ppm"
#
# 741.3697	35086.5	"b11+i/-2.2ppm"
#
# 786.4466	589662.8	"y10/-0.4ppm"
#
# 787.4497	126578.1	"y10+i/0.1ppm"
#
# 796.4298	26216.7	"y10-H2O+CO/-1.8ppm"
#
# 811.4042	86153.5	"b12/-1.7ppm"
#
# 857.4827	695273.1	"y11/-1.6ppm"
#
# 858.486	161580.1	"y11+i/-0.9ppm"
#
# 928.5199	778338.2	"y12/-1.4ppm"
#
# 929.5222	204507.9	"y12+i/-1.7ppm"
#
# 999.5569	792133.5	"y13/-1.3ppm"
#
# 1000.5593	262896.2	"y13+i/-1.6ppm"
#
# 1070.5943	748903.4	"y14/-0.9ppm"
#
# 1071.5974	250705.6	"y14+i/-0.7ppm"
#
# 1141.6311	611860	"y15/-1.1ppm"
#
# 1142.6336	242145.1	"y15+i/-1.4ppm"
#
# 1212.6682	442693.3	"y16/-1.1ppm"
#
# 1213.671	173247.7	"y16+i/-1.0ppm"
#
# 1269.6893	264065.6	"y17/-1.3ppm"
#
# 1270.6915	112235.1	"y17+i/-1.8ppm"
#
# 1340.7251	74808.5	"y18/-2.3ppm"
#
#
#
# Name: AGAGAGAAAAAAAAAAAAAAAK/3_0
#
# MW: 1598.8599
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.AGAGAGAAAAAAAAAAAAAAAK.Q Charge=3 Parent=532.9533 CE=25.77 NCE=29.22 Q-value=0.0000 Nprot=1 Protein="XXX_sp|P55011|S12A2_HUMAN(pre=R,post=Q)" Nrep=146/200 Theo_mz_diff=1.0ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.2319 Unassigned_20ppm=0.0668 num_unassigned_peaks_20ppm=67 max_unassigned_ab_20ppm=0.41 top_20_num_unassigned_peaks_20ppm=2/20
#
# Num peaks: 129
#
# 101.0709	976843.8	"a2/-0.8ppm"
#
# 110.0713	376659.9	"?"
#
# 112.0868	26365.1	"?"
#
# 116.0705	77273.4	"?"
#
# 120.0807	709527.5	"?"
#
# 121.0841	36108.3	"?"
#
# 127.0864	39223.7	"?"
#
# 129.0656	120230.4	"Int/AG/-2.0ppm,Int/GA/-2.0ppm"
#
# 129.0657	1650641.9	"b2/-1.4ppm"
#
# 129.1021	837966.9	"IKD/-1.1ppm,y1-H2O/-1.1ppm"
#
# 130.065	78470.1	"?"
#
# 130.069	37610	"b2+i/2.1ppm"
#
# 130.0861	278684.1	"y1-NH3/-1.2ppm"
#
# 136.0755	497615.3	"?"
#
# 141.0654	24439.5	"?"
#
# 141.1019	131153.1	"?"
#
# 143.1176	66394.3	"?"
#
# 145.0969	122645	"?"
#
# 147.1125	501370.4	"y1/-2.1ppm"
#
# 155.0812	104253.9	"?"
#
# 157.0969	88052.1	"y1-H2O+CO/-1.6ppm"
#
# 157.1333	124590.1	"?"
#
# 158.0921	80031.4	"?"
#
# 159.0913	101163.3	"?"
#
# 169.0969	643917.5	"?"
#
# 171.1125	33117.7	"?"
#
# 173.0918	129620.3	"?"
#
# 173.1282	179978.8	"?"
#
# 175.1187	512150.2	"IKF/-1.4ppm"
#
# 183.1126	46509.7	"y2-H2O-NH3/-1.1ppm"
#
# 183.1488	39077.2	"?"
#
# 185.0918	41110.8	"?"
#
# 185.1281	76095.7	"?"
#
# 185.1646	83652.3	"?"
#
# 186.0871	103261.4	"?"
#
# 187.1438	127865.3	"?"
#
# 197.1281	85728.6	"?"
#
# 199.1802	131493.1	"?"
#
# 200.1025	1720602.1	"b3/-1.9ppm"
#
# 200.1027	93493.7	"?"
#
# 200.1391	59859	"y2-H2O/-1.3ppm"
#
# 201.1053	88701.3	"b3+i/-1.9ppm"
#
# 201.123	166715.8	"y2-NH3/-1.8ppm"
#
# 207.1124	83900.1	"?"
#
# 212.1026	80474.5	"?"
#
# 215.1391	117784.4	"?"
#
# 218.1496	175038.2	"y2/-1.5ppm"
#
# 226.1185	89951.3	"?"
#
# 229.1298	78559.8	"?"
#
# 233.1643	81456.4	"?"
#
# 242.1129	48447.8	"?"
#
# 242.1493	62435.4	"?"
#
# 244.1652	88565.7	"?"
#
# 254.1493	450152	"y3-H2O-NH3/-2.4ppm"
#
# 257.1239	1284026.4	"b4/-1.9ppm,y3-H2O+CO/-1.9ppm"
#
# 257.124	136808.4	"?"
#
# 258.1243	103953.1	"b4+i/-10.2ppm,y3-H2O+CO+i/-10.2ppm"
#
# 269.1238	23072.4	"?"
#
# 271.1396	33689.8	"?"
#
# 271.176	403576.9	"y3-H2O/-2.0ppm,a4/-2.0ppm"
#
# 283.1398	168331.2	"?"
#
# 288.2024	117859.2	"?"
#
# 289.1864	524763.6	"y3/-2.1ppm"
#
# 290.1891	24473.7	"y3+i/-2.6ppm"
#
# 297.1551	36497.1	"?"
#
# 300.1653	56582.3	"?"
#
# 313.1501	73670.7	"?"
#
# 314.146	44067.7	"?"
#
# 320.6738	222559.7	"?"
#
# 321.1754	26037.2	"?"
#
# 325.1864	611691.1	"y4-H2O-NH3/-2.2ppm"
#
# 326.1902	69949.4	"y4-H2O-NH3+i/1.1ppm"
#
# 328.1608	1466974.1	"b5/-2.1ppm,y4-H2O+CO/-2.1ppm"
#
# 329.1602	216894.6	"b5+i/-11.6ppm,y4-H2O+CO+i/-11.6ppm"
#
# 340.1602	39167.2	"?"
#
# 342.2126	342366.7	"y4-H2O/-2.8ppm,a5/-2.8ppm"
#
# 354.1758	82324.8	"?"
#
# 356.6936	62461.1	"?"
#
# 357.189	176318.2	"a6/2.4ppm"
#
# 360.2237	271160.8	"y4/-1.1ppm"
#
# 367.1714	128398.5	"?"
#
# 368.1911	41210.8	"?"
#
# 382.2079	468903.3	"?"
#
# 383.2095	61771.3	"?"
#
# 385.1813	82832.6	"?"
#
# 385.1823	1311411.9	"b6/-1.5ppm"
#
# 386.1833	218430.8	"b6+i/-5.7ppm"
#
# 391.7108	269246.2	"?"
#
# 392.2113	49999.2	"?"
#
# 428.2262	78280.2	"a7/2.2ppm"
#
# 431.2609	566873.3	"y5/-0.9ppm"
#
# 432.2634	57515.2	"y5+i/-1.4ppm"
#
# 438.2084	100979.2	"?"
#
# 438.2094	36491.2	"b7-H2O/-0.2ppm"
#
# 453.2447	284873.4	"?"
#
# 456.2193	1237151.2	"b7/-1.5ppm"
#
# 457.2213	242672.3	"b7+i/-3.1ppm"
#
# 496.2484	32403.2	"?"
#
# 502.2984	311277.1	"y6/0.1ppm"
#
# 509.2459	39390.2	"?"
#
# 509.248	31354.5	"b8-H2O/2.5ppm"
#
# 524.2818	181121.5	"?"
#
# 527.2564	1205149.2	"b8/-1.4ppm"
#
# 528.2586	252901.6	"b8+i/-2.6ppm"
#
# 573.3344	1366991.6	"y7/-2.1ppm"
#
# 574.3367	547371.3	"y7+i/-2.9ppm"
#
# 575.3455	302151.3	"y7+2i/9.3ppm"
#
# 580.2823	32954.3	"b9-H2O/-2.3ppm"
#
# 595.3177	61091.2	"?"
#
# 598.2932	964937	"b9/-1.7ppm"
#
# 599.2972	245853.4	"b9+i/0.2ppm"
#
# 644.3716	1064849.2	"y8/-1.7ppm"
#
# 645.3741	220494.5	"y8+i/-1.9ppm"
#
# 669.3302	588182.5	"b10/-1.8ppm"
#
# 670.3325	135790.9	"b10+i/-2.5ppm"
#
# 715.4079	869553.2	"y9/-2.8ppm"
#
# 716.4105	196312.7	"y9+i/-3.0ppm"
#
# 740.3674	259305.2	"b11/-1.6ppm"
#
# 741.3694	43255.2	"b11+i/-2.6ppm"
#
# 780.387	123741.3	"?"
#
# 786.4458	624247	"y10/-1.4ppm"
#
# 787.4475	145545	"y10+i/-2.8ppm"
#
# 811.4035	54270	"b12/-2.5ppm"
#
# 857.4821	398385.2	"y11/-2.3ppm"
#
# 858.4854	84782.7	"y11+i/-1.6ppm"
#
# 928.5188	216608.7	"y12/-2.6ppm"
#
# 929.5226	40226.5	"y12+i/-1.3ppm"
#
# 999.5569	109122.7	"y13/-1.3ppm"
#
# 1070.5957	41924.2	"y14/0.5ppm"
#
#
#
# Name: ASDGPSAGEPPAPPAAAAAAAAAAAR/2_0
#
# MW: 2188.0862
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.ASDGPSAGEPPAPPAAAAAAAAAAAR.Q Charge=2 Parent=1094.0431 CE=54.74 NCE=27.80 Q-value=0.0000 Nprot=1 Protein="XXX_sp|Q8WXD9|CSKI1_HUMAN(pre=R,post=Q)" Nrep=4/5 Theo_mz_diff=3.4ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.1088 Unassigned_20ppm=0.1112 num_unassigned_peaks_20ppm=20 max_unassigned_ab_20ppm=0.16 top_20_num_unassigned_peaks_20ppm=4/20
#
# Num peaks: 101
#
# 129.1021	456.7	"?"
#
# 169.0977	354.6	"Int/AP/3.2ppm,Int/PA/3.2ppm"
#
# 175.1193	1385.9	"y1/2.0ppm,IRJ/2.0ppm"
#
# 204.0868	1646	"?"
#
# 240.1346	616.9	"Int/AAP/1.4ppm"
#
# 248.161	131.4	"?"
#
# 274.104	992.8	"b3/2.7ppm"
#
# 303.1296	419.7	"a4/-1.2ppm"
#
# 311.171	1818.7	"Int/AAAP/-1.2ppm"
#
# 313.1522	63.6	"?"
#
# 317.1932	2742.1	"y3/0.0ppm"
#
# 331.125	3355.1	"b4/0.6ppm"
#
# 351.9347	294.1	"?"
#
# 382.2084	2807.5	"Int/AAAAP/-0.2ppm"
#
# 383.2106	217.1	"Int/AAAAP+i/-1.9ppm"
#
# 400.1836	931.3	"a5/2.7ppm"
#
# 428.1781	6240.7	"b5/1.3ppm"
#
# 429.1793	274.8	"b5+i/-3.2ppm"
#
# 453.2457	3379.8	"Int/AAAAAP/0.2ppm"
#
# 454.25	76	"?"
#
# 478.772	242.3	"y12^2/8.4ppm"
#
# 487.214	1215.8	"a6/-1.9ppm"
#
# 515.21	11060	"b6/0.8ppm"
#
# 516.2134	1477.1	"b6+i/2.2ppm"
#
# 524.2824	2913	"Int/AAAAAAP/-0.6ppm"
#
# 525.2864	482.7	"Int/AAAAAAP+i/1.6ppm"
#
# 530.3049	2015.2	"y6/0.7ppm"
#
# 531.3087	197.7	"y6+i/2.6ppm"
#
# 558.2529	1278	"a7/2.2ppm"
#
# 568.2379	261.5	"b7-H2O/3.5ppm"
#
# 586.2472	14401.1	"b7/0.9ppm"
#
# 587.2505	2629.3	"b7+i/1.9ppm"
#
# 595.3191	2246.3	"Int/AAAAAAAP/-1.2ppm"
#
# 596.3233	90.7	"Int/AAAAAAAP+i/1.1ppm"
#
# 601.3429	761.2	"y7/1.9ppm"
#
# 611.3389	4626.1	"y15^2/0.5ppm"
#
# 611.8414	3019.7	"y15^2+i/2.0ppm"
#
# 612.3447	163.3	"y15^2+2i/4.9ppm"
#
# 615.2747	893.9	"a8/2.6ppm"
#
# 625.2572	878.5	"b8-H2O/-0.8ppm"
#
# 626.2652	96.5	"b8-H2O+i/8.7ppm"
#
# 643.2686	17128.5	"b8/0.7ppm"
#
# 644.2715	3088.5	"b8+i/0.9ppm"
#
# 666.3556	1440.9	"Int/AAAAAAAAP/-2.0ppm"
#
# 717.36	164.9	"Int/PPAPPEGA/4.7ppm"
#
# 737.3996	431.6	"Int/AAAAAAAAAP/7.5ppm"
#
# 743.4158	2200.5	"y9/-0.1ppm"
#
# 744.316	172.2	"a9/0.2ppm"
#
# 744.4247	358.3	"y9+i/7.5ppm"
#
# 754.3005	1007.2	"b9-H2O/0.4ppm"
#
# 772.3114	19420	"b9/0.9ppm"
#
# 773.314	3925	"b9+i/0.6ppm"
#
# 804.3938	708.6	"Int/PAPPEGASP/6.4ppm,Int/PPAPPEGAS/6.4ppm"
#
# 841.3716	81.5	"a10/4.2ppm"
#
# 851.3533	1112	"b10-H2O/0.4ppm"
#
# 869.3644	15622.5	"b10/1.1ppm"
#
# 870.3662	3495.5	"b10+i/-0.3ppm"
#
# 885.4916	408.7	"y11/1.5ppm"
#
# 938.4644	1110.4	"?"
#
# 938.5218	205	"y12-H2O/4.6ppm"
#
# 938.9685	797.6	"?"
#
# 948.4065	642	"b11-H2O/1.0ppm"
#
# 956.5277	6992.9	"y12/0.4ppm"
#
# 957.5283	2836.4	"y12+i/-1.5ppm"
#
# 966.4182	4190.8	"b11/2.4ppm"
#
# 967.4205	932.4	"b11+i/1.8ppm"
#
# 997.493	610.3	"?"
#
# 998.5184	310.5	"?"
#
# 1053.5788	1814.9	"y13/-0.9ppm"
#
# 1054.5766	469.1	"y13+i/-5.0ppm"
#
# 1073.4909	2244.2	"Int/PPAPPEGASPGD/1.0ppm"
#
# 1074.4962	990.4	"Int/PPAPPEGASPGD+i/3.2ppm"
#
# 1075.5133	284	"Int/PPAPPEGASPGD+2i/16.7ppm"
#
# 1079.5159	1471.1	"?"
#
# 1093.5253	3993.1	"?"
#
# 1093.5822	7871.9	"?"
#
# 1094.5195	7864.4	"?"
#
# 1094.5649	5545.1	"?"
#
# 1150.6301	2511.2	"y14/-2.0ppm"
#
# 1151.6369	1540.4	"y14+i/1.0ppm"
#
# 1203.6597	2388.8	"y15-H2O/0.3ppm"
#
# 1204.656	1667	"y15-NH3/9.2ppm,y15-H2O+i/-4.4ppm"
#
# 1205.6556	371.5	"y15-H2O+2i/-6.6ppm,y15-NH3+i/6.8ppm"
#
# 1221.6714	50000	"y15/1.1ppm"
#
# 1222.6728	30435.6	"y15+i/0.1ppm"
#
# 1223.6687	1912.1	"y15+2i/-4.7ppm"
#
# 1249.5721	249.6	"?"
#
# 1265.6485	516.9	"?"
#
# 1266.6492	656.7	"?"
#
# 1267.6416	514.8	"?"
#
# 1318.7246	7061.3	"y16/1.3ppm"
#
# 1319.7261	3898.6	"y16+i/0.5ppm"
#
# 1415.7771	3464.9	"y17/1.1ppm"
#
# 1416.771	2197.7	"y17+i/-4.6ppm"
#
# 1478.7101	211.5	"?"
#
# 1544.8153	1745.3	"y18/-1.7ppm"
#
# 1545.8217	1584.8	"y18+i/0.6ppm"
#
# 1601.8427	1001.1	"y19/2.0ppm"
#
# 1602.8505	668.1	"y19+i/4.9ppm"
#
# 1672.8713	88.1	"y20/-3.0ppm"
#
# 1673.903	283.7	"y20+i/13.4ppm"
#
#
#
# Name: ASDGPSAGEPPAPPAAAAAAAAAAAR/3_0
#
# MW: 2189.0934
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.ASDGPSAGEPPAPPAAAAAAAAAAAR.Q Charge=3 Parent=729.6978 CE=0.00 NCE=30.00 Q-value=0.0000 Nprot=1 Protein="XXX_sp|Q8WXD9|CSKI1_HUMAN(pre=R,post=Q)" Nrep=3/3 Theo_mz_diff=0.7ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.2137 Unassigned_20ppm=0.2257 num_unassigned_peaks_20ppm=28 max_unassigned_ab_20ppm=0.79 top_20_num_unassigned_peaks_20ppm=2/20
#
# Num peaks: 140
#
# 110.0709	146.6	"?"
#
# 129.102	430.1	"?"
#
# 131.0812	147.7	"a2/-2.5ppm"
#
# 136.0755	242	"?"
#
# 141.1021	201.9	"Int/PA-CO/-1.0ppm"
#
# 142.0495	230.6	"b2-NH3/-2.8ppm"
#
# 147.1125	227.7	"?"
#
# 159.0761	373.2	"b2/-2.1ppm"
#
# 169.0971	610.3	"Int/AP/-0.3ppm,Int/PA/-0.3ppm"
#
# 175.1188	638.4	"y1/-0.9ppm,IRJ/-0.9ppm"
#
# 195.1124	422.9	"Int/PP/-2.1ppm"
#
# 213.1593	119.4	"?"
#
# 227.1027	267.4	"Int/PE/0.3ppm"
#
# 238.1546	151.6	"Int/PAP-CO/-1.7ppm,Int/PPA-CO/-1.7ppm"
#
# 240.1338	433.6	"Int/AAP/-1.9ppm"
#
# 243.1334	704.6	"?"
#
# 244.1283	162.9	"?"
#
# 261.1558	1081.6	"?"
#
# 265.6554	243.2	"y6^2/-1.6ppm"
#
# 266.1496	1935.4	"Int/PAP/-1.2ppm,Int/PPA/-1.2ppm"
#
# 267.1541	248.5	"Int/PAP+i/4.6ppm,Int/PPA+i/4.6ppm"
#
# 274.1033	1093.9	"b3/-0.1ppm"
#
# 277.1169	137.6	"?"
#
# 303.1298	377.1	"a4/-0.4ppm"
#
# 311.1712	891.1	"Int/AAAP/-0.6ppm"
#
# 317.1933	1339.9	"y3/0.3ppm"
#
# 320.6739	131.5	"?"
#
# 324.1549	349.4	"Int/PPE/-1.5ppm"
#
# 326.1128	320.6	"?"
#
# 331.1248	1710.3	"b4/-0.1ppm"
#
# 332.1272	172	"b4+i/-1.5ppm"
#
# 337.1866	498.8	"Int/APPA/-1.3ppm"
#
# 344.2	370.6	"?"
#
# 355.1609	84.6	"Int/PEGA/-0.9ppm"
#
# 356.1689	144.2	"Int/PEGA+i/13.4ppm"
#
# 356.217	1239.3	"?"
#
# 357.2182	230.6	"?"
#
# 363.2026	232.2	"Int/PAPP/-0.2ppm,Int/PPAP/-0.2ppm"
#
# 374.2397	809.7	"?"
#
# 381.177	205.3	"Int/PPEG/0.4ppm"
#
# 382.2079	1034	"Int/AAAAP/-1.6ppm"
#
# 383.211	205.8	"Int/AAAAP+i/-0.9ppm"
#
# 391.7112	461.7	"?"
#
# 400.1829	528.4	"a5/0.5ppm"
#
# 408.2227	190.1	"Int/AAPPA/-3.5ppm"
#
# 428.1775	2552.3	"b5/-0.4ppm"
#
# 429.1799	189.6	"b5+i/-1.5ppm"
#
# 440.2371	364.2	"?"
#
# 440.738	151.5	"?"
#
# 443.2482	1980.9	"y11^2/-0.9ppm"
#
# 443.7502	987.4	"y11^2+i/0.3ppm"
#
# 444.252	177	"y11^2+2i/1.4ppm"
#
# 453.2461	982.6	"Int/AAAAAP/1.1ppm"
#
# 454.2451	223.5	"Int/AAAAAP+i/-7.4ppm"
#
# 459.2684	169.3	"y5/2.0ppm"
#
# 469.7626	227	"y12-H2O^2/1.2ppm"
#
# 478.7669	21626	"y12^2/-0.6ppm"
#
# 479.2615	265.6	"Int/AAAPPA/0.5ppm"
#
# 479.2682	11663.9	"y12^2+i/-0.8ppm"
#
# 479.7693	2515.4	"y12^2+2i/-1.0ppm"
#
# 480.2711	312.6	"y12^2+3i/-0.1ppm"
#
# 487.2145	457.4	"a6/-0.6ppm"
#
# 487.3241	810	"?"
#
# 512.2132	180.5	"?"
#
# 515.2095	3354.1	"b6/-0.4ppm"
#
# 516.213	575.8	"b6+i/1.3ppm"
#
# 524.2821	806.9	"Int/AAAAAAP/-1.2ppm"
#
# 525.2857	189.6	"Int/AAAAAAP+i/0.3ppm"
#
# 527.2956	171.9	"y13^2/3.3ppm"
#
# 530.3042	1440.7	"y6/-0.4ppm"
#
# 531.3085	357.7	"y6+i/2.2ppm"
#
# 539.2453	222.5	"Int/PEGASP/-1.3ppm,Int/PPEGAS/-1.3ppm"
#
# 550.2982	270	"Int/AAAAPPA/-0.3ppm"
#
# 558.248	551	"a7/-8.2ppm"
#
# 568.2372	239.9	"b7-H2O/2.1ppm,Int/AAAPPA+i/-13.8ppm"
#
# 575.82	295.8	"y14^2/0.0ppm"
#
# 583.3442	269.4	"?"
#
# 584.3352	200	"?"
#
# 586.2465	4356.1	"b7/-0.5ppm"
#
# 587.2496	974	"b7+i/0.1ppm"
#
# 589.2968	271.6	"Int/PPAPPE/-2.1ppm"
#
# 595.3198	590.8	"Int/AAAAAAAP/-0.1ppm"
#
# 601.3411	1072.2	"y7/-0.7ppm"
#
# 602.3315	194.2	"y15-H2O^2/-2.6ppm"
#
# 602.3448	169.9	"y7+i/0.7ppm"
#
# 611.3384	12462.7	"y15^2/-0.2ppm"
#
# 611.8398	8059.4	"y15^2+i/-0.2ppm"
#
# 612.3404	2540.8	"y15^2+2i/-1.2ppm"
#
# 612.8425	356.1	"y15^2+3i/-0.1ppm"
#
# 615.2714	278.2	"a8/-3.5ppm"
#
# 621.3358	157.9	"Int/AAAAAPPA/0.5ppm"
#
# 625.2602	219.4	"b8-H2O/4.7ppm,Int/AAAAPPA+i/-9.2ppm"
#
# 643.2514	165.4	"?"
#
# 643.268	4683.3	"b8/-0.3ppm"
#
# 644.2705	1352.9	"b8+i/-0.8ppm"
#
# 650.8665	557.3	"y16-H2O^2/9.4ppm"
#
# 659.8638	187	"y16^2/-1.5ppm"
#
# 660.3649	202.4	"y16^2+i/-1.9ppm"
#
# 666.3563	536.7	"Int/AAAAAAAAP/-1.0ppm"
#
# 672.379	355.2	"y8/0.4ppm"
#
# 692.3713	189.5	"Int/AAAAAAPPA/-1.9ppm"
#
# 707.3467	438.8	"Int/PAPPEGAS/15.3ppm"
#
# 707.8494	271.4	"?"
#
# 729.3699	1733.3	"?"
#
# 729.451	12708.8	"?"
#
# 730.4532	17171.6	"?"
#
# 737.3947	241.3	"Int/AAAAAAAAAP/0.9ppm"
#
# 743.4153	1874.5	"y9/-0.7ppm"
#
# 744.4186	529.7	"y9+i/0.0ppm"
#
# 754.3035	271.9	"b9-H2O/5.2ppm,Int/AAAAAPPA+i/-7.0ppm"
#
# 772.3105	5292.8	"b9/-0.5ppm"
#
# 773.3131	1449.1	"b9+i/-0.8ppm"
#
# 774.3147	205.3	"b9+2i/-2.1ppm"
#
# 804.3886	331.3	"Int/PAPPEGASP/-0.1ppm,Int/PPAPPEGAS/-0.1ppm"
#
# 808.3485	637.6	"Int/PPEGASPGD/1.6ppm"
#
# 814.4532	926	"y10/0.3ppm"
#
# 815.4603	375.4	"y10+i/4.8ppm"
#
# 834.4365	286.6	"Int/AAAAAAAAPPA/-12.4ppm"
#
# 851.3545	161.3	"b10-H2O/2.1ppm,Int/AAAAAAPPA+i/-8.9ppm"
#
# 869.3635	5320.4	"b10/-0.2ppm"
#
# 870.3629	1470.4	"b10+i/-4.9ppm"
#
# 871.3637	315.5	"b10+2i/-7.2ppm"
#
# 885.4897	4266	"y11/-0.3ppm"
#
# 886.492	1755.3	"y11+i/-0.8ppm"
#
# 887.4959	552.5	"Int/PPAPPEGASPGD-CO/-13.2ppm,y11+2i/0.6ppm"
#
# 948.4088	226.8	"b11-H2O/4.0ppm"
#
# 956.5273	4642.3	"y12/0.1ppm"
#
# 957.5304	2436.8	"y12+i/0.4ppm"
#
# 958.5303	448.4	"Int/PPAPPEGASPGDS-H2O/17.4ppm,y12+2i/-1.9ppm"
#
# 963.4754	218	"?"
#
# 966.4159	2809.1	"b11/-0.5ppm"
#
# 967.4187	731.6	"b11+i/-0.5ppm"
#
# 968.4222	138.6	"b11+2i/0.8ppm"
#
# 1053.5749	582.9	"y13/-4.1ppm"
#
# 1054.5814	232.6	"y13+i/-1.1ppm"
#
# 1073.4878	215.3	"Int/PPAPPEGASPGD/-1.9ppm"
#
# 1150.6319	1491.4	"y14/-0.6ppm"
#
# 1151.6353	762.2	"y14+i/-0.2ppm"
#
# 1221.6716	1221.9	"y15/1.3ppm"
#
# 1222.6675	887.6	"y15+i/-3.7ppm"
#
#
#
# Name: SVAAAAAAAAAR/2_0
#
# MW: 1001.5606
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.SVAAAAAAAAAR.R Charge=2 Parent=500.7803 CE=24.44 NCE=28.66 Q-value=0.0000 Nprot=1 Protein="XXX_sp|Q96JP5|ZFP91_HUMAN(pre=R,post=R)" Nrep=153/200 Theo_mz_diff=0.7ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.1319 Unassigned_20ppm=0.0655 num_unassigned_peaks_20ppm=23 max_unassigned_ab_20ppm=0.22 top_20_num_unassigned_peaks_20ppm=3/20
#
# Num peaks: 64
#
# 101.0712	31202.7	"?"
#
# 110.0714	170899.8	"?"
#
# 120.0809	103773.7	"?"
#
# 129.1023	265656.1	"?"
#
# 130.0864	69344	"?"
#
# 136.0757	118193.1	"?"
#
# 141.1022	50070.9	"?"
#
# 143.1179	88012.1	"?"
#
# 147.1128	97791.6	"?"
#
# 158.0924	36077.8	"y1-NH3/-0.0ppm"
#
# 159.1129	343243.4	"a2/1.0ppm"
#
# 169.0972	390095	"Int/VS-H2O/0.3ppm"
#
# 170.1006	12566.4	"Int/VS-H2O+i/3.1ppm"
#
# 171.1129	65509	"Int/AV/0.6ppm"
#
# 175.119	246637.9	"y1/0.3ppm,IRJ/0.3ppm"
#
# 187.1077	926743.5	"b2/-0.0ppm"
#
# 188.111	26874.6	"b2+i/3.5ppm"
#
# 201.1234	48524.9	"?"
#
# 229.1295	46035.5	"y2-NH3/-0.1ppm"
#
# 240.1342	285784.4	"?"
#
# 241.1375	11921.1	"?"
#
# 242.1134	54297	"?"
#
# 246.156	111751.4	"y2/-0.3ppm"
#
# 258.1448	1524515.6	"b3/-0.1ppm"
#
# 259.1481	89787.4	"b3+i/2.3ppm"
#
# 283.1763	19620.2	"?"
#
# 300.1668	28842.7	"y3-NH3/0.5ppm"
#
# 301.187	339041.2	"a4/-0.1ppm"
#
# 302.1904	12705.1	"a4+i/2.5ppm"
#
# 311.1712	354620.6	"?"
#
# 312.1743	30519.7	"?"
#
# 313.1505	61300	"?"
#
# 313.1865	12798.3	"?"
#
# 317.1931	138209.9	"y3/-0.3ppm"
#
# 329.1818	967074.4	"b4/-0.5ppm"
#
# 330.185	85032.7	"b4+i/1.0ppm"
#
# 372.224	249529.1	"a5/-0.4ppm"
#
# 373.2264	15079.5	"a5+i/-1.5ppm"
#
# 382.2084	169218.2	"?"
#
# 383.2112	13742.1	"?"
#
# 384.2245	13326.8	"?"
#
# 388.2303	373836.6	"y4/-0.0ppm"
#
# 389.2329	45092.4	"y4+i/-0.2ppm"
#
# 400.2188	605827.8	"b5/-0.7ppm"
#
# 401.2217	64033.8	"b5+i/-0.4ppm"
#
# 443.2611	75351	"a6/-0.4ppm"
#
# 453.2457	32898.3	"?"
#
# 459.2674	738076.1	"y5/-0.0ppm"
#
# 460.2703	132118	"y5+i/0.4ppm"
#
# 471.2559	317205.1	"b6/-0.6ppm"
#
# 472.2594	34492.8	"b6+i/1.1ppm"
#
# 500.2818	213450.2	"?"
#
# 530.3046	1202123.1	"y6/0.1ppm"
#
# 531.3076	261387.4	"y6+i/0.6ppm"
#
# 542.2931	117673.5	"b7/-0.3ppm"
#
# 601.3417	1634981.3	"y7/0.1ppm"
#
# 602.3448	414124.7	"y7+i/0.7ppm"
#
# 613.3305	33681.6	"b8/0.2ppm"
#
# 672.3788	1542360.9	"y8/0.1ppm"
#
# 673.3819	440885.5	"y8+i/0.6ppm"
#
# 743.4159	743110	"y9/0.0ppm"
#
# 744.4186	230861.3	"y9+i/0.0ppm"
#
# 814.453	427337	"y10/0.0ppm"
#
# 815.4558	155120	"y10+i/0.1ppm"
#
#
#
# Name: GAFAGAAAAAAAAR/2_0
#
# MW: 1147.6088
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.GAFAGAAAAAAAAR.R Charge=2 Parent=573.8044 CE=29.09 NCE=29.03 Q-value=0.0007 Nprot=1 Protein="XXX_sp|Q8N697|S15A4_HUMAN(pre=R,post=R)" Nrep=22/35 Theo_mz_diff=2.0ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.2962 Unassigned_20ppm=0.2031 num_unassigned_peaks_20ppm=58 max_unassigned_ab_20ppm=0.42 top_20_num_unassigned_peaks_20ppm=6/20
#
# Num peaks: 100
#
# 101.0715	48110	"a2/4.4ppm"
#
# 101.0717	13637	"?"
#
# 102.0557	11256.8	"?"
#
# 110.0718	40122.3	"?"
#
# 112.0877	6558.2	"IRG/6.9ppm"
#
# 116.0713	2747.6	"IRI/6.0ppm"
#
# 120.0813	48963	"IFA/4.4ppm"
#
# 129.0661	120066.1	"b2/2.1ppm"
#
# 129.0665	5755.7	"Int/GA/5.0ppm"
#
# 129.1028	90577.6	"?"
#
# 130.0868	15572.9	"?"
#
# 136.0761	84754.2	"?"
#
# 141.1026	11608	"?"
#
# 143.1183	10476.6	"?"
#
# 147.1132	33543.1	"?"
#
# 157.0971	3060.6	"?"
#
# 157.1341	6856.6	"?"
#
# 158.0928	17233.1	"y1-NH3/2.5ppm"
#
# 159.0771	6479.7	"?"
#
# 159.0922	4337.8	"y1-NH3+i/-17.2ppm"
#
# 169.0976	65860	"?"
#
# 171.0768	3508	"?"
#
# 171.1132	6102.5	"?"
#
# 173.0928	5574.4	"?"
#
# 173.1291	16063	"?"
#
# 175.1193	84560.4	"y1/2.0ppm,IRJ/2.0ppm"
#
# 176.1229	1922.7	"y1+i/9.4ppm,IRJ+i/9.4ppm"
#
# 183.15	6767.7	"?"
#
# 185.1292	7066.2	"?"
#
# 185.1656	16511.2	"?"
#
# 187.1447	4501.6	"?"
#
# 197.1291	10804.4	"?"
#
# 199.1808	11316.5	"?"
#
# 200.104	6040.1	"?"
#
# 200.14	4439	"?"
#
# 201.1241	17202.5	"?"
#
# 204.135	7151.3	"?"
#
# 207.1138	8946.1	"?"
#
# 213.0875	9816	"?"
#
# 213.1604	8769.9	"?"
#
# 215.1403	25856.5	"?"
#
# 226.1193	5075.6	"?"
#
# 227.1762	6245.8	"?"
#
# 228.1355	5483.3	"?"
#
# 230.1149	4991.6	"?"
#
# 240.1349	59770.6	"?"
#
# 242.1147	8164.4	"?"
#
# 242.1513	8984.2	"?"
#
# 243.1352	12358.6	"?"
#
# 244.1662	6375.1	"?"
#
# 246.1568	13576.6	"y2/3.4ppm"
#
# 248.1402	4143.6	"a3/4.3ppm"
#
# 255.1457	9120	"?"
#
# 258.1102	3000.5	"?"
#
# 260.198	8366.8	"?"
#
# 271.1408	5353.2	"?"
#
# 276.135	215338.7	"b3/3.2ppm"
#
# 277.137	6471.4	"b3+i/-0.0ppm"
#
# 283.1787	4289.5	"?"
#
# 300.1714	16222.5	"y3-NH3/16.5ppm,b4+i/-9.9ppm"
#
# 311.1724	78803.3	"?"
#
# 313.1526	11254.8	"?"
#
# 317.1935	8161	"y3/0.9ppm"
#
# 319.1773	48309.5	"a4/3.4ppm"
#
# 342.1785	5430.3	"?"
#
# 347.1724	157732.3	"b4/3.8ppm"
#
# 347.1736	4645.6	"?"
#
# 371.2056	5261	"y4-NH3/4.4ppm"
#
# 376.1986	41109.8	"a5/2.0ppm"
#
# 382.2099	40134.4	"?"
#
# 388.2314	22136.4	"y4/2.6ppm"
#
# 390.2148	4109.6	"?"
#
# 404.1938	118272.6	"b5/2.7ppm"
#
# 405.1986	6614.6	"b5+i/8.3ppm"
#
# 413.2166	5576.9	"?"
#
# 418.2114	5138.7	"?"
#
# 447.2366	18156.8	"a6/3.9ppm"
#
# 453.2486	12353.8	"?"
#
# 459.2693	19235.5	"y5/3.7ppm"
#
# 475.2307	82813.3	"b6/1.7ppm"
#
# 476.236	6209.8	"b6+i/7.6ppm"
#
# 484.254	2767.5	"?"
#
# 489.25	3677.9	"?"
#
# 513.2821	2925.7	"y6-NH3/7.4ppm"
#
# 530.306	173529.2	"y6/2.6ppm"
#
# 531.3104	24112.7	"y6+i/5.4ppm"
#
# 546.2695	39470.6	"b7/4.9ppm"
#
# 573.3372	84875.1	"?"
#
# 601.3435	167775	"y7/2.9ppm"
#
# 602.3467	26019.6	"y7+i/3.6ppm"
#
# 672.3806	198280.2	"y8/2.6ppm"
#
# 673.3819	48489.8	"y8+i/0.6ppm"
#
# 688.3389	5787.7	"b9/-3.8ppm"
#
# 743.4185	201465.5	"y9/3.3ppm"
#
# 744.4214	42068.9	"y9+i/3.5ppm"
#
# 800.4395	157678.7	"y10/2.6ppm"
#
# 801.4425	38584.5	"y10+i/2.9ppm"
#
# 871.4781	48237.2	"y11/4.0ppm"
#
# 872.4822	11911.7	"y11+i/5.4ppm"
#
# 1018.5493	15681.5	"y12/6.5ppm"
#
#
#
# Name: AHMQAAAAAAAAK/2_1(2,M,Oxidation)
#
# MW: 1199.607
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=1(2,M,Oxidation) Fullname=R.AHMQAAAAAAAAK.N Charge=2 Parent=599.8035 CE=34.00 NCE=32.00 Q-value=0.0000 Nprot=1 Protein="XXX_sp|Q5TF21|SOGA3_HUMAN(pre=R,post=N)" Nrep=3/4 Theo_mz_diff=0.3ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.4776 Unassigned_20ppm=0.3527 num_unassigned_peaks_20ppm=150 max_unassigned_ab_20ppm=0.63 top_20_num_unassigned_peaks_20ppm=7/20
#
# Num peaks: 227
#
# 122.0714	284.5	"?"
#
# 127.0867	1028.1	"?"
#
# 129.1022	9420.2	"IKD/-0.3ppm,y1-H2O/-0.3ppm"
#
# 130.0863	4732.7	"y1-NH3/0.4ppm"
#
# 130.1055	869.2	"IKD+i/3.6ppm,y1-H2O+i/3.6ppm"
#
# 136.0757	1277.1	"?"
#
# 141.0661	354.5	"?"
#
# 141.1022	2792.9	"?"
#
# 143.118	2011	"?"
#
# 147.1129	8359	"y1/0.7ppm"
#
# 148.1164	728.3	"y1+i/5.3ppm"
#
# 155.0816	968.2	"?"
#
# 156.0768	3176.6	"IHF/0.3ppm"
#
# 157.0974	885.1	"y1-H2O+CO/1.6ppm"
#
# 158.0926	1175.2	"?"
#
# 167.0821	603.8	"?"
#
# 167.0929	2290.4	"?"
#
# 168.0768	495.3	"?"
#
# 169.0972	8783.6	"?"
#
# 169.1334	639.8	"?"
#
# 171.0762	365.6	"?"
#
# 171.1128	461.9	"?"
#
# 173.0921	914.2	"?"
#
# 173.1284	249.4	"?"
#
# 175.119	8253.7	"IKF/0.3ppm"
#
# 181.0973	636.2	"?"
#
# 181.1083	258.1	"?"
#
# 185.0918	860.1	"?"
#
# 185.1288	238.1	"?"
#
# 185.1649	1146.4	"?"
#
# 192.0765	237.8	"b2-NH3/-2.0ppm"
#
# 197.1284	824.8	"?"
#
# 199.1079	1030.2	"?"
#
# 200.1392	412.8	"y2-H2O/-0.8ppm"
#
# 201.0872	648.1	"?"
#
# 201.1232	590.1	"y2-NH3/-0.8ppm"
#
# 203.1032	646.1	"?"
#
# 204.1348	874.1	"?"
#
# 209.0924	218.6	"?"
#
# 209.1033	15035.8	"b2/-0.0ppm"
#
# 209.1038	1263.6	"Int/HA/2.4ppm"
#
# 211.1445	148.8	"?"
#
# 212.1031	980.6	"?"
#
# 213.087	333.6	"?"
#
# 217.0817	344.1	"?"
#
# 218.1499	2016.7	"y2/-0.1ppm"
#
# 221.1035	651.7	"?"
#
# 224.103	471.5	"?"
#
# 226.119	1180.4	"?"
#
# 226.1553	3216.8	"?"
#
# 227.1028	1614.5	"?"
#
# 227.1137	478.5	"?"
#
# 228.134	423.4	"y2-H2O+CO/-1.2ppm"
#
# 228.1711	2237.5	"?"
#
# 230.1135	769.5	"?"
#
# 231.098	263.6	"?"
#
# 234.1458	868.2	"?"
#
# 240.0977	1303.9	"?"
#
# 240.1342	7965.4	"?"
#
# 241.0822	1507.2	"?"
#
# 241.1378	568.2	"?"
#
# 242.1135	1448.9	"?"
#
# 244.0928	592.5	"?"
#
# 244.1655	2951.2	"?"
#
# 245.1689	398.7	"?"
#
# 249.0987	196.2	"?"
#
# 251.6546	484.8	"y6^2/5.1ppm"
#
# 253.1293	9088.3	"?"
#
# 254.1504	915	"?"
#
# 255.1455	591.2	"?"
#
# 256.1296	1746.4	"?"
#
# 256.1652	2059	"?"
#
# 258.1454	4171.4	"?"
#
# 260.1976	461.1	"?"
#
# 269.1241	1316.6	"?"
#
# 271.1773	200.8	"y3-H2O/2.5ppm"
#
# 272.1716	1414.3	"?"
#
# 275.1712	289.8	"?"
#
# 276.1552	2615	"?"
#
# 278.1258	602.4	"?"
#
# 283.1769	750.4	"?"
#
# 284.1248	553.1	"?"
#
# 285.1024	544.4	"Int/mH/2.9ppm"
#
# 287.1717	1621.3	"y7^2/0.9ppm"
#
# 289.1624	608.5	"?"
#
# 289.1881	5579	"y3/3.0ppm"
#
# 290.1892	318.6	"y3+i/-1.4ppm"
#
# 290.6902	623.4	"y8-CH3SOH^2/-1.5ppm"
#
# 292.1402	146.9	"?"
#
# 294.1471	351.8	"?"
#
# 295.1398	350.2	"?"
#
# 296.2264	2621.1	"y4-CH3SOH/1.3ppm"
#
# 297.1559	817.3	"?"
#
# 301.1877	355.3	"?"
#
# 303.2398	412.8	"?"
#
# 311.1714	6326.8	"?"
#
# 313.1509	2133.6	"?"
#
# 319.1561	732.9	"?"
#
# 322.6595	984.3	"?"
#
# 322.6911	1261.5	"y8^2/2.8ppm"
#
# 325.1507	1184.9	"?"
#
# 326.171	300.2	"?"
#
# 328.1441	767.7	"a3/1.6ppm"
#
# 333.2129	308.4	"?"
#
# 338.128	515.9	"b3-H2O/-0.8ppm"
#
# 341.2187	534.6	"?"
#
# 345.2125	923	"?"
#
# 347.1376	670.9	"?"
#
# 349.252	440.8	"y5-CH3SOH-H2O/-0.6ppm"
#
# 356.1387	26974.9	"b3/-0.1ppm"
#
# 356.1426	471.1	"?"
#
# 357.1425	1387.9	"b3+i/4.6ppm"
#
# 358.2098	1037.4	"y9^2/2.9ppm"
#
# 360.2257	3481.8	"y4/3.1ppm"
#
# 367.2606	1677.5	"y5-CH3SOH/-4.1ppm"
#
# 368.1931	597.8	"?"
#
# 368.2629	231.6	"y5-CH3SOH+i/-4.8ppm"
#
# 382.1405	932.1	"?"
#
# 382.2085	2970.8	"?"
#
# 384.1877	1300	"?"
#
# 398.2036	353.5	"?"
#
# 399.1555	1347.9	"?"
#
# 413.2407	1519.3	"y10-H2O^2/16.8ppm"
#
# 413.252	527.6	"y5-H2O/2.2ppm"
#
# 414.237	802.3	"y5-NH3/3.8ppm"
#
# 418.1763	486.5	"?"
#
# 420.1964	303	"?"
#
# 422.2381	625.6	"y10^2/0.6ppm"
#
# 428.2566	677.9	"?"
#
# 428.7465	298	"?"
#
# 431.2608	2973.3	"y5/-0.6ppm"
#
# 432.2606	163.8	"y5+i/-5.2ppm"
#
# 438.3001	4486.7	"y6-CH3SOH/0.1ppm"
#
# 439.3039	424.8	"y6-CH3SOH+i/1.8ppm"
#
# 443.2638	482	"?"
#
# 450.2034	3747.4	"?"
#
# 453.213	251.4	"?"
#
# 453.2479	341.4	"?"
#
# 454.2672	909.6	"?"
#
# 456.2023	6704.1	"a4/-0.4ppm"
#
# 463.2424	216.1	"?"
#
# 470.7313	129.4	"?"
#
# 480.2161	752	"?"
#
# 484.1973	17168.2	"b4/-0.1ppm"
#
# 484.1994	747.9	"?"
#
# 485.2017	464.8	"b4+i/5.5ppm"
#
# 491.2366	1061.8	"b11^2/9.0ppm"
#
# 502.2975	7100.6	"y6/-1.2ppm"
#
# 503.3019	1118.3	"y6+i/1.3ppm"
#
# 509.3371	7218.3	"y7-CH3SOH/-0.1ppm"
#
# 510.341	1293	"y7-CH3SOH+i/1.6ppm"
#
# 516.3519	342.3	"?"
#
# 518.1945	444.9	"?"
#
# 527.2391	4596.5	"a5/-1.3ppm"
#
# 527.2396	294.6	"?"
#
# 527.2763	733	"?"
#
# 528.2824	162.6	"?"
#
# 534.2771	830.8	"?"
#
# 535.2861	369.2	"?"
#
# 537.2253	344.6	"b5-H2O/4.2ppm,y3-NH3/4.2ppm"
#
# 538.2666	171.2	"?"
#
# 539.2962	361.2	"?"
#
# 549.279	977.8	"?"
#
# 550.2676	1246.4	"?"
#
# 550.7692	4466.2	"?"
#
# 555.2342	10412.1	"b5/-0.7ppm"
#
# 555.2357	1625.5	"?"
#
# 555.2894	1103	"y12-H2O^2/17.5ppm"
#
# 555.3278	475.2	"y7-H2O/3.9ppm"
#
# 556.3142	452.5	"?"
#
# 557.3026	1354.9	"?"
#
# 562.2735	1368.1	"?"
#
# 565.3153	402.8	"?"
#
# 573.3348	8372.9	"y7/-0.8ppm"
#
# 574.3408	1649.8	"y7+i/3.5ppm"
#
# 580.374	9090.3	"y8-CH3SOH/-0.3ppm"
#
# 581.2714	370.5	"?"
#
# 581.309	539.9	"?"
#
# 581.3755	2292.1	"y8-CH3SOH+i/-1.9ppm"
#
# 582.2942	1045.6	"?"
#
# 582.3318	626.6	"?"
#
# 583.2818	844.9	"?"
#
# 596.2731	513.6	"?"
#
# 598.2763	1160.9	"a6/-0.9ppm"
#
# 598.2777	1142.5	"?"
#
# 598.765	580.7	"?"
#
# 598.8081	4226.5	"?"
#
# 599.2786	7868.9	"?"
#
# 599.3166	14119.8	"?"
#
# 599.3613	1260.8	"?"
#
# 599.7649	724.8	"?"
#
# 599.8019	1272	"p/-2.7ppm"
#
# 600.2119	3408.7	"?"
#
# 600.2734	1246	"?"
#
# 600.309	16946.7	"?"
#
# 600.3489	14266.4	"?"
#
# 604.2925	509.6	"?"
#
# 605.3166	263.9	"?"
#
# 626.2707	1760.6	"?"
#
# 626.2712	4337.1	"b6/-0.8ppm"
#
# 626.3641	491.6	"y8-H2O/2.6ppm"
#
# 633.3099	2407.9	"?"
#
# 634.3172	713.1	"?"
#
# 637.3011	2901.1	"?"
#
# 644.3711	9317.6	"y8/-1.7ppm"
#
# 645.3755	2096.9	"y8+i/0.3ppm"
#
# 651.4105	8325.3	"y9-CH3SOH/-1.0ppm"
#
# 652.4174	2000.4	"y9-CH3SOH+i/3.9ppm"
#
# 656.3136	369.8	"?"
#
# 669.3136	811.7	"a7/-0.3ppm"
#
# 675.3193	846.1	"?"
#
# 697.3098	926.7	"b7/2.3ppm"
#
# 697.3105	1650.4	"?"
#
# 704.3477	1276.2	"?"
#
# 705.3456	333.4	"?"
#
# 715.4082	6808.2	"y9/-1.6ppm"
#
# 716.4163	1709.5	"y9+i/4.3ppm"
#
# 752.3962	194.3	"?"
#
# 768.349	1499.7	"?"
#
# 779.4658	2982.6	"y10-CH3SOH/-4.5ppm"
#
# 780.4741	667.3	"y10-CH3SOH+i/1.5ppm"
#
# 839.3872	490	"?"
#
# 843.4692	2285.7	"y10/0.9ppm"
#
# 844.4742	679.1	"y10+i/3.3ppm"
#
# 926.5097	1540	"y11-CH3SOH/4.3ppm"
#
# 990.5094	319.4	"y11/5.4ppm"
#
# 1052.4991	611.8	"b12/4.7ppm"
#
#
#
# Name: TLMTPSEPTPSSPAALAMTAAAAAAAAK/3_0
#
# MW: 2601.3252
#
# Comment: Consensus Pep=Tryptic Peptype=<Protein><Peptide><Protein> Mods=0 Fullname=R.TLMTPSEPTPSSPAALAMTAAAAAAAAK.K Charge=3 Parent=867.1084 CE=0.00 NCE=30.00 Q-value=0.0001 Nprot=1 Protein="XXX_sp|Q9NQS7|INCE_HUMAN(pre=R,post=K)" Nrep=6/8 Theo_mz_diff=2.1ppm Quality=7/7 MC=0 MCtype=Normal Unassigned_all_20ppm=0.2018 Unassigned_20ppm=0.1640 num_unassigned_peaks_20ppm=31 max_unassigned_ab_20ppm=0.48 top_20_num_unassigned_peaks_20ppm=4/20
#
# Num peaks: 118
#
# 101.0709	1793	"?"
#
# 104.0528	2373.1	"IMA/-0.4ppm"
#
# 110.0711	7745.3	"?"
#
# 120.0805	7042.2	"?"
#
# 129.1022	11975.7	"IKD/-0.3ppm,y1-H2O/-0.3ppm"
#
# 130.0862	4548.3	"y1-NH3/-0.4ppm"
#
# 136.0754	5498.4	"?"
#
# 147.1125	9547.7	"y1/-2.1ppm"
#
# 155.0812	2923.4	"?"
#
# 157.0971	3351.2	"y1-H2O+CO/-0.3ppm"
#
# 167.0814	6661.9	"Int/PS-H2O/-0.6ppm"
#
# 169.097	8247.7	"?"
#
# 171.1125	4640.8	"Int/PT-CO/-1.8ppm"
#
# 175.1185	3618.4	"IKF/-2.6ppm"
#
# 185.0918	9884.3	"Int/PS/-1.4ppm"
#
# 185.1282	1521.7	"?"
#
# 187.1439	4674.2	"a2/-1.6ppm"
#
# 199.1076	7920.5	"Int/PE-CO/-0.6ppm,Int/PT/-0.6ppm"
#
# 201.1231	1795.1	"?"
#
# 215.1388	13567.2	"b2/-1.4ppm"
#
# 218.1497	7327	"y2/-0.7ppm"
#
# 227.1023	4198.4	"Int/PE/-1.5ppm"
#
# 240.1339	8699.6	"?"
#
# 254.1132	19043	"Int/PSS-H2O/-1.3ppm"
#
# 256.1657	2880.1	"Int/LAA/0.5ppm"
#
# 272.1239	8152.6	"Int/PSS/-0.7ppm"
#
# 289.1866	4778.3	"y3/-1.2ppm"
#
# 311.1716	12568.1	"?"
#
# 314.1341	2659.5	"Int/PES/-1.8ppm"
#
# 346.1792	29210	"b3/-1.5ppm"
#
# 349.2079	4570.6	"y9-H2O^2/9.6ppm"
#
# 358.2081	26015.3	"y9^2/-0.7ppm"
#
# 358.7103	9784.6	"y9^2+i/0.8ppm"
#
# 359.2086	3191.5	"y9^2+2i/-3.2ppm"
#
# 382.2083	7435.5	"?"
#
# 419.2319	7723.7	"a4/-1.6ppm"
#
# 428.1984	2428.8	"?"
#
# 436.7177	5697.9	"?"
#
# 446.2065	3696	"?"
#
# 447.2268	29970.8	"b4/-1.5ppm"
#
# 452.2142	3166.3	"Int/PSSPT-H2O/0.5ppm"
#
# 453.2468	3086.8	"?"
#
# 470.2224	2852.9	"Int/PSSPT/-4.5ppm"
#
# 474.2534	4430.7	"y11^2/1.4ppm"
#
# 488.2549	3724.2	"?"
#
# 499.2329	3096	"?"
#
# 500.7656	4712.9	"y12-H2O^2/-0.3ppm"
#
# 501.2664	3799.3	"y12-NH3^2/13.5ppm,y12-H2O^2+i/-1.4ppm"
#
# 502.2993	19561	"y6/1.3ppm"
#
# 503.3028	5780.4	"y6+i/2.2ppm"
#
# 509.7717	2935.4	"y12^2/0.9ppm"
#
# 516.2848	8872.1	"a5/-0.7ppm"
#
# 541.2795	5490.6	"?"
#
# 544.2793	31257.6	"b5/-1.8ppm"
#
# 559.2899	4566.1	"Int/TMALAA/-1.7ppm"
#
# 573.3347	18411.1	"y7/-1.0ppm"
#
# 574.3372	5743	"Int/ALAAPSSPT-H2O/12.6ppm,y7+i/-1.5ppm"
#
# 581.3035	2425.3	"Int/PTPESP-CO/18.1ppm"
#
# 588.2797	4942.4	"?"
#
# 592.8265	4169.7	"y14-H2O^2/0.1ppm"
#
# 593.3295	3930	"y14-NH3^2/15.2ppm,y14-H2O^2+i/2.2ppm"
#
# 601.8318	23002.8	"y14^2/0.1ppm"
#
# 602.3333	15721.6	"y14^2+i/0.2ppm"
#
# 602.8337	2813.7	"y14^2+2i/-0.3ppm"
#
# 603.3173	2903.8	"a6/0.6ppm"
#
# 612.3168	7265.5	"?"
#
# 630.3279	7840.4	"Int/ATMALAA/-0.1ppm"
#
# 631.3116	30611.6	"b6/-0.8ppm"
#
# 637.3601	15185.6	"y15^2/12.7ppm"
#
# 637.852	3178.3	"y15^2+i/0.4ppm"
#
# 641.3072	4028.2	"?"
#
# 644.3697	3111	"y8/-3.2ppm"
#
# 659.316	4312.5	"?"
#
# 683.3532	5631.4	"?"
#
# 701.3642	10034.5	"Int/AATMALAA/-1.2ppm"
#
# 712.3439	5502.4	"?"
#
# 715.409	63688.5	"y9/-0.7ppm"
#
# 716.4125	27854.8	"y9+i/-0.1ppm"
#
# 717.4127	3276.9	"y9+2i/-0.4ppm"
#
# 730.356	5475.8	"?"
#
# 754.3916	6861.7	"?"
#
# 760.354	21201.6	"b7/-1.1ppm"
#
# 816.4576	5803.5	"y10/0.2ppm"

# %%
import re

# %%
with open('NrevDecoy_NEW.msp', 'w') as file:
    f = open('NrevDecoy.msp')
    total = 0
    
    while True:
        if not total:
            line = f.readline()
        if not line: break
        
        if line.startswith('Name'):
            total += 1
            if not total % 50000:
                print(total)
            
            #print(line[:-1])
            s = line[6:-1].split('/')
            
            seq = s[0]
            
            charge = s[1][0]
            modnum = s[1][2]
            
            name = 'Name: ' + seq + '/' + charge + '\n'
            #print(name)
            file.write(name)
            
            line = f.readline()
            line = f.readline()
            comment = line.split(' ')
            parent = comment[7].split('=')[1]
            collision_energy = comment[9].split('=')[1]
            
            mw = 'MW: ' + parent + '\n'
            #print(mw)
            file.write(mw)
            
            if modnum == '0':
                mods = ' Mods=0'
                modstring = ' ModString=' + seq + '///' + charge
                #print(mods)
                #print(modstring)
                
                
            else:
                modification = []
                
                m1 = s[1][3:]
                m2 = re.split('[(|)]', m1)
                
                for i in m2:
                    tmp = i.split(',')
                    if i != '' and len(tmp) == 3:
                        modification.append(tmp)
                #print(modification)
                
                mods = ' Mods=' + modnum
                for i in modification:
                    mods += '/'
                    mods += i[0]
                    
                    if i[1] == 'M':
                        mods += ',M,Oxidation'
                    
                    elif i[1] == 'C':
                        mods += ',C,Carbamidomethyl'
                        
                #print(mods)
                
                modstring = ' ModString=' + seq + '//'
                cnt = 0
                for i in modification:
                    cnt += 1
                    if i[1] == 'M':
                        modstring =  modstring + 'Oxidation@M' + i[0]
                        
                    elif i[1] == 'C':
                        modstring = modstring + 'Carbamidomethyl@C' + i[0]
                    
                    if cnt != int(modnum):
                        modstring += '; '
                
                #print(modstring)
                
            comment = 'Comment: Parent=' + parent + ' Collision_energy=' + collision_energy + mods + modstring + ' Protein="XXX"\n'
            #print(comment)
            file.write(comment)
            
            
            
            line = f.readline()
            
            while True:
                if line.startswith('Name'):
                    break
                if not line: break
                
                #print(line)
                file.write(line)
                line = f.readline()
                
    f.close()
file.close()
print(total)
# Out:
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 374994

# %%
f = open('NrevDecoy_NEW.msp')

for i in range(1000):
    line = f.readline()
    print(line)
# Out:
# Name: AGAGAGAAAAAAAAAAAAAAAK/2
#
# MW: 798.9263
#
# Comment: Parent=798.9263 Collision_energy=29.43 Mods=0 ModString=AGAGAGAAAAAAAAAAAAAAAK///2 Protein="XXX"
#
# Num peaks: 117
#
# 101.0708	97764.4	"a2/-1.6ppm"
#
# 110.0712	259243.2	"?"
#
# 116.0704	26069.5	"?"
#
# 120.0806	208924.4	"?"
#
# 129.0656	259764.2	"b2/-2.1ppm"
#
# 129.0657	25535.9	"Int/AG/-1.2ppm,Int/GA/-1.2ppm"
#
# 129.1021	361336.8	"IKD/-1.1ppm,y1-H2O/-1.1ppm"
#
# 130.086	120990.5	"y1-NH3/-1.9ppm"
#
# 136.0754	401263.5	"?"
#
# 141.1019	54146.8	"?"
#
# 147.1125	239262.1	"y1/-2.1ppm"
#
# 155.0811	52239.2	"?"
#
# 169.0969	272722.9	"?"
#
# 173.1282	164845.6	"?"
#
# 175.1187	257521.5	"IKF/-1.4ppm"
#
# 183.149	72741.8	"?"
#
# 200.1025	958104.7	"b3/-1.9ppm"
#
# 201.1054	26387.6	"b3+i/-1.4ppm"
#
# 201.123	103584.8	"y2-NH3/-1.8ppm"
#
# 212.1027	28649.9	"?"
#
# 213.0865	47385.4	"?"
#
# 218.1496	44120.9	"y2/-1.5ppm"
#
# 226.1184	53687.9	"?"
#
# 242.113	40070.1	"?"
#
# 244.1652	50732.7	"?"
#
# 254.1495	363209.3	"y3-H2O-NH3/-1.9ppm"
#
# 257.1238	36446.7	"?"
#
# 257.124	1224329.9	"b4/-1.5ppm,y3-H2O+CO/-1.5ppm"
#
# 258.1271	73896.6	"b4+i/-0.4ppm,y3-H2O+CO+i/-0.4ppm"
#
# 271.1395	19571.4	"?"
#
# 271.1762	293322.1	"y3-H2O/-1.2ppm,a4/-1.2ppm"
#
# 283.1403	32984.4	"?"
#
# 283.1759	28564.5	"?"
#
# 289.1864	242734.1	"y3/-2.1ppm"
#
# 297.1552	20175.3	"?"
#
# 313.1502	95582.2	"?"
#
# 325.1864	775584.9	"y4-H2O-NH3/-1.9ppm"
#
# 326.1898	42391.8	"y4-H2O-NH3+i/-0.1ppm"
#
# 328.1609	1600454.8	"b5/-1.8ppm,y4-H2O+CO/-1.8ppm"
#
# 328.1613	41814.3	"?"
#
# 329.1626	149618.5	"b5+i/-4.8ppm,y4-H2O+CO+i/-4.8ppm"
#
# 342.1762	33653.3	"?"
#
# 342.2127	405507.9	"y4-H2O/-2.5ppm,a5/-2.5ppm"
#
# 354.1762	22267.2	"?"
#
# 357.1884	308594.3	"a6/0.9ppm"
#
# 360.2242	147454.5	"y4/0.0ppm"
#
# 367.1713	27548.3	"?"
#
# 367.1716	25666.3	"b6-H2O/-1.9ppm"
#
# 368.1925	46015.5	"?"
#
# 382.2078	731886	"?"
#
# 383.2103	62534.8	"?"
#
# 384.1872	44375.8	"?"
#
# 385.1823	1773724.2	"b6/-1.5ppm"
#
# 386.1849	230900.2	"b6+i/-2.0ppm"
#
# 428.2269	132956.4	"a7/3.7ppm"
#
# 431.2609	495643.6	"y5/-0.9ppm"
#
# 432.2637	30190.2	"y5+i/-0.7ppm"
#
# 438.2086	29863.6	"?"
#
# 438.2091	73528.3	"b7-H2O/-0.8ppm"
#
# 441.245	61334	"y5-H2O+CO/-1.5ppm"
#
# 453.2448	455874.2	"?"
#
# 454.2491	43076.5	"?"
#
# 456.2194	1568386.1	"b7/-1.3ppm"
#
# 457.222	235075.2	"b7+i/-1.7ppm"
#
# 496.2504	29551.8	"?"
#
# 502.2983	239881.5	"y6/-0.2ppm"
#
# 509.2465	23055	"?"
#
# 509.2466	74590.4	"b8-H2O/-0.0ppm"
#
# 512.282	67415.4	"y6-H2O+CO/-1.5ppm"
#
# 524.2817	231866.9	"?"
#
# 525.2848	22162.9	"?"
#
# 527.2563	1182016.9	"b8/-1.6ppm"
#
# 527.2572	26445.4	"?"
#
# 528.2595	209164.7	"b8+i/-1.0ppm"
#
# 555.2883	61569.5	"?"
#
# 573.3351	741356.3	"y7/-0.6ppm"
#
# 574.3386	87145	"y7+i/0.7ppm"
#
# 580.2824	36950.8	"b9-H2O/-2.1ppm"
#
# 583.3197	37299.4	"y7-H2O+CO/-0.3ppm"
#
# 595.3178	93112.3	"?"
#
# 598.2932	780743.7	"b9/-1.7ppm"
#
# 598.294	28506.8	"?"
#
# 599.2963	146597.5	"b9+i/-1.2ppm"
#
# 626.3245	57194.1	"?"
#
# 644.3718	551164.1	"y8/-1.2ppm"
#
# 645.3749	73691.5	"y8+i/-0.8ppm"
#
# 654.3576	46118.5	"y8-H2O+CO/1.0ppm"
#
# 666.3549	23063.4	"?"
#
# 669.3304	456267.1	"b10/-1.6ppm"
#
# 669.331	27664.2	"?"
#
# 670.3334	90213.5	"b10+i/-1.3ppm"
#
# 697.3611	33964.2	"?"
#
# 715.4087	556586	"y9/-1.6ppm"
#
# 716.4114	95708.4	"y9+i/-1.6ppm"
#
# 725.3928	40435.1	"y9-H2O+CO/-1.9ppm"
#
# 740.3669	18991.8	"?"
#
# 740.3682	237790.1	"b11/-0.5ppm"
#
# 741.3697	35086.5	"b11+i/-2.2ppm"
#
# 786.4466	589662.8	"y10/-0.4ppm"
#
# 787.4497	126578.1	"y10+i/0.1ppm"
#
# 796.4298	26216.7	"y10-H2O+CO/-1.8ppm"
#
# 811.4042	86153.5	"b12/-1.7ppm"
#
# 857.4827	695273.1	"y11/-1.6ppm"
#
# 858.486	161580.1	"y11+i/-0.9ppm"
#
# 928.5199	778338.2	"y12/-1.4ppm"
#
# 929.5222	204507.9	"y12+i/-1.7ppm"
#
# 999.5569	792133.5	"y13/-1.3ppm"
#
# 1000.5593	262896.2	"y13+i/-1.6ppm"
#
# 1070.5943	748903.4	"y14/-0.9ppm"
#
# 1071.5974	250705.6	"y14+i/-0.7ppm"
#
# 1141.6311	611860	"y15/-1.1ppm"
#
# 1142.6336	242145.1	"y15+i/-1.4ppm"
#
# 1212.6682	442693.3	"y16/-1.1ppm"
#
# 1213.671	173247.7	"y16+i/-1.0ppm"
#
# 1269.6893	264065.6	"y17/-1.3ppm"
#
# 1270.6915	112235.1	"y17+i/-1.8ppm"
#
# 1340.7251	74808.5	"y18/-2.3ppm"
#
#
#
# Name: AGAGAGAAAAAAAAAAAAAAAK/3
#
# MW: 532.9533
#
# Comment: Parent=532.9533 Collision_energy=29.22 Mods=0 ModString=AGAGAGAAAAAAAAAAAAAAAK///3 Protein="XXX"
#
# Num peaks: 129
#
# 101.0709	976843.8	"a2/-0.8ppm"
#
# 110.0713	376659.9	"?"
#
# 112.0868	26365.1	"?"
#
# 116.0705	77273.4	"?"
#
# 120.0807	709527.5	"?"
#
# 121.0841	36108.3	"?"
#
# 127.0864	39223.7	"?"
#
# 129.0656	120230.4	"Int/AG/-2.0ppm,Int/GA/-2.0ppm"
#
# 129.0657	1650641.9	"b2/-1.4ppm"
#
# 129.1021	837966.9	"IKD/-1.1ppm,y1-H2O/-1.1ppm"
#
# 130.065	78470.1	"?"
#
# 130.069	37610	"b2+i/2.1ppm"
#
# 130.0861	278684.1	"y1-NH3/-1.2ppm"
#
# 136.0755	497615.3	"?"
#
# 141.0654	24439.5	"?"
#
# 141.1019	131153.1	"?"
#
# 143.1176	66394.3	"?"
#
# 145.0969	122645	"?"
#
# 147.1125	501370.4	"y1/-2.1ppm"
#
# 155.0812	104253.9	"?"
#
# 157.0969	88052.1	"y1-H2O+CO/-1.6ppm"
#
# 157.1333	124590.1	"?"
#
# 158.0921	80031.4	"?"
#
# 159.0913	101163.3	"?"
#
# 169.0969	643917.5	"?"
#
# 171.1125	33117.7	"?"
#
# 173.0918	129620.3	"?"
#
# 173.1282	179978.8	"?"
#
# 175.1187	512150.2	"IKF/-1.4ppm"
#
# 183.1126	46509.7	"y2-H2O-NH3/-1.1ppm"
#
# 183.1488	39077.2	"?"
#
# 185.0918	41110.8	"?"
#
# 185.1281	76095.7	"?"
#
# 185.1646	83652.3	"?"
#
# 186.0871	103261.4	"?"
#
# 187.1438	127865.3	"?"
#
# 197.1281	85728.6	"?"
#
# 199.1802	131493.1	"?"
#
# 200.1025	1720602.1	"b3/-1.9ppm"
#
# 200.1027	93493.7	"?"
#
# 200.1391	59859	"y2-H2O/-1.3ppm"
#
# 201.1053	88701.3	"b3+i/-1.9ppm"
#
# 201.123	166715.8	"y2-NH3/-1.8ppm"
#
# 207.1124	83900.1	"?"
#
# 212.1026	80474.5	"?"
#
# 215.1391	117784.4	"?"
#
# 218.1496	175038.2	"y2/-1.5ppm"
#
# 226.1185	89951.3	"?"
#
# 229.1298	78559.8	"?"
#
# 233.1643	81456.4	"?"
#
# 242.1129	48447.8	"?"
#
# 242.1493	62435.4	"?"
#
# 244.1652	88565.7	"?"
#
# 254.1493	450152	"y3-H2O-NH3/-2.4ppm"
#
# 257.1239	1284026.4	"b4/-1.9ppm,y3-H2O+CO/-1.9ppm"
#
# 257.124	136808.4	"?"
#
# 258.1243	103953.1	"b4+i/-10.2ppm,y3-H2O+CO+i/-10.2ppm"
#
# 269.1238	23072.4	"?"
#
# 271.1396	33689.8	"?"
#
# 271.176	403576.9	"y3-H2O/-2.0ppm,a4/-2.0ppm"
#
# 283.1398	168331.2	"?"
#
# 288.2024	117859.2	"?"
#
# 289.1864	524763.6	"y3/-2.1ppm"
#
# 290.1891	24473.7	"y3+i/-2.6ppm"
#
# 297.1551	36497.1	"?"
#
# 300.1653	56582.3	"?"
#
# 313.1501	73670.7	"?"
#
# 314.146	44067.7	"?"
#
# 320.6738	222559.7	"?"
#
# 321.1754	26037.2	"?"
#
# 325.1864	611691.1	"y4-H2O-NH3/-2.2ppm"
#
# 326.1902	69949.4	"y4-H2O-NH3+i/1.1ppm"
#
# 328.1608	1466974.1	"b5/-2.1ppm,y4-H2O+CO/-2.1ppm"
#
# 329.1602	216894.6	"b5+i/-11.6ppm,y4-H2O+CO+i/-11.6ppm"
#
# 340.1602	39167.2	"?"
#
# 342.2126	342366.7	"y4-H2O/-2.8ppm,a5/-2.8ppm"
#
# 354.1758	82324.8	"?"
#
# 356.6936	62461.1	"?"
#
# 357.189	176318.2	"a6/2.4ppm"
#
# 360.2237	271160.8	"y4/-1.1ppm"
#
# 367.1714	128398.5	"?"
#
# 368.1911	41210.8	"?"
#
# 382.2079	468903.3	"?"
#
# 383.2095	61771.3	"?"
#
# 385.1813	82832.6	"?"
#
# 385.1823	1311411.9	"b6/-1.5ppm"
#
# 386.1833	218430.8	"b6+i/-5.7ppm"
#
# 391.7108	269246.2	"?"
#
# 392.2113	49999.2	"?"
#
# 428.2262	78280.2	"a7/2.2ppm"
#
# 431.2609	566873.3	"y5/-0.9ppm"
#
# 432.2634	57515.2	"y5+i/-1.4ppm"
#
# 438.2084	100979.2	"?"
#
# 438.2094	36491.2	"b7-H2O/-0.2ppm"
#
# 453.2447	284873.4	"?"
#
# 456.2193	1237151.2	"b7/-1.5ppm"
#
# 457.2213	242672.3	"b7+i/-3.1ppm"
#
# 496.2484	32403.2	"?"
#
# 502.2984	311277.1	"y6/0.1ppm"
#
# 509.2459	39390.2	"?"
#
# 509.248	31354.5	"b8-H2O/2.5ppm"
#
# 524.2818	181121.5	"?"
#
# 527.2564	1205149.2	"b8/-1.4ppm"
#
# 528.2586	252901.6	"b8+i/-2.6ppm"
#
# 573.3344	1366991.6	"y7/-2.1ppm"
#
# 574.3367	547371.3	"y7+i/-2.9ppm"
#
# 575.3455	302151.3	"y7+2i/9.3ppm"
#
# 580.2823	32954.3	"b9-H2O/-2.3ppm"
#
# 595.3177	61091.2	"?"
#
# 598.2932	964937	"b9/-1.7ppm"
#
# 599.2972	245853.4	"b9+i/0.2ppm"
#
# 644.3716	1064849.2	"y8/-1.7ppm"
#
# 645.3741	220494.5	"y8+i/-1.9ppm"
#
# 669.3302	588182.5	"b10/-1.8ppm"
#
# 670.3325	135790.9	"b10+i/-2.5ppm"
#
# 715.4079	869553.2	"y9/-2.8ppm"
#
# 716.4105	196312.7	"y9+i/-3.0ppm"
#
# 740.3674	259305.2	"b11/-1.6ppm"
#
# 741.3694	43255.2	"b11+i/-2.6ppm"
#
# 780.387	123741.3	"?"
#
# 786.4458	624247	"y10/-1.4ppm"
#
# 787.4475	145545	"y10+i/-2.8ppm"
#
# 811.4035	54270	"b12/-2.5ppm"
#
# 857.4821	398385.2	"y11/-2.3ppm"
#
# 858.4854	84782.7	"y11+i/-1.6ppm"
#
# 928.5188	216608.7	"y12/-2.6ppm"
#
# 929.5226	40226.5	"y12+i/-1.3ppm"
#
# 999.5569	109122.7	"y13/-1.3ppm"
#
# 1070.5957	41924.2	"y14/0.5ppm"
#
#
#
# Name: ASDGPSAGEPPAPPAAAAAAAAAAAR/2
#
# MW: 1094.0431
#
# Comment: Parent=1094.0431 Collision_energy=27.80 Mods=0 ModString=ASDGPSAGEPPAPPAAAAAAAAAAAR///2 Protein="XXX"
#
# Num peaks: 101
#
# 129.1021	456.7	"?"
#
# 169.0977	354.6	"Int/AP/3.2ppm,Int/PA/3.2ppm"
#
# 175.1193	1385.9	"y1/2.0ppm,IRJ/2.0ppm"
#
# 204.0868	1646	"?"
#
# 240.1346	616.9	"Int/AAP/1.4ppm"
#
# 248.161	131.4	"?"
#
# 274.104	992.8	"b3/2.7ppm"
#
# 303.1296	419.7	"a4/-1.2ppm"
#
# 311.171	1818.7	"Int/AAAP/-1.2ppm"
#
# 313.1522	63.6	"?"
#
# 317.1932	2742.1	"y3/0.0ppm"
#
# 331.125	3355.1	"b4/0.6ppm"
#
# 351.9347	294.1	"?"
#
# 382.2084	2807.5	"Int/AAAAP/-0.2ppm"
#
# 383.2106	217.1	"Int/AAAAP+i/-1.9ppm"
#
# 400.1836	931.3	"a5/2.7ppm"
#
# 428.1781	6240.7	"b5/1.3ppm"
#
# 429.1793	274.8	"b5+i/-3.2ppm"
#
# 453.2457	3379.8	"Int/AAAAAP/0.2ppm"
#
# 454.25	76	"?"
#
# 478.772	242.3	"y12^2/8.4ppm"
#
# 487.214	1215.8	"a6/-1.9ppm"
#
# 515.21	11060	"b6/0.8ppm"
#
# 516.2134	1477.1	"b6+i/2.2ppm"
#
# 524.2824	2913	"Int/AAAAAAP/-0.6ppm"
#
# 525.2864	482.7	"Int/AAAAAAP+i/1.6ppm"
#
# 530.3049	2015.2	"y6/0.7ppm"
#
# 531.3087	197.7	"y6+i/2.6ppm"
#
# 558.2529	1278	"a7/2.2ppm"
#
# 568.2379	261.5	"b7-H2O/3.5ppm"
#
# 586.2472	14401.1	"b7/0.9ppm"
#
# 587.2505	2629.3	"b7+i/1.9ppm"
#
# 595.3191	2246.3	"Int/AAAAAAAP/-1.2ppm"
#
# 596.3233	90.7	"Int/AAAAAAAP+i/1.1ppm"
#
# 601.3429	761.2	"y7/1.9ppm"
#
# 611.3389	4626.1	"y15^2/0.5ppm"
#
# 611.8414	3019.7	"y15^2+i/2.0ppm"
#
# 612.3447	163.3	"y15^2+2i/4.9ppm"
#
# 615.2747	893.9	"a8/2.6ppm"
#
# 625.2572	878.5	"b8-H2O/-0.8ppm"
#
# 626.2652	96.5	"b8-H2O+i/8.7ppm"
#
# 643.2686	17128.5	"b8/0.7ppm"
#
# 644.2715	3088.5	"b8+i/0.9ppm"
#
# 666.3556	1440.9	"Int/AAAAAAAAP/-2.0ppm"
#
# 717.36	164.9	"Int/PPAPPEGA/4.7ppm"
#
# 737.3996	431.6	"Int/AAAAAAAAAP/7.5ppm"
#
# 743.4158	2200.5	"y9/-0.1ppm"
#
# 744.316	172.2	"a9/0.2ppm"
#
# 744.4247	358.3	"y9+i/7.5ppm"
#
# 754.3005	1007.2	"b9-H2O/0.4ppm"
#
# 772.3114	19420	"b9/0.9ppm"
#
# 773.314	3925	"b9+i/0.6ppm"
#
# 804.3938	708.6	"Int/PAPPEGASP/6.4ppm,Int/PPAPPEGAS/6.4ppm"
#
# 841.3716	81.5	"a10/4.2ppm"
#
# 851.3533	1112	"b10-H2O/0.4ppm"
#
# 869.3644	15622.5	"b10/1.1ppm"
#
# 870.3662	3495.5	"b10+i/-0.3ppm"
#
# 885.4916	408.7	"y11/1.5ppm"
#
# 938.4644	1110.4	"?"
#
# 938.5218	205	"y12-H2O/4.6ppm"
#
# 938.9685	797.6	"?"
#
# 948.4065	642	"b11-H2O/1.0ppm"
#
# 956.5277	6992.9	"y12/0.4ppm"
#
# 957.5283	2836.4	"y12+i/-1.5ppm"
#
# 966.4182	4190.8	"b11/2.4ppm"
#
# 967.4205	932.4	"b11+i/1.8ppm"
#
# 997.493	610.3	"?"
#
# 998.5184	310.5	"?"
#
# 1053.5788	1814.9	"y13/-0.9ppm"
#
# 1054.5766	469.1	"y13+i/-5.0ppm"
#
# 1073.4909	2244.2	"Int/PPAPPEGASPGD/1.0ppm"
#
# 1074.4962	990.4	"Int/PPAPPEGASPGD+i/3.2ppm"
#
# 1075.5133	284	"Int/PPAPPEGASPGD+2i/16.7ppm"
#
# 1079.5159	1471.1	"?"
#
# 1093.5253	3993.1	"?"
#
# 1093.5822	7871.9	"?"
#
# 1094.5195	7864.4	"?"
#
# 1094.5649	5545.1	"?"
#
# 1150.6301	2511.2	"y14/-2.0ppm"
#
# 1151.6369	1540.4	"y14+i/1.0ppm"
#
# 1203.6597	2388.8	"y15-H2O/0.3ppm"
#
# 1204.656	1667	"y15-NH3/9.2ppm,y15-H2O+i/-4.4ppm"
#
# 1205.6556	371.5	"y15-H2O+2i/-6.6ppm,y15-NH3+i/6.8ppm"
#
# 1221.6714	50000	"y15/1.1ppm"
#
# 1222.6728	30435.6	"y15+i/0.1ppm"
#
# 1223.6687	1912.1	"y15+2i/-4.7ppm"
#
# 1249.5721	249.6	"?"
#
# 1265.6485	516.9	"?"
#
# 1266.6492	656.7	"?"
#
# 1267.6416	514.8	"?"
#
# 1318.7246	7061.3	"y16/1.3ppm"
#
# 1319.7261	3898.6	"y16+i/0.5ppm"
#
# 1415.7771	3464.9	"y17/1.1ppm"
#
# 1416.771	2197.7	"y17+i/-4.6ppm"
#
# 1478.7101	211.5	"?"
#
# 1544.8153	1745.3	"y18/-1.7ppm"
#
# 1545.8217	1584.8	"y18+i/0.6ppm"
#
# 1601.8427	1001.1	"y19/2.0ppm"
#
# 1602.8505	668.1	"y19+i/4.9ppm"
#
# 1672.8713	88.1	"y20/-3.0ppm"
#
# 1673.903	283.7	"y20+i/13.4ppm"
#
#
#
# Name: ASDGPSAGEPPAPPAAAAAAAAAAAR/3
#
# MW: 729.6978
#
# Comment: Parent=729.6978 Collision_energy=30.00 Mods=0 ModString=ASDGPSAGEPPAPPAAAAAAAAAAAR///3 Protein="XXX"
#
# Num peaks: 140
#
# 110.0709	146.6	"?"
#
# 129.102	430.1	"?"
#
# 131.0812	147.7	"a2/-2.5ppm"
#
# 136.0755	242	"?"
#
# 141.1021	201.9	"Int/PA-CO/-1.0ppm"
#
# 142.0495	230.6	"b2-NH3/-2.8ppm"
#
# 147.1125	227.7	"?"
#
# 159.0761	373.2	"b2/-2.1ppm"
#
# 169.0971	610.3	"Int/AP/-0.3ppm,Int/PA/-0.3ppm"
#
# 175.1188	638.4	"y1/-0.9ppm,IRJ/-0.9ppm"
#
# 195.1124	422.9	"Int/PP/-2.1ppm"
#
# 213.1593	119.4	"?"
#
# 227.1027	267.4	"Int/PE/0.3ppm"
#
# 238.1546	151.6	"Int/PAP-CO/-1.7ppm,Int/PPA-CO/-1.7ppm"
#
# 240.1338	433.6	"Int/AAP/-1.9ppm"
#
# 243.1334	704.6	"?"
#
# 244.1283	162.9	"?"
#
# 261.1558	1081.6	"?"
#
# 265.6554	243.2	"y6^2/-1.6ppm"
#
# 266.1496	1935.4	"Int/PAP/-1.2ppm,Int/PPA/-1.2ppm"
#
# 267.1541	248.5	"Int/PAP+i/4.6ppm,Int/PPA+i/4.6ppm"
#
# 274.1033	1093.9	"b3/-0.1ppm"
#
# 277.1169	137.6	"?"
#
# 303.1298	377.1	"a4/-0.4ppm"
#
# 311.1712	891.1	"Int/AAAP/-0.6ppm"
#
# 317.1933	1339.9	"y3/0.3ppm"
#
# 320.6739	131.5	"?"
#
# 324.1549	349.4	"Int/PPE/-1.5ppm"
#
# 326.1128	320.6	"?"
#
# 331.1248	1710.3	"b4/-0.1ppm"
#
# 332.1272	172	"b4+i/-1.5ppm"
#
# 337.1866	498.8	"Int/APPA/-1.3ppm"
#
# 344.2	370.6	"?"
#
# 355.1609	84.6	"Int/PEGA/-0.9ppm"
#
# 356.1689	144.2	"Int/PEGA+i/13.4ppm"
#
# 356.217	1239.3	"?"
#
# 357.2182	230.6	"?"
#
# 363.2026	232.2	"Int/PAPP/-0.2ppm,Int/PPAP/-0.2ppm"
#
# 374.2397	809.7	"?"
#
# 381.177	205.3	"Int/PPEG/0.4ppm"
#
# 382.2079	1034	"Int/AAAAP/-1.6ppm"
#
# 383.211	205.8	"Int/AAAAP+i/-0.9ppm"
#
# 391.7112	461.7	"?"
#
# 400.1829	528.4	"a5/0.5ppm"
#
# 408.2227	190.1	"Int/AAPPA/-3.5ppm"
#
# 428.1775	2552.3	"b5/-0.4ppm"
#
# 429.1799	189.6	"b5+i/-1.5ppm"
#
# 440.2371	364.2	"?"
#
# 440.738	151.5	"?"
#
# 443.2482	1980.9	"y11^2/-0.9ppm"
#
# 443.7502	987.4	"y11^2+i/0.3ppm"
#
# 444.252	177	"y11^2+2i/1.4ppm"
#
# 453.2461	982.6	"Int/AAAAAP/1.1ppm"
#
# 454.2451	223.5	"Int/AAAAAP+i/-7.4ppm"
#
# 459.2684	169.3	"y5/2.0ppm"
#
# 469.7626	227	"y12-H2O^2/1.2ppm"
#
# 478.7669	21626	"y12^2/-0.6ppm"
#
# 479.2615	265.6	"Int/AAAPPA/0.5ppm"
#
# 479.2682	11663.9	"y12^2+i/-0.8ppm"
#
# 479.7693	2515.4	"y12^2+2i/-1.0ppm"
#
# 480.2711	312.6	"y12^2+3i/-0.1ppm"
#
# 487.2145	457.4	"a6/-0.6ppm"
#
# 487.3241	810	"?"
#
# 512.2132	180.5	"?"
#
# 515.2095	3354.1	"b6/-0.4ppm"
#
# 516.213	575.8	"b6+i/1.3ppm"
#
# 524.2821	806.9	"Int/AAAAAAP/-1.2ppm"
#
# 525.2857	189.6	"Int/AAAAAAP+i/0.3ppm"
#
# 527.2956	171.9	"y13^2/3.3ppm"
#
# 530.3042	1440.7	"y6/-0.4ppm"
#
# 531.3085	357.7	"y6+i/2.2ppm"
#
# 539.2453	222.5	"Int/PEGASP/-1.3ppm,Int/PPEGAS/-1.3ppm"
#
# 550.2982	270	"Int/AAAAPPA/-0.3ppm"
#
# 558.248	551	"a7/-8.2ppm"
#
# 568.2372	239.9	"b7-H2O/2.1ppm,Int/AAAPPA+i/-13.8ppm"
#
# 575.82	295.8	"y14^2/0.0ppm"
#
# 583.3442	269.4	"?"
#
# 584.3352	200	"?"
#
# 586.2465	4356.1	"b7/-0.5ppm"
#
# 587.2496	974	"b7+i/0.1ppm"
#
# 589.2968	271.6	"Int/PPAPPE/-2.1ppm"
#
# 595.3198	590.8	"Int/AAAAAAAP/-0.1ppm"
#
# 601.3411	1072.2	"y7/-0.7ppm"
#
# 602.3315	194.2	"y15-H2O^2/-2.6ppm"
#
# 602.3448	169.9	"y7+i/0.7ppm"
#
# 611.3384	12462.7	"y15^2/-0.2ppm"
#
# 611.8398	8059.4	"y15^2+i/-0.2ppm"
#
# 612.3404	2540.8	"y15^2+2i/-1.2ppm"
#
# 612.8425	356.1	"y15^2+3i/-0.1ppm"
#
# 615.2714	278.2	"a8/-3.5ppm"
#
# 621.3358	157.9	"Int/AAAAAPPA/0.5ppm"
#
# 625.2602	219.4	"b8-H2O/4.7ppm,Int/AAAAPPA+i/-9.2ppm"
#
# 643.2514	165.4	"?"
#
# 643.268	4683.3	"b8/-0.3ppm"
#
# 644.2705	1352.9	"b8+i/-0.8ppm"
#
# 650.8665	557.3	"y16-H2O^2/9.4ppm"
#
# 659.8638	187	"y16^2/-1.5ppm"
#
# 660.3649	202.4	"y16^2+i/-1.9ppm"
#
# 666.3563	536.7	"Int/AAAAAAAAP/-1.0ppm"
#
# 672.379	355.2	"y8/0.4ppm"
#
# 692.3713	189.5	"Int/AAAAAAPPA/-1.9ppm"
#
# 707.3467	438.8	"Int/PAPPEGAS/15.3ppm"
#
# 707.8494	271.4	"?"
#
# 729.3699	1733.3	"?"
#
# 729.451	12708.8	"?"
#
# 730.4532	17171.6	"?"
#
# 737.3947	241.3	"Int/AAAAAAAAAP/0.9ppm"
#
# 743.4153	1874.5	"y9/-0.7ppm"
#
# 744.4186	529.7	"y9+i/0.0ppm"
#
# 754.3035	271.9	"b9-H2O/5.2ppm,Int/AAAAAPPA+i/-7.0ppm"
#
# 772.3105	5292.8	"b9/-0.5ppm"
#
# 773.3131	1449.1	"b9+i/-0.8ppm"
#
# 774.3147	205.3	"b9+2i/-2.1ppm"
#
# 804.3886	331.3	"Int/PAPPEGASP/-0.1ppm,Int/PPAPPEGAS/-0.1ppm"
#
# 808.3485	637.6	"Int/PPEGASPGD/1.6ppm"
#
# 814.4532	926	"y10/0.3ppm"
#
# 815.4603	375.4	"y10+i/4.8ppm"
#
# 834.4365	286.6	"Int/AAAAAAAAPPA/-12.4ppm"
#
# 851.3545	161.3	"b10-H2O/2.1ppm,Int/AAAAAAPPA+i/-8.9ppm"
#
# 869.3635	5320.4	"b10/-0.2ppm"
#
# 870.3629	1470.4	"b10+i/-4.9ppm"
#
# 871.3637	315.5	"b10+2i/-7.2ppm"
#
# 885.4897	4266	"y11/-0.3ppm"
#
# 886.492	1755.3	"y11+i/-0.8ppm"
#
# 887.4959	552.5	"Int/PPAPPEGASPGD-CO/-13.2ppm,y11+2i/0.6ppm"
#
# 948.4088	226.8	"b11-H2O/4.0ppm"
#
# 956.5273	4642.3	"y12/0.1ppm"
#
# 957.5304	2436.8	"y12+i/0.4ppm"
#
# 958.5303	448.4	"Int/PPAPPEGASPGDS-H2O/17.4ppm,y12+2i/-1.9ppm"
#
# 963.4754	218	"?"
#
# 966.4159	2809.1	"b11/-0.5ppm"
#
# 967.4187	731.6	"b11+i/-0.5ppm"
#
# 968.4222	138.6	"b11+2i/0.8ppm"
#
# 1053.5749	582.9	"y13/-4.1ppm"
#
# 1054.5814	232.6	"y13+i/-1.1ppm"
#
# 1073.4878	215.3	"Int/PPAPPEGASPGD/-1.9ppm"
#
# 1150.6319	1491.4	"y14/-0.6ppm"
#
# 1151.6353	762.2	"y14+i/-0.2ppm"
#
# 1221.6716	1221.9	"y15/1.3ppm"
#
# 1222.6675	887.6	"y15+i/-3.7ppm"
#
#
#
# Name: SVAAAAAAAAAR/2
#
# MW: 500.7803
#
# Comment: Parent=500.7803 Collision_energy=28.66 Mods=0 ModString=SVAAAAAAAAAR///2 Protein="XXX"
#
# Num peaks: 64
#
# 101.0712	31202.7	"?"
#
# 110.0714	170899.8	"?"
#
# 120.0809	103773.7	"?"
#
# 129.1023	265656.1	"?"
#
# 130.0864	69344	"?"
#
# 136.0757	118193.1	"?"
#
# 141.1022	50070.9	"?"
#
# 143.1179	88012.1	"?"
#
# 147.1128	97791.6	"?"
#
# 158.0924	36077.8	"y1-NH3/-0.0ppm"
#
# 159.1129	343243.4	"a2/1.0ppm"
#
# 169.0972	390095	"Int/VS-H2O/0.3ppm"
#
# 170.1006	12566.4	"Int/VS-H2O+i/3.1ppm"
#
# 171.1129	65509	"Int/AV/0.6ppm"
#
# 175.119	246637.9	"y1/0.3ppm,IRJ/0.3ppm"
#
# 187.1077	926743.5	"b2/-0.0ppm"
#
# 188.111	26874.6	"b2+i/3.5ppm"
#
# 201.1234	48524.9	"?"
#
# 229.1295	46035.5	"y2-NH3/-0.1ppm"
#
# 240.1342	285784.4	"?"
#
# 241.1375	11921.1	"?"
#
# 242.1134	54297	"?"
#
# 246.156	111751.4	"y2/-0.3ppm"
#
# 258.1448	1524515.6	"b3/-0.1ppm"
#
# 259.1481	89787.4	"b3+i/2.3ppm"
#
# 283.1763	19620.2	"?"
#
# 300.1668	28842.7	"y3-NH3/0.5ppm"
#
# 301.187	339041.2	"a4/-0.1ppm"
#
# 302.1904	12705.1	"a4+i/2.5ppm"
#
# 311.1712	354620.6	"?"
#
# 312.1743	30519.7	"?"
#
# 313.1505	61300	"?"
#
# 313.1865	12798.3	"?"
#
# 317.1931	138209.9	"y3/-0.3ppm"
#
# 329.1818	967074.4	"b4/-0.5ppm"
#
# 330.185	85032.7	"b4+i/1.0ppm"
#
# 372.224	249529.1	"a5/-0.4ppm"
#
# 373.2264	15079.5	"a5+i/-1.5ppm"
#
# 382.2084	169218.2	"?"
#
# 383.2112	13742.1	"?"
#
# 384.2245	13326.8	"?"
#
# 388.2303	373836.6	"y4/-0.0ppm"
#
# 389.2329	45092.4	"y4+i/-0.2ppm"
#
# 400.2188	605827.8	"b5/-0.7ppm"
#
# 401.2217	64033.8	"b5+i/-0.4ppm"
#
# 443.2611	75351	"a6/-0.4ppm"
#
# 453.2457	32898.3	"?"
#
# 459.2674	738076.1	"y5/-0.0ppm"
#
# 460.2703	132118	"y5+i/0.4ppm"
#
# 471.2559	317205.1	"b6/-0.6ppm"
#
# 472.2594	34492.8	"b6+i/1.1ppm"
#
# 500.2818	213450.2	"?"
#
# 530.3046	1202123.1	"y6/0.1ppm"
#
# 531.3076	261387.4	"y6+i/0.6ppm"
#
# 542.2931	117673.5	"b7/-0.3ppm"
#
# 601.3417	1634981.3	"y7/0.1ppm"
#
# 602.3448	414124.7	"y7+i/0.7ppm"
#
# 613.3305	33681.6	"b8/0.2ppm"
#
# 672.3788	1542360.9	"y8/0.1ppm"
#
# 673.3819	440885.5	"y8+i/0.6ppm"
#
# 743.4159	743110	"y9/0.0ppm"
#
# 744.4186	230861.3	"y9+i/0.0ppm"
#
# 814.453	427337	"y10/0.0ppm"
#
# 815.4558	155120	"y10+i/0.1ppm"
#
#
#
# Name: GAFAGAAAAAAAAR/2
#
# MW: 573.8044
#
# Comment: Parent=573.8044 Collision_energy=29.03 Mods=0 ModString=GAFAGAAAAAAAAR///2 Protein="XXX"
#
# Num peaks: 100
#
# 101.0715	48110	"a2/4.4ppm"
#
# 101.0717	13637	"?"
#
# 102.0557	11256.8	"?"
#
# 110.0718	40122.3	"?"
#
# 112.0877	6558.2	"IRG/6.9ppm"
#
# 116.0713	2747.6	"IRI/6.0ppm"
#
# 120.0813	48963	"IFA/4.4ppm"
#
# 129.0661	120066.1	"b2/2.1ppm"
#
# 129.0665	5755.7	"Int/GA/5.0ppm"
#
# 129.1028	90577.6	"?"
#
# 130.0868	15572.9	"?"
#
# 136.0761	84754.2	"?"
#
# 141.1026	11608	"?"
#
# 143.1183	10476.6	"?"
#
# 147.1132	33543.1	"?"
#
# 157.0971	3060.6	"?"
#
# 157.1341	6856.6	"?"
#
# 158.0928	17233.1	"y1-NH3/2.5ppm"
#
# 159.0771	6479.7	"?"
#
# 159.0922	4337.8	"y1-NH3+i/-17.2ppm"
#
# 169.0976	65860	"?"
#
# 171.0768	3508	"?"
#
# 171.1132	6102.5	"?"
#
# 173.0928	5574.4	"?"
#
# 173.1291	16063	"?"
#
# 175.1193	84560.4	"y1/2.0ppm,IRJ/2.0ppm"
#
# 176.1229	1922.7	"y1+i/9.4ppm,IRJ+i/9.4ppm"
#
# 183.15	6767.7	"?"
#
# 185.1292	7066.2	"?"
#
# 185.1656	16511.2	"?"
#
# 187.1447	4501.6	"?"
#
# 197.1291	10804.4	"?"
#
# 199.1808	11316.5	"?"
#
# 200.104	6040.1	"?"
#
# 200.14	4439	"?"
#
# 201.1241	17202.5	"?"
#
# 204.135	7151.3	"?"
#
# 207.1138	8946.1	"?"
#
# 213.0875	9816	"?"
#
# 213.1604	8769.9	"?"
#
# 215.1403	25856.5	"?"
#
# 226.1193	5075.6	"?"
#
# 227.1762	6245.8	"?"
#
# 228.1355	5483.3	"?"
#
# 230.1149	4991.6	"?"
#
# 240.1349	59770.6	"?"
#
# 242.1147	8164.4	"?"
#
# 242.1513	8984.2	"?"
#
# 243.1352	12358.6	"?"
#
# 244.1662	6375.1	"?"
#
# 246.1568	13576.6	"y2/3.4ppm"
#
# 248.1402	4143.6	"a3/4.3ppm"
#
# 255.1457	9120	"?"
#
# 258.1102	3000.5	"?"
#
# 260.198	8366.8	"?"
#
# 271.1408	5353.2	"?"
#
# 276.135	215338.7	"b3/3.2ppm"
#
# 277.137	6471.4	"b3+i/-0.0ppm"
#
# 283.1787	4289.5	"?"
#
# 300.1714	16222.5	"y3-NH3/16.5ppm,b4+i/-9.9ppm"
#
# 311.1724	78803.3	"?"
#
# 313.1526	11254.8	"?"
#
# 317.1935	8161	"y3/0.9ppm"
#
# 319.1773	48309.5	"a4/3.4ppm"
#
# 342.1785	5430.3	"?"
#
# 347.1724	157732.3	"b4/3.8ppm"
#
# 347.1736	4645.6	"?"
#
# 371.2056	5261	"y4-NH3/4.4ppm"
#
# 376.1986	41109.8	"a5/2.0ppm"
#
# 382.2099	40134.4	"?"
#
# 388.2314	22136.4	"y4/2.6ppm"
#
# 390.2148	4109.6	"?"
#
# 404.1938	118272.6	"b5/2.7ppm"
#
# 405.1986	6614.6	"b5+i/8.3ppm"
#
# 413.2166	5576.9	"?"
#
# 418.2114	5138.7	"?"
#
# 447.2366	18156.8	"a6/3.9ppm"
#
# 453.2486	12353.8	"?"
#
# 459.2693	19235.5	"y5/3.7ppm"
#
# 475.2307	82813.3	"b6/1.7ppm"
#
# 476.236	6209.8	"b6+i/7.6ppm"
#
# 484.254	2767.5	"?"
#
# 489.25	3677.9	"?"
#
# 513.2821	2925.7	"y6-NH3/7.4ppm"
#
# 530.306	173529.2	"y6/2.6ppm"
#
# 531.3104	24112.7	"y6+i/5.4ppm"
#
# 546.2695	39470.6	"b7/4.9ppm"
#
# 573.3372	84875.1	"?"
#
# 601.3435	167775	"y7/2.9ppm"
#
# 602.3467	26019.6	"y7+i/3.6ppm"
#
# 672.3806	198280.2	"y8/2.6ppm"
#
# 673.3819	48489.8	"y8+i/0.6ppm"
#
# 688.3389	5787.7	"b9/-3.8ppm"
#
# 743.4185	201465.5	"y9/3.3ppm"
#
# 744.4214	42068.9	"y9+i/3.5ppm"
#
# 800.4395	157678.7	"y10/2.6ppm"
#
# 801.4425	38584.5	"y10+i/2.9ppm"
#
# 871.4781	48237.2	"y11/4.0ppm"
#
# 872.4822	11911.7	"y11+i/5.4ppm"
#
# 1018.5493	15681.5	"y12/6.5ppm"
#
#
#
# Name: AHMQAAAAAAAAK/2
#
# MW: 599.8035
#
# Comment: Parent=599.8035 Collision_energy=32.00 Mods=1/2,M,Oxidation ModString=AHMQAAAAAAAAK//Oxidation@M2 Protein="XXX"
#
# Num peaks: 227
#
# 122.0714	284.5	"?"
#
# 127.0867	1028.1	"?"
#
# 129.1022	9420.2	"IKD/-0.3ppm,y1-H2O/-0.3ppm"
#
# 130.0863	4732.7	"y1-NH3/0.4ppm"
#
# 130.1055	869.2	"IKD+i/3.6ppm,y1-H2O+i/3.6ppm"
#
# 136.0757	1277.1	"?"
#
# 141.0661	354.5	"?"
#
# 141.1022	2792.9	"?"
#
# 143.118	2011	"?"
#
# 147.1129	8359	"y1/0.7ppm"
#
# 148.1164	728.3	"y1+i/5.3ppm"
#
# 155.0816	968.2	"?"
#
# 156.0768	3176.6	"IHF/0.3ppm"
#
# 157.0974	885.1	"y1-H2O+CO/1.6ppm"
#
# 158.0926	1175.2	"?"
#
# 167.0821	603.8	"?"
#
# 167.0929	2290.4	"?"
#
# 168.0768	495.3	"?"
#
# 169.0972	8783.6	"?"
#
# 169.1334	639.8	"?"
#
# 171.0762	365.6	"?"
#
# 171.1128	461.9	"?"
#
# 173.0921	914.2	"?"
#
# 173.1284	249.4	"?"
#
# 175.119	8253.7	"IKF/0.3ppm"
#
# 181.0973	636.2	"?"
#
# 181.1083	258.1	"?"
#
# 185.0918	860.1	"?"
#
# 185.1288	238.1	"?"
#
# 185.1649	1146.4	"?"
#
# 192.0765	237.8	"b2-NH3/-2.0ppm"
#
# 197.1284	824.8	"?"
#
# 199.1079	1030.2	"?"
#
# 200.1392	412.8	"y2-H2O/-0.8ppm"
#
# 201.0872	648.1	"?"
#
# 201.1232	590.1	"y2-NH3/-0.8ppm"
#
# 203.1032	646.1	"?"
#
# 204.1348	874.1	"?"
#
# 209.0924	218.6	"?"
#
# 209.1033	15035.8	"b2/-0.0ppm"
#
# 209.1038	1263.6	"Int/HA/2.4ppm"
#
# 211.1445	148.8	"?"
#
# 212.1031	980.6	"?"
#
# 213.087	333.6	"?"
#
# 217.0817	344.1	"?"
#
# 218.1499	2016.7	"y2/-0.1ppm"
#
# 221.1035	651.7	"?"
#
# 224.103	471.5	"?"
#
# 226.119	1180.4	"?"
#
# 226.1553	3216.8	"?"
#
# 227.1028	1614.5	"?"
#
# 227.1137	478.5	"?"
#
# 228.134	423.4	"y2-H2O+CO/-1.2ppm"
#
# 228.1711	2237.5	"?"
#
# 230.1135	769.5	"?"
#
# 231.098	263.6	"?"
#
# 234.1458	868.2	"?"
#
# 240.0977	1303.9	"?"
#
# 240.1342	7965.4	"?"
#
# 241.0822	1507.2	"?"
#
# 241.1378	568.2	"?"
#
# 242.1135	1448.9	"?"
#
# 244.0928	592.5	"?"
#
# 244.1655	2951.2	"?"
#
# 245.1689	398.7	"?"
#
# 249.0987	196.2	"?"
#
# 251.6546	484.8	"y6^2/5.1ppm"
#
# 253.1293	9088.3	"?"
#
# 254.1504	915	"?"
#
# 255.1455	591.2	"?"
#
# 256.1296	1746.4	"?"
#
# 256.1652	2059	"?"
#
# 258.1454	4171.4	"?"
#
# 260.1976	461.1	"?"
#
# 269.1241	1316.6	"?"
#
# 271.1773	200.8	"y3-H2O/2.5ppm"
#
# 272.1716	1414.3	"?"
#
# 275.1712	289.8	"?"
#
# 276.1552	2615	"?"
#
# 278.1258	602.4	"?"
#
# 283.1769	750.4	"?"
#
# 284.1248	553.1	"?"
#
# 285.1024	544.4	"Int/mH/2.9ppm"
#
# 287.1717	1621.3	"y7^2/0.9ppm"
#
# 289.1624	608.5	"?"
#
# 289.1881	5579	"y3/3.0ppm"
#
# 290.1892	318.6	"y3+i/-1.4ppm"
#
# 290.6902	623.4	"y8-CH3SOH^2/-1.5ppm"
#
# 292.1402	146.9	"?"
#
# 294.1471	351.8	"?"
#
# 295.1398	350.2	"?"
#
# 296.2264	2621.1	"y4-CH3SOH/1.3ppm"
#
# 297.1559	817.3	"?"
#
# 301.1877	355.3	"?"
#
# 303.2398	412.8	"?"
#
# 311.1714	6326.8	"?"
#
# 313.1509	2133.6	"?"
#
# 319.1561	732.9	"?"
#
# 322.6595	984.3	"?"
#
# 322.6911	1261.5	"y8^2/2.8ppm"
#
# 325.1507	1184.9	"?"
#
# 326.171	300.2	"?"
#
# 328.1441	767.7	"a3/1.6ppm"
#
# 333.2129	308.4	"?"
#
# 338.128	515.9	"b3-H2O/-0.8ppm"
#
# 341.2187	534.6	"?"
#
# 345.2125	923	"?"
#
# 347.1376	670.9	"?"
#
# 349.252	440.8	"y5-CH3SOH-H2O/-0.6ppm"
#
# 356.1387	26974.9	"b3/-0.1ppm"
#
# 356.1426	471.1	"?"
#
# 357.1425	1387.9	"b3+i/4.6ppm"
#
# 358.2098	1037.4	"y9^2/2.9ppm"
#
# 360.2257	3481.8	"y4/3.1ppm"
#
# 367.2606	1677.5	"y5-CH3SOH/-4.1ppm"
#
# 368.1931	597.8	"?"
#
# 368.2629	231.6	"y5-CH3SOH+i/-4.8ppm"
#
# 382.1405	932.1	"?"
#
# 382.2085	2970.8	"?"
#
# 384.1877	1300	"?"
#
# 398.2036	353.5	"?"
#
# 399.1555	1347.9	"?"
#
# 413.2407	1519.3	"y10-H2O^2/16.8ppm"
#
# 413.252	527.6	"y5-H2O/2.2ppm"
#
# 414.237	802.3	"y5-NH3/3.8ppm"
#
# 418.1763	486.5	"?"
#
# 420.1964	303	"?"
#
# 422.2381	625.6	"y10^2/0.6ppm"
#
# 428.2566	677.9	"?"
#
# 428.7465	298	"?"
#
# 431.2608	2973.3	"y5/-0.6ppm"
#
# 432.2606	163.8	"y5+i/-5.2ppm"
#
# 438.3001	4486.7	"y6-CH3SOH/0.1ppm"
#
# 439.3039	424.8	"y6-CH3SOH+i/1.8ppm"
#
# 443.2638	482	"?"
#
# 450.2034	3747.4	"?"
#
# 453.213	251.4	"?"
#
# 453.2479	341.4	"?"
#
# 454.2672	909.6	"?"
#
# 456.2023	6704.1	"a4/-0.4ppm"
#
# 463.2424	216.1	"?"
#
# 470.7313	129.4	"?"
#
# 480.2161	752	"?"
#
# 484.1973	17168.2	"b4/-0.1ppm"
#
# 484.1994	747.9	"?"
#
# 485.2017	464.8	"b4+i/5.5ppm"
#
# 491.2366	1061.8	"b11^2/9.0ppm"
#
# 502.2975	7100.6	"y6/-1.2ppm"
#
# 503.3019	1118.3	"y6+i/1.3ppm"
#
# 509.3371	7218.3	"y7-CH3SOH/-0.1ppm"
#
# 510.341	1293	"y7-CH3SOH+i/1.6ppm"
#
# 516.3519	342.3	"?"
#
# 518.1945	444.9	"?"
#
# 527.2391	4596.5	"a5/-1.3ppm"
#
# 527.2396	294.6	"?"
#
# 527.2763	733	"?"
#
# 528.2824	162.6	"?"
#
# 534.2771	830.8	"?"
#
# 535.2861	369.2	"?"
#
# 537.2253	344.6	"b5-H2O/4.2ppm,y3-NH3/4.2ppm"
#
# 538.2666	171.2	"?"
#
# 539.2962	361.2	"?"
#
# 549.279	977.8	"?"
#
# 550.2676	1246.4	"?"
#
# 550.7692	4466.2	"?"
#
# 555.2342	10412.1	"b5/-0.7ppm"
#
# 555.2357	1625.5	"?"
#
# 555.2894	1103	"y12-H2O^2/17.5ppm"
#
# 555.3278	475.2	"y7-H2O/3.9ppm"
#
# 556.3142	452.5	"?"
#
# 557.3026	1354.9	"?"
#
# 562.2735	1368.1	"?"
#
# 565.3153	402.8	"?"
#
# 573.3348	8372.9	"y7/-0.8ppm"
#
# 574.3408	1649.8	"y7+i/3.5ppm"
#
# 580.374	9090.3	"y8-CH3SOH/-0.3ppm"
#
# 581.2714	370.5	"?"
#
# 581.309	539.9	"?"
#
# 581.3755	2292.1	"y8-CH3SOH+i/-1.9ppm"
#
# 582.2942	1045.6	"?"
#
# 582.3318	626.6	"?"
#
# 583.2818	844.9	"?"
#
# 596.2731	513.6	"?"
#
# 598.2763	1160.9	"a6/-0.9ppm"
#
# 598.2777	1142.5	"?"
#
# 598.765	580.7	"?"
#
# 598.8081	4226.5	"?"
#
# 599.2786	7868.9	"?"
#
# 599.3166	14119.8	"?"
#
# 599.3613	1260.8	"?"
#
# 599.7649	724.8	"?"
#
# 599.8019	1272	"p/-2.7ppm"
#
# 600.2119	3408.7	"?"
#
# 600.2734	1246	"?"
#
# 600.309	16946.7	"?"
#
# 600.3489	14266.4	"?"
#
# 604.2925	509.6	"?"
#
# 605.3166	263.9	"?"
#
# 626.2707	1760.6	"?"
#
# 626.2712	4337.1	"b6/-0.8ppm"
#
# 626.3641	491.6	"y8-H2O/2.6ppm"
#
# 633.3099	2407.9	"?"
#
# 634.3172	713.1	"?"
#
# 637.3011	2901.1	"?"
#
# 644.3711	9317.6	"y8/-1.7ppm"
#
# 645.3755	2096.9	"y8+i/0.3ppm"
#
# 651.4105	8325.3	"y9-CH3SOH/-1.0ppm"
#
# 652.4174	2000.4	"y9-CH3SOH+i/3.9ppm"
#
# 656.3136	369.8	"?"
#
# 669.3136	811.7	"a7/-0.3ppm"
#
# 675.3193	846.1	"?"
#
# 697.3098	926.7	"b7/2.3ppm"
#
# 697.3105	1650.4	"?"
#
# 704.3477	1276.2	"?"
#
# 705.3456	333.4	"?"
#
# 715.4082	6808.2	"y9/-1.6ppm"
#
# 716.4163	1709.5	"y9+i/4.3ppm"
#
# 752.3962	194.3	"?"
#
# 768.349	1499.7	"?"
#
# 779.4658	2982.6	"y10-CH3SOH/-4.5ppm"
#
# 780.4741	667.3	"y10-CH3SOH+i/1.5ppm"
#
# 839.3872	490	"?"
#
# 843.4692	2285.7	"y10/0.9ppm"
#
# 844.4742	679.1	"y10+i/3.3ppm"
#
# 926.5097	1540	"y11-CH3SOH/4.3ppm"
#
# 990.5094	319.4	"y11/5.4ppm"
#
# 1052.4991	611.8	"b12/4.7ppm"
#
#
#
# Name: TLMTPSEPTPSSPAALAMTAAAAAAAAK/3
#
# MW: 867.1084
#
# Comment: Parent=867.1084 Collision_energy=30.00 Mods=0 ModString=TLMTPSEPTPSSPAALAMTAAAAAAAAK///3 Protein="XXX"
#
# Num peaks: 118
#
# 101.0709	1793	"?"
#
# 104.0528	2373.1	"IMA/-0.4ppm"
#
# 110.0711	7745.3	"?"
#
# 120.0805	7042.2	"?"
#
# 129.1022	11975.7	"IKD/-0.3ppm,y1-H2O/-0.3ppm"
#
# 130.0862	4548.3	"y1-NH3/-0.4ppm"
#
# 136.0754	5498.4	"?"
#
# 147.1125	9547.7	"y1/-2.1ppm"
#
# 155.0812	2923.4	"?"
#
# 157.0971	3351.2	"y1-H2O+CO/-0.3ppm"
#
# 167.0814	6661.9	"Int/PS-H2O/-0.6ppm"
#
# 169.097	8247.7	"?"
#
# 171.1125	4640.8	"Int/PT-CO/-1.8ppm"
#
# 175.1185	3618.4	"IKF/-2.6ppm"
#
# 185.0918	9884.3	"Int/PS/-1.4ppm"
#
# 185.1282	1521.7	"?"
#
# 187.1439	4674.2	"a2/-1.6ppm"
#
# 199.1076	7920.5	"Int/PE-CO/-0.6ppm,Int/PT/-0.6ppm"
#
# 201.1231	1795.1	"?"
#
# 215.1388	13567.2	"b2/-1.4ppm"
#
# 218.1497	7327	"y2/-0.7ppm"
#
# 227.1023	4198.4	"Int/PE/-1.5ppm"
#
# 240.1339	8699.6	"?"
#
# 254.1132	19043	"Int/PSS-H2O/-1.3ppm"
#
# 256.1657	2880.1	"Int/LAA/0.5ppm"
#
# 272.1239	8152.6	"Int/PSS/-0.7ppm"
#
# 289.1866	4778.3	"y3/-1.2ppm"
#
# 311.1716	12568.1	"?"
#
# 314.1341	2659.5	"Int/PES/-1.8ppm"
#
# 346.1792	29210	"b3/-1.5ppm"
#
# 349.2079	4570.6	"y9-H2O^2/9.6ppm"
#
# 358.2081	26015.3	"y9^2/-0.7ppm"
#
# 358.7103	9784.6	"y9^2+i/0.8ppm"
#
# 359.2086	3191.5	"y9^2+2i/-3.2ppm"
#
# 382.2083	7435.5	"?"
#
# 419.2319	7723.7	"a4/-1.6ppm"
#
# 428.1984	2428.8	"?"
#
# 436.7177	5697.9	"?"
#
# 446.2065	3696	"?"
#
# 447.2268	29970.8	"b4/-1.5ppm"
#
# 452.2142	3166.3	"Int/PSSPT-H2O/0.5ppm"
#
# 453.2468	3086.8	"?"
#
# 470.2224	2852.9	"Int/PSSPT/-4.5ppm"
#
# 474.2534	4430.7	"y11^2/1.4ppm"
#
# 488.2549	3724.2	"?"
#
# 499.2329	3096	"?"
#
# 500.7656	4712.9	"y12-H2O^2/-0.3ppm"
#
# 501.2664	3799.3	"y12-NH3^2/13.5ppm,y12-H2O^2+i/-1.4ppm"
#
# 502.2993	19561	"y6/1.3ppm"
#
# 503.3028	5780.4	"y6+i/2.2ppm"
#
# 509.7717	2935.4	"y12^2/0.9ppm"
#
# 516.2848	8872.1	"a5/-0.7ppm"
#
# 541.2795	5490.6	"?"
#
# 544.2793	31257.6	"b5/-1.8ppm"
#
# 559.2899	4566.1	"Int/TMALAA/-1.7ppm"
#
# 573.3347	18411.1	"y7/-1.0ppm"
#
# 574.3372	5743	"Int/ALAAPSSPT-H2O/12.6ppm,y7+i/-1.5ppm"
#
# 581.3035	2425.3	"Int/PTPESP-CO/18.1ppm"
#
# 588.2797	4942.4	"?"
#
# 592.8265	4169.7	"y14-H2O^2/0.1ppm"
#
# 593.3295	3930	"y14-NH3^2/15.2ppm,y14-H2O^2+i/2.2ppm"
#
# 601.8318	23002.8	"y14^2/0.1ppm"
#
# 602.3333	15721.6	"y14^2+i/0.2ppm"
#
# 602.8337	2813.7	"y14^2+2i/-0.3ppm"
#
# 603.3173	2903.8	"a6/0.6ppm"
#
# 612.3168	7265.5	"?"
#
# 630.3279	7840.4	"Int/ATMALAA/-0.1ppm"
#
# 631.3116	30611.6	"b6/-0.8ppm"
#
# 637.3601	15185.6	"y15^2/12.7ppm"
#
# 637.852	3178.3	"y15^2+i/0.4ppm"
#
# 641.3072	4028.2	"?"
#
# 644.3697	3111	"y8/-3.2ppm"
#
# 659.316	4312.5	"?"
#
# 683.3532	5631.4	"?"
#
# 701.3642	10034.5	"Int/AATMALAA/-1.2ppm"
#
# 712.3439	5502.4	"?"
#
# 715.409	63688.5	"y9/-0.7ppm"
#
# 716.4125	27854.8	"y9+i/-0.1ppm"
#
# 717.4127	3276.9	"y9+2i/-0.4ppm"
#
# 730.356	5475.8	"?"
#
# 754.3916	6861.7	"?"
#
# 760.354	21201.6	"b7/-1.1ppm"
#
# 816.4576	5803.5	"y10/0.2ppm"
