# %%
# %matplotlib inline
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
NNt1_1 = pd.read_excel('./target_decoy/HEK/TPRP_10_NEW_1_target.xlsx')
NNt1_1.head()
# Out:
#                                            ### Query  Rk              ID  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01873.01873.3   1   LSVEADINGLR/3
# 1  b1906_293T_proteinID_01A_QE3_122212.01882.01882.3   1     LAAFGQLHK/3
# 2  b1906_293T_proteinID_01A_QE3_122212.01899.01899.4   1  RRPENPKPQDGK/4
# 3  b1906_293T_proteinID_01A_QE3_122212.01905.01905.3   1  RRPENPKPQDGK/3
# 4  b1906_293T_proteinID_01A_QE3_122212.01909.01909.3   1   HGGYKPSDEHK/3
#
#      Dot   Delta DelRk  DBias  MzDiff  #Cand  MeanDot  ...  PValue  KSScore  \
# 0  0.336  0.0113   [2]      0   0.330    104    0.102  ...      -1        0
# 1  0.196  0.0110   [2]      0  -0.002     57    0.072  ...      -1        0
# 2  0.470  0.2830   [2]      0  -0.001     10    0.144  ...      -1        0
# 3  0.600  0.3030   [2]      0  -0.002    120    0.106  ...      -1        0
# 4  0.601  0.2650   [2]      0  -0.003     45    0.087  ...      -1        0
#
# ...

# %%
NNt1_2 = pd.read_excel('./target_decoy/HEK/TPRP_10_NEW_2_target.xlsx')
NNt1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55820.55820.4   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55825.55825.4   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55826.55826.3   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55834.55834.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55835.55835.2   1
#
#                                          ID    Dot  Delta DelRk  DBias  \
# 0       NDLSHPIHADNC[160]LLDPEANEC[160]WK/4  0.142  0.072   [2]      0
# 1        KLTATPTPLGGM[147]TGFHM[147]QTEDR/4  0.179  0.014   [2]      0
# 2                    PVTTPEEIAQVATISANGDK/3  0.756  0.501   [2]      0
# 3  FQALC[160]NLYGAITIAQAM[147]IFC[160]HTR/3  0.126  0.007   [2]      0
# 4  VEDGAQQC[160]LDC[160]GLC[160]FASPGSLSR/2  0.716  0.654   [2]      0
#
#    MzDiff  #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status  \
# 0   0.001      2    0.106  ...      -1        0          0        ()  Normal
# ...

# %%
NNd1_1 = pd.read_excel('./target_decoy/HEK/TPRP_10_NEW_1_decoy.xlsx')
NNd1_1.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1906_293T_proteinID_01A_QE3_122212.01886.01886.2   1
# 1  b1906_293T_proteinID_01A_QE3_122212.01911.01911.3   1
# 2  b1906_293T_proteinID_01A_QE3_122212.01913.01913.2   1
# 3  b1906_293T_proteinID_01A_QE3_122212.01926.01926.4   1
# 4  b1906_293T_proteinID_01A_QE3_122212.01927.01927.3   1
#
#                               ID    Dot  Delta DelRk  DBias  MzDiff  #Cand  \
# 0                      HSGPFQR/2  0.231  0.033   [2]      0   0.004     52
# 1  AEDSNEQC[160]QVPHEDSSTEPEVK/3  0.151  0.023   [2]      0   0.008      7
# 2              PDALIGC[160]ENK/2  0.276  0.054   [2]      0   0.494     71
# 3                PERGTSLAHLEMR/4  0.381  0.139   [2]      0   0.003     20
# 4                 EERLNETDIHLK/3  0.277  0.063   [2]      0   0.001    122
#
#    MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst Spec #Pr  \
# 0    0.069  ...      -1        0          0        ()  Normal  Unk  Unk   1
# ...

# %%
NNd1_2 = pd.read_excel('./target_decoy/HEK/TPRP_10_NEW_2_decoy.xlsx')
NNd1_2.head()
# Out:
#                                            ### Query  Rk  \
# 0  b1932_293T_proteinID_12A_QE3_122212.55821.55821.3   1
# 1  b1932_293T_proteinID_12A_QE3_122212.55827.55827.2   1
# 2  b1932_293T_proteinID_12A_QE3_122212.55828.55828.2   1
# 3  b1932_293T_proteinID_12A_QE3_122212.55829.55829.3   1
# 4  b1932_293T_proteinID_12A_QE3_122212.55831.55831.3   1
#
#                                       ID    Dot  Delta DelRk  DBias  MzDiff  \
# 0                 AETSLASQDFVDMITVPIDK/3  0.253  0.083   [2]      0   0.325
# 1                          LSVLEEEEKKK/2  0.253  0.000   [2]      0   0.506
# 2                      DLSLC[160]IPHTK/2  0.218  0.019   [2]      0   0.000
# 3    YQLGTTHLISGFHC[160]NLQDGGVLDYDTTR/3  0.098  0.013   [2]      0  -0.002
# 4  ELGGC[160]EEIIEAITSAEDGAM[147]ILINK/3  0.247  0.096   [2]      0   0.333
#
#    #Cand  MeanDot  ...  PValue  KSScore  OpModMass  OpModLoc  Status Inst  \
# 0     69    0.063  ...      -1        0          0        ()  Normal  Unk
# ...

# %%
NNt3 = list(NNt1_1['Dot']) + list(NNt1_2['Dot'])
NNt3
# Out:
# [0.336,
#  0.196,
#  0.47,
#  0.6,
#  0.601,
#  0.571,
#  0.399,
#  0.686,
#  0.28,
#  0.173,
#  0.269,
#  0.176,
#  0.271,
#  0.191,
#  0.44,
#  0.234,
#  0.258,
#  0.393,
#  0.231,
#  0.202,
#  0.065,
#  0.089,
#  0.568,
#  0.238,
#  0.208,
#  0.166,
#  0.237,
#  0.14,
#  0.156,
#  0.051,
#  0.142,
#  0.337,
#  0.154,
#  0.307,
#  0.255,
#  0.247,
#  0.294,
#  0.169,
#  0.188,
#  0.589,
#  0.172,
#  0.577,
#  0.257,
#  0.213,
#  0.346,
#  0.603,
#  0.585,
#  0.304,
#  0.453,
#  0.278,
#  0.233,
#  0.275,
#  0.684,
#  0.385,
#  0.498,
#  0.224,
#  0.261,
#  0.266,
#  0.315,
#  0.219,
#  0.198,
#  0.451,
#  0.207,
#  0.286,
#  0.258,
#  0.214,
#  0.328,
#  0.091,
#  0.398,
#  0.575,
#  0.188,
#  0.15,
#  0.236,
#  0.639,
#  0.28,
#  0.139,
#  0.23,
#  0.514,
#  0.324,
#  0.587,
#  0.216,
#  0.49,
#  0.292,
#  0.238,
#  0.488,
#  0.168,
#  0.303,
#  0.309,
#  0.152,
#  0.23,
#  0.243,
#  0.157,
#  0.119,
#  0.422,
#  0.23,
#  0.538,
#  0.33,
#  0.203,
#  0.178,
#  0.663,
#  0.128,
# ...

# %%
NNd3 = list(NNd1_1['Dot']) + list(NNd1_2['Dot'])
NNd3
# Out:
# [0.231,
#  0.151,
#  0.276,
#  0.381,
#  0.277,
#  0.168,
#  0.273,
#  0.135,
#  0.232,
#  0.177,
#  0.285,
#  0.272,
#  0.214,
#  0.227,
#  0.438,
#  0.165,
#  0.341,
#  0.426,
#  0.208,
#  0.285,
#  0.334,
#  0.164,
#  0.128,
#  0.39,
#  0.209,
#  0.207,
#  0.26,
#  0.129,
#  0.159,
#  0.155,
#  0.068,
#  0.186,
#  0.265,
#  0.227,
#  0.13,
#  0.166,
#  0.224,
#  0.158,
#  0.231,
#  0.176,
#  0.283,
#  0.23,
#  0.161,
#  0.248,
#  0.294,
#  0.098,
#  0.212,
#  0.289,
#  0.247,
#  0.185,
#  0.252,
#  0.175,
#  0.274,
#  0.293,
#  0.153,
#  0.146,
#  0.234,
#  0.283,
#  0.116,
#  0.309,
#  0.235,
#  0.179,
#  0.25,
#  0.237,
#  0.298,
#  0.239,
#  0.275,
#  0.215,
#  0.226,
#  0.227,
#  0.142,
#  0.225,
#  0.242,
#  0.255,
#  0.204,
#  0.286,
#  0.294,
#  0.237,
#  0.348,
#  0.235,
#  0.124,
#  0.144,
#  0.259,
#  0.153,
#  0.334,
#  0.339,
#  0.324,
#  0.232,
#  0.299,
#  0.248,
#  0.283,
#  0.179,
#  0.215,
#  0.287,
#  0.305,
#  0.213,
#  0.193,
#  0.299,
#  0.147,
#  0.213,
# ...

# %%
nnt3 = plt.hist(NNt3, bins = 50)
nnd3 = plt.hist(NNd3, bins = 50)

# %%
print(nnt3[1][1] - nnt3[1][0])
print(nnd3[1][1] - nnd3[1][0])

plt.figure(figsize = (10, 7))
plt.xlabel('Dot score')
plt.ylabel('Count')
plt.title('TPRP_NIST_NEW: HEK')
plt.plot(nnt3[1][:-1] + 0.0085, nnt3[0])
plt.plot(nnd3[1][:-1] + 0.007, nnd3[0])
plt.show()
# Out:
# 0.01798
# 0.01492

# %%
print(len(NNt3))
print(len(NNd3))
# Out:
# 706365
# 344529

# %%
score = 0

for i in range(0, 1000):
    score += 0.001
    print('score: ', score)
    
    nnt = 0
    nnd = 0
    
    for j in NNt3:
        if j >= score:
            nnt += 1
    print('nnt: ', nnt)
    
    for k in NNd3:
        if k >= score:
            nnd += 1
    print('nnd: ', nnd)
    
    print('FDR: ', nnd / nnt)
    print("\n")
    
    if (nnd / nnt) <= 0.01:
        print(nnt)
        print(nnd)
        print(nnd / nnt)
        print(score)
        break
"""
결과
score:  0.5110000000000003
nnt:  247971
nnd:  2474
FDR:  0.009976973113791532
"""
# Out:
# score:  0.001
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.002
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.003
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.004
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.005
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.006
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.007
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.008
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.009000000000000001
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.010000000000000002
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.011000000000000003
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# score:  0.012000000000000004
# nnt:  706365
# nnd:  344529
# FDR:  0.4877492514493215
#
#
# ...
